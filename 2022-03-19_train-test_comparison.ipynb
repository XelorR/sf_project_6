# %% [markdown]
# ## imports

# %%
import pandas as pd
import numpy as np
import re
import time
import json

from lib.data_viz_functions import *

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## reading data from disk

# %%
train = pd.read_pickle("data/train_df_full_part1.pkl.zip", compression="zip")
test = pd.read_pickle("data/test.pkl.zip", compression="zip")

train.shape, test.shape
# Out:
# ((130201, 36), (34686, 32))

# %% [markdown]
# ## functions

# %%
def get_number_of_weeks_from_ownings(in_str):
    if not isinstance(in_str, str):
        return None
    list_of_own = in_str.split()
    if len(list_of_own) == 5:
        return int(list_of_own[0]) * 12 + int(list_of_own[3])
    else:
        if list_of_own[1] in ['лет', 'год']:
            return int(list_of_own[0]) * 12
        else:
            return int(list_of_own[0])
        
        
def get_number_of_owners_from_owners(in_str):
    if not isinstance(in_str, str):
        return None
    else:
        result = in_str.replace('\xa0', '')
        return int(re.sub('\D', '', result))
    # return string (to cat)
    

def get_engine_value(in_str):
    parsed_str = re.findall('(\d+.\d+)', in_str)
    if len(parsed_str):
        return float(parsed_str[0])
    else:
        return None

# %% [markdown]
# ## quick view

# %%
describe_nums(train.select_dtypes(exclude="object"))
# Out:
# <style  type="text/css" >
# #T_3966a_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#         }#T_3966a_row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_3966a_row0_col4{
#             background-color:  #ffede5;
#             color:  #000000;
#         }#T_3966a_row0_col7{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_3966a_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 31.3%, transparent 31.3%);
#         }#T_3966a_row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 67.7%, transparent 67.7%);
#         }#T_3966a_row1_col4{
#             background-color:  #e43027;
#             color:  #f1f1f1;
#         }#T_3966a_row1_col7{
#             background-color:  #3aba76;
#             color:  #000000;
#         }#T_3966a_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 11.7%, transparent 11.7%);
#         }#T_3966a_row2_col3,#T_3966a_row4_col3,#T_3966a_row5_col3,#T_3966a_row6_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }#T_3966a_row2_col4{
#             background-color:  #fff0e8;
#             color:  #000000;
#         }#T_3966a_row2_col7,#T_3966a_row3_col7,#T_3966a_row4_col7,#T_3966a_row5_col7,#T_3966a_row6_col7,#T_3966a_row7_col7{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_3966a_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 6.2%, transparent 6.2%);
#         }#T_3966a_row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }#T_3966a_row3_col4{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_3966a_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 3.5%, transparent 3.5%);
#         }#T_3966a_row4_col4,#T_3966a_row5_col4,#T_3966a_row6_col4,#T_3966a_row7_col4{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_3966a_row5_col0,#T_3966a_row6_col0,#T_3966a_row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.0%, transparent 0.0%);
#         }#T_3966a_row7_col3,#T_3966a_row8_col0,#T_3966a_row9_col0{
#             width:  10em;
#              height:  80%;
#         }#T_3966a_row8_col4,#T_3966a_row8_col7,#T_3966a_row9_col4,#T_3966a_row9_col7{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_3966a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >unique</th>        <th class="col_heading level0 col1" >n/a count</th>        <th class="col_heading level0 col2" >count</th>        <th class="col_heading level0 col3" >mean</th>        <th class="col_heading level0 col4" >std</th>        <th class="col_heading level0 col5" >min</th>        <th class="col_heading level0 col6" >25%</th>        <th class="col_heading level0 col7" >50%</th>        <th class="col_heading level0 col8" >75%</th>        <th class="col_heading level0 col9" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3966a_level0_row0" class="row_heading level0 row0" >parsing_unixtime</th>
#                         <td id="T_3966a_row0_col0" class="data row0 col0" >130154</td>
#                         <td id="T_3966a_row0_col1" class="data row0 col1" >47</td>
#                         <td id="T_3966a_row0_col2" class="data row0 col2" >130154.000000</td>
#                         <td id="T_3966a_row0_col3" class="data row0 col3" >1632842487.144867</td>
#                         <td id="T_3966a_row0_col4" class="data row0 col4" >131636.029755</td>
#                         <td id="T_3966a_row0_col5" class="data row0 col5" >1632613481.000000</td>
#                         <td id="T_3966a_row0_col6" class="data row0 col6" >1632724602.500000</td>
#                         <td id="T_3966a_row0_col7" class="data row0 col7" >1632820776.000000</td>
#                         <td id="T_3966a_row0_col8" class="data row0 col8" >1632972687.500000</td>
#                         <td id="T_3966a_row0_col9" class="data row0 col9" >1633049056.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3966a_level0_row1" class="row_heading level0 row1" >sell_id</th>
#                         <td id="T_3966a_row1_col0" class="data row1 col0" >40721</td>
#                         <td id="T_3966a_row1_col1" class="data row1 col1" >232</td>
#                         <td id="T_3966a_row1_col2" class="data row1 col2" >129969.000000</td>
#                         <td id="T_3966a_row1_col3" class="data row1 col3" >1104865960.875278</td>
#                         <td id="T_3966a_row1_col4" class="data row1 col4" >1779786.356124</td>
#                         <td id="T_3966a_row1_col5" class="data row1 col5" >1003139396.000000</td>
#                         <td id="T_3966a_row1_col6" class="data row1 col6" >1104900484.000000</td>
#                         <td id="T_3966a_row1_col7" class="data row1 col7" >1105218565.000000</td>
#                         <td id="T_3966a_row1_col8" class="data row1 col8" >1105376150.000000</td>
#                         <td id="T_3966a_row1_col9" class="data row1 col9" >1105402618.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3966a_level0_row2" class="row_heading level0 row2" >mileage</th>
#                         <td id="T_3966a_row2_col0" class="data row2 col0" >15181</td>
#                         <td id="T_3966a_row2_col1" class="data row2 col1" >27167</td>
#                         <td id="T_3966a_row2_col2" class="data row2 col2" >103034.000000</td>
#                         <td id="T_3966a_row2_col3" class="data row2 col3" >116610.915407</td>
#                         <td id="T_3966a_row2_col4" class="data row2 col4" >85154.492046</td>
#                         <td id="T_3966a_row2_col5" class="data row2 col5" >1.000000</td>
#                         <td id="T_3966a_row2_col6" class="data row2 col6" >51000.000000</td>
#                         <td id="T_3966a_row2_col7" class="data row2 col7" >100000.000000</td>
#                         <td id="T_3966a_row2_col8" class="data row2 col8" >161000.000000</td>
#                         <td id="T_3966a_row2_col9" class="data row2 col9" >1000000.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3966a_level0_row3" class="row_heading level0 row3" >price</th>
#                         <td id="T_3966a_row3_col0" class="data row3 col0" >8105</td>
#                         <td id="T_3966a_row3_col1" class="data row3 col1" >20436</td>
#                         <td id="T_3966a_row3_col2" class="data row3 col2" >109765.000000</td>
#                         <td id="T_3966a_row3_col3" class="data row3 col3" >2801223.260639</td>
#                         <td id="T_3966a_row3_col4" class="data row3 col4" >2689068.150067</td>
#                         <td id="T_3966a_row3_col5" class="data row3 col5" >23000.000000</td>
#                         <td id="T_3966a_row3_col6" class="data row3 col6" >1000000.000000</td>
#                         <td id="T_3966a_row3_col7" class="data row3 col7" >2045000.000000</td>
#                         <td id="T_3966a_row3_col8" class="data row3 col8" >3649000.000000</td>
#                         <td id="T_3966a_row3_col9" class="data row3 col9" >39990000.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3966a_level0_row4" class="row_hea

# %%
describe_nums(test.select_dtypes(exclude="object"))
# Out:
# <style  type="text/css" >
# #T_6e0ee_row0_col0,#T_6e0ee_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#         }#T_6e0ee_row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_6e0ee_row0_col4,#T_6e0ee_row2_col4{
#             background-color:  #fff4ef;
#             color:  #000000;
#         }#T_6e0ee_row0_col7{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_6e0ee_row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 68.5%, transparent 68.5%);
#         }#T_6e0ee_row1_col4{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_6e0ee_row1_col7{
#             background-color:  #3dbc74;
#             color:  #000000;
#         }#T_6e0ee_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 32.5%, transparent 32.5%);
#         }#T_6e0ee_row2_col3,#T_6e0ee_row3_col3,#T_6e0ee_row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }#T_6e0ee_row2_col7,#T_6e0ee_row3_col7,#T_6e0ee_row4_col7,#T_6e0ee_row5_col7{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_6e0ee_row3_col0,#T_6e0ee_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.2%, transparent 0.2%);
#         }#T_6e0ee_row3_col4,#T_6e0ee_row4_col4,#T_6e0ee_row5_col4{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_6e0ee_row5_col0,#T_6e0ee_row5_col3{
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_6e0ee_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >unique</th>        <th class="col_heading level0 col1" >n/a count</th>        <th class="col_heading level0 col2" >count</th>        <th class="col_heading level0 col3" >mean</th>        <th class="col_heading level0 col4" >std</th>        <th class="col_heading level0 col5" >min</th>        <th class="col_heading level0 col6" >25%</th>        <th class="col_heading level0 col7" >50%</th>        <th class="col_heading level0 col8" >75%</th>        <th class="col_heading level0 col9" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6e0ee_level0_row0" class="row_heading level0 row0" >parsing_unixtime</th>
#                         <td id="T_6e0ee_row0_col0" class="data row0 col0" >34686</td>
#                         <td id="T_6e0ee_row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_6e0ee_row0_col2" class="data row0 col2" >34686.000000</td>
#                         <td id="T_6e0ee_row0_col3" class="data row0 col3" >1603286733.619356</td>
#                         <td id="T_6e0ee_row0_col4" class="data row0 col4" >149307.058483</td>
#                         <td id="T_6e0ee_row0_col5" class="data row0 col5" >1603107306.000000</td>
#                         <td id="T_6e0ee_row0_col6" class="data row0 col6" >1603221157.750000</td>
#                         <td id="T_6e0ee_row0_col7" class="data row0 col7" >1603254133.000000</td>
#                         <td id="T_6e0ee_row0_col8" class="data row0 col8" >1603290080.250000</td>
#                         <td id="T_6e0ee_row0_col9" class="data row0 col9" >1603710264.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6e0ee_level0_row1" class="row_heading level0 row1" >sell_id</th>
#                         <td id="T_6e0ee_row1_col0" class="data row1 col0" >34686</td>
#                         <td id="T_6e0ee_row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_6e0ee_row1_col2" class="data row1 col2" >34686.000000</td>
#                         <td id="T_6e0ee_row1_col3" class="data row1 col3" >1098300150.880644</td>
#                         <td id="T_6e0ee_row1_col4" class="data row1 col4" >19112247.594511</td>
#                         <td id="T_6e0ee_row1_col5" class="data row1 col5" >2665.000000</td>
#                         <td id="T_6e0ee_row1_col6" class="data row1 col6" >1099048798.000000</td>
#                         <td id="T_6e0ee_row1_col7" class="data row1 col7" >1100910913.000000</td>
#                         <td id="T_6e0ee_row1_col8" class="data row1 col8" >1101245023.750000</td>
#                         <td id="T_6e0ee_row1_col9" class="data row1 col9" >1101374610.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6e0ee_level0_row2" class="row_heading level0 row2" >mileage</th>
#                         <td id="T_6e0ee_row2_col0" class="data row2 col0" >11268</td>
#                         <td id="T_6e0ee_row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_6e0ee_row2_col2" class="data row2 col2" >34686.000000</td>
#                         <td id="T_6e0ee_row2_col3" class="data row2 col3" >162009.767889</td>
#                         <td id="T_6e0ee_row2_col4" class="data row2 col4" >100676.559489</td>
#                         <td id="T_6e0ee_row2_col5" class="data row2 col5" >1.000000</td>
#                         <td id="T_6e0ee_row2_col6" class="data row2 col6" >91153.500000</td>
#                         <td id="T_6e0ee_row2_col7" class="data row2 col7" >149779.500000</td>
#                         <td id="T_6e0ee_row2_col8" class="data row2 col8" >215000.000000</td>
#                         <td id="T_6e0ee_row2_col9" class="data row2 col9" >1000000.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6e0ee_level0_row3" class="row_heading level0 row3" >productionDate</th>
#                         <td id="T_6e0ee_row3_col0" class="data row3 col0" >69</td>
#                         <td id="T_6e0ee_row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_6e0ee_row3_col2" class="data row3 col2" >34686.000000</td>
#                         <td id="T_6e0ee_row3_col3" class="data row3 col3" >2009.264602</td>
#                         <td id="T_6e0ee_row3_col4" class="data row3 col4" >7.047661</td>
#                         <td id="T_6e0ee_row3_col5" class="data row3 col5" >1904.000000</td>
#                         <td id="T_6e0ee_row3_col6" class="data row3 col6" >2006.000000</td>
#                         <td id="T_6e0ee_row3_col7" class="data row3 col7" >2011.000000</td>
#                         <td id="T_6e0ee_row3_col8" class="data row3 col8" >2014.000000</td>
#                         <td id="T_6e0ee_row3_col9" class="data row3 col9" >2020.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6e0ee_level0_row4" class="row_heading level0 row4" >modelDate</th>
#                         <td id="T_6e0ee_row4_col0" class="data row4 col0" >66</td>
#                         <td id="T_6e0ee_row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_6e0ee_row4_col2" class="data row4 col2" >34686.000000</td>
#                         <td id="T_6e0ee_row4_col3" class="data row4 col3" >2007.074728</td>
#                         <td id="T_6e0ee_row4_col4" class="data row4 col4" >7.415894</td>
#                         <td id="T_6e0ee_row4_col5" class="data row4 col5" >1904.000000</td>
#                         <td id="T_6e0ee_row4_col6" class="data row4 col6" >2004.000000</td>
#                         <td id="T_6e0ee_row4_col7" class="data row4 col7" >2008.000000</td>
#                         <td id="T_6e0ee_row4_col8" class="data row4 col8" >2012.000000</td>
#                         <td id="T_6e0ee_row4_col9" class="data row4 col9" >2020.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6e0ee_level0_row5" class="row_heading level0 row5" >numberOfDoors</th>
#                         <td id="T_6e0ee_row5_c

# %%
train.select_dtypes("object").shape, test.select_dtypes("object").shape
# Out:
# ((130201, 26), (34686, 26))

# %%
train.select_dtypes("object").describe().T.sort_values("unique", ascending=False)
# Out:
#                        count unique  \
# super_gen             130135  43825
# image                 130065  42933
# car_url               129969  40721
# description           129988  35274
# equipment_dict        129969  31190
# complectation_dict    105267   2348
# name                  130153   2283
# region                103034   1335
# date_added            103034    939
# vehicleConfiguration  129987    564
# model_name            103034    514
# enginePower           129988    307
# Владение               14286    261
# engineDisplacement    129988     52
# bodyType              129986     21
# color                 129988     16
# brand                 129988     12
# fuelType              129986      5
# vehicleTransmission   129986      4
# Владельцы             103034      3
# Привод                103032      3
# ПТС                   103034      2
# Руль                  103033      2
# priceCurrency         130153      2
# Состояние             103032      1
# Таможня               103030      1
#
#                                                                     top  \
# super_gen             {'sale-data-attributes': {'asciiCat': 'cars', ...
# image                 https://avatars.mds.yandex.net/get-autoru-vos/...
# car_url               https://auto.ru/cars/new/group/toyota/rav_4/21...
# description           Официальный дилер Mercedes Benz ООО РОЛЬФ фили...
# equipment_dict                                                       {}
# complectation_dict    ['cruise-control', 'multi-wheel', 'airbag-pass...
# name                                      Nissan X-Trail III Рестайлинг
# region                                                         в Москве
# date_added                                                  25 сентября
# vehicleConfiguration                      ALLROAD_5_DOORS AUTOMATIC 3.0
# model_name                                                       Tiguan
# enginePower                                                     249 N12
# Владение                                              3 года и 2 месяца
# engineDisplacement                                              2.0 LTR
# bodyType                                              внедорожник 5 дв.
# color                                                            чёрный
# brand                                                            TOYOTA
# fuelType                                                         бензин
# vehicleTransmission                                      автоматическая
# Владельцы                                                    1 владелец
# Привод                                                           полный
# ПТС                                                            Оригинал
# Руль                                                              Левый
# priceCurrency                                                       RUB
# Состояние                                            Не требует ремонта
# Таможня                                                      Растаможен
#
#                         freq
# super_gen                235
# image                    241
# car_url                  428
# description             3230
# equipment_dict          8214
# complectation_dict      1979
# name                    4013
# region                 39180
# date_added             44873
# vehicleConfiguration   10895
# model_name              4592
# enginePower            14262
# Владение                 646
# engineDisplacement     36933
# bodyType               75068
# color                  42216
# brand                  20117
# fuelType              100407
# vehicleTransmission    73836
# Владельцы              40576
# Привод                 58563
# ПТС                    92587
# Руль                   99356
# priceCurrency         129969
# Состояние             103032
# Таможня               103030

# %%
train['enginePower'] = train['enginePower'].replace('undefined N12', None)
train['enginePower'] = train[~pd.isna(train['enginePower'])]['enginePower'].str.split().str.get(0).astype('int')

# %%
train['engineDisplacement'] = train['engineDisplacement'].replace(' LTR', None)
train['engineDisplacement'] = train[~pd.isna(train['engineDisplacement'])]['engineDisplacement'].str.split().str.get(0).astype('float')

# %%
train['engineDisplacement'] = train[~pd.isna(train['engineDisplacement'])]['engineDisplacement'].apply(get_engine_value)

# %%
train[~pd.isna(train['engineDisplacement'])]['engineDisplacement']
# Out:
# 0         1.8
# 1         1.6
# 2         1.6
# 3         1.4
# 4         1.4
#          ...
# 130196    2.0
# 130197    2.4
# 130198    1.6
# 130199    1.6
# 130200    2.0
# Name: engineDisplacement, Length: 129572, dtype: float64

# %%
for i in range(10):
    print(f'page {i+1} of 10', end='\r')
    time.sleep(1)
# Out:
# page 10 of 10

# %%
train['used'] = train['car_url'].str.contains('used')

# %%
train[train['used'] == False].dropna(thresh=24).shape
# Out:
# (0, 37)

# %% [markdown]
# check NA <= 5 () (new column)
# make new or used column
# electric - drop

# %%
train.loc[~train['car_url'].str.contains('used')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-280-a73ae67a6aa8> in <module>
# ----> 1 train.loc[~train['car_url'].str.contains('used')]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __invert__(self)
#    1434             return self
#    1435
# -> 1436         new_data = self._mgr.apply(operator.invert)
#    1437         result = self._constructor(new_data).__finalize__(self, method="__invert__")
#    1438         return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     423             try:
#     424                 if callable(f):
# --> 425                     applied = b.apply(f, **kwargs)
#     426                 else:
#     427                     applied = getattr(b, f)(**kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in apply(self, func, **kwargs)
#     376         """
#     377         with np.errstate(all="ignore"):
# --> 378             result = func(self.values, **kwargs)
#     379
#     380         return self._split_op_result(result)
#
# TypeError: bad operand type for unary ~: 'float'

# %% [markdown]
# make plot

# %%
test.iloc[34682]
# Out:
# bodyType                                                            седан
# brand                                                                 BMW
# car_url                 https://auto.ru/cars/used/sale/bmw/5er/1101369...
# color                                                              чёрный
# complectation_dict                                                    NaN
# description                                Продаётся отличный автомобиль.
# engineDisplacement                                                2.0 LTR
# enginePower                                                       190 N12
# equipment_dict                                                        NaN
# fuelType                                                           дизель
# image                   https://autoru.naydex.net/nwI1K7152/b604fdsYg7...
# mileage                                                             98000
# modelDate                                                            2016
# model_info              {"code":"5ER","name":"5 серии","ru_name":"5 се...
# model_name                                                            5ER
# name                                   520d xDrive 2.0d AT (190 л.с.) 4WD
# numberOfDoors                                                           4
# parsing_unixtime                                               1603707651
# priceCurrency                                                         RUB
# productionDate                                                       2018
# sell_id                                                        1101369581
# super_gen               {"id":"20856402","name":"520","nameplate":"520...
# vehicleConfiguration                                  SEDAN AUTOMATIC 2.0
# vehicleTransmission                                        автоматическая
# vendor                                                           EUROPEAN
# Владельцы                                                      1 владелец
# Владение                                                              NaN
# ПТС                                                              Оригинал
# Привод                                                             полный
# Руль                                                                Левый
# Состояние                                              Не требует ремонта
# Таможня                                                        Растаможен
# Name: 34682, dtype: object

# %%
train['car_url'].str.contains('used').value_counts()
# Out:
# True     103034
# False     26935
# Name: car_url, dtype: int64

# %%
in_str = '2.0 LTR'
parsed_str = re.findall('(\d+.\d+)', in_str)
if len(parsed_str):
    print(parsed_str[0])
else:
    print(None)
# Out:
# 2.0

# %%
test.select_dtypes("object").describe().T.sort_values("unique", ascending=False)
# Out:
#                       count unique  \
# car_url               34686  34686
# image                 34686  34557
# description           34686  31732
# equipment_dict        24690  23705
# super_gen             34686   5890
# name                  34686   2780
# complectation_dict     6418   2364
# model_info            34686    954
# vehicleConfiguration  34686    634
# model_name            34686    544
# enginePower           34686    315
# Владение              11995    275
# engineDisplacement    34686     55
# bodyType              34686     24
# color                 34686     16
# brand                 34686     12
# fuelType              34686      5
# vehicleTransmission   34686      4
# Владельцы             34686      3
# Привод                34686      3
# vendor                34686      2
# ПТС                   34685      2
# Руль                  34686      2
# priceCurrency         34686      1
# Состояние             34686      1
# Таможня               34686      1
#
#                                                                     top   freq
# car_url               https://auto.ru/cars/used/sale/bmw/3er/1078412...      1
# image                 https://avatars.mds.yandex.net/get-verba/21620...     13
# description           Выгода до 82 000 руб. при обмене на Ваш автомо...    264
# equipment_dict                                         {"leather":true}    108
# super_gen             {"id":"6214876","displacement":1598,"engine_ty...    193
# name                                                  1.6 AT (110 л.с.)    631
# complectation_dict    {"id":"4562904","name":"Elegance","available_o...     51
# model_info            {"code":"OCTAVIA","name":"Octavia","ru_name":"...   1404
# vehicleConfiguration                      ALLROAD_5_DOORS AUTOMATIC 3.0   2389
# model_name                                                      OCTAVIA   1418
# enginePower                                                     249 N12   1708
# Владение                                             1 год и 10 месяцев    209
# engineDisplacement                                              2.0 LTR   7391
# bodyType                                                          седан  13147
# color                                                            чёрный  11010
# brand                                                               BMW   4473
# fuelType                                                         бензин  28601
# vehicleTransmission                                      автоматическая  19596
# Владельцы                                                   3 или более  15957
# Привод                                                         передний  15565
# vendor                                                         EUROPEAN  20682
# ПТС                                                            Оригинал  30098
# Руль                                                              Левый  33287
# priceCurrency                                                       RUB  34686
# Состояние                                            Не требует ремонта  34686
# Таможня                                                      Растаможен  34686

# %%
test['fuelType'].value_counts()
# Out:
# бензин     28601
# дизель      5800
# гибрид       223
# электро       55
# газ            7
# Name: fuelType, dtype: int64

# %%
test[~pd.isna(test['complectation_dict'])]
# Out:
#                 bodyType  brand  \
# 2                лифтбек  SKODA
# 3                лифтбек  SKODA
# 5                лифтбек  SKODA
# 6      внедорожник 5 дв.  SKODA
# 16               лифтбек  SKODA
# ...                  ...    ...
# 34665  внедорожник 5 дв.    BMW
# 34666              седан    BMW
# 34668              седан    BMW
# 34669              седан    BMW
# 34684  внедорожник 5 дв.    BMW
#
#                                                  car_url       color  \
# 2      https://auto.ru/cars/used/sale/skoda/superb/11...       серый
# 3      https://auto.ru/cars/used/sale/skoda/octavia/1...  коричневый
# 5      https://auto.ru/cars/used/sale/skoda/octavia_r...       серый
# 6      https://auto.ru/cars/used/sale/skoda/yeti/1101...   пурпурный
# 16     https://auto.ru/cars/used/sale/skoda/octavia/1...       белый
# ...                                                  ...         ...
# 34665  https://auto.ru/cars/used/sale/bmw/x4/11013707...       белый
# 34666  https://auto.ru/cars/used/sale/bmw/3er/1101370...  коричневый
# 34668  https://auto.ru/cars/used/sale/bmw/5er/1101369...      чёрный
# 34669  https://auto.ru/cars/used/sale/bmw/3er/1101370...      чёрный
# 34684  https://auto.ru/cars/used/sale/bmw/x1/11013625...  коричневый
#
#                                       complectation_dict  \
# 2      {"id":"20026336","name":"Ambition","available_...
# 3      {"id":"20803582","name":"Ambition","available_...
# 5      {"id":"5011515","name":"RS","available_options...
# 6      {"id":"20069264","name":"Elegance","available_...
# 16     {"id":"20913628","name":"Style","available_opt...
# ...                                                  ...
# 34665  {"id":"21184881","name":"xDrive20i xLine","ava...
# 34666  {"id":"20580761","name":"328i","available_opti...
# 34668  {"id":"21037026","name":"520d xDrive","availab...
# 34669  {"id":"21078977","name":"318i","available_opti...
# 34684  {"id":"6336008","name":"xDrive20d Локальная сб...
#
#                                              description engineDisplacement  \
# 2      Все автомобили, представленные в продаже, прох...            1.8 LTR
# 3      КОМПЛЕКТ ЗИМНЕЙ (ЛЕТНЕЙ) РЕЗИНЫ ПО СЕЗОНУ В ПО...            1.6 LTR
# 5      Продаю свой автомобиль! Автомобиль полностью и...            2.0 LTR
# 6      - выгода 60 000 рублей при покупке авто в Trad...            1.8 LTR
# 16     • Автомобиль продается официальным дилером SKO...            1.8 LTR
# ...                                                  ...                ...
# 34665  Доброго дня!.Автомобиль в отличном состоянии, ...            2.0 LTR
# 34666  Третий собственник по ПТС. Машина была  куплен...            2.0 LTR
# 34668  Добрый день . Предлагаю ЛУЧШИЙ автомобиль в св...            2.0 LTR
# 34669  Машина немецкой сборки, на гарантии, обслужива...            1.5 LTR
# 34684  Автомобиль в идеальном состоянии . Куплен новы...            2.0 LTR
#
#       enginePower                                     equipment_dict fuelType  \
# 2         152 N12  {"cruise-control":true,"tinted-glass":true,"es...   бензин
# 3         110 N12  {"cruise-control":true,"roller-blind-for-rear-...   бензин
# 5         200 N12  {"cruise-control":true,"tinted-glass":true,"es...   бензин
# 6         152 N12  {"cruise-control":true,"tinted-glass":true,"es...   бензин
# 16        180 N12  {"asr":true,"esp":true,"adaptive-light":true,"...   бензин
# ...           ...                                                ...      ...
# 34665     184 N12  {"esp":true,"start-stop-function":true,"airbag...   бензин
# 34666     245 N12  {"asr":true,"tinted-glass":true,"esp":true,"us...   бензин
# 34668     190 N12  {"cruise-control":true,"asr":true,"tinted-glas...   дизель
# 34669     136 N12  {"engine-proof":true,"esp":true,"airbag-driver...   бензин
# 34684     184 N12  {"engine-proof":true,"esp":true,"start-stop-fu...   дизель
#
#                                                    image  mileage  modelDate  \
# 2      https://avatars.mds.yandex.net/get-autoru-vos/...    88000       2013
# 3      https://autoru.naydex.net/o9DBXQ270/5ac010hAY0...    95000       2013
# 5      https://avatars.mds.yandex.net/get-autoru-vos/...   172000       2008
# 6      https://autoru.naydex.net/o9DBXQ270/5ac010hAY0...   107000       2009
# 16     https://avatars.mds.yandex.net/get-autoru-vos/...    43800       2017
# ...                                                  ...      ...        ...
# 34665  https://autoru.naydex.net/nwI1K7152/b604fdsYg7...    80000       2014
# 34666  https://autoru.naydex.net/nwI1K7152/b604fdsYg7...   117000       2011
# 34668  https://avatars.mds.yandex.net/get-autoru-vos/...    45000       2016
# 34669  https://autoru.naydex.net/nwI1K7152/b604fdsYg7...    64600       2015
# 34684  https://autoru.naydex.net/nwI1K7152/b604fdsYg7...    90500       2012
#
#                                               model_info  model_name  \
# 2      {"code":"SUPERB","name":"Superb","ru_name":"Су...      SUPERB
# 3      {"code":"OCTAVIA","name":"Octavia","ru_name":"...     OCTAVIA
# 5      {"code":"OCTAVIA_RS","name":"Octavia RS","ru_n...  OCTAVIA_RS
# 6      {"code":"YETI","name":"Yeti","ru_name":"Йети",...        YETI
# 16     {"code":"OCTAVIA","name":"Octavia","ru_name":"...     OCTAVIA
# ...                                                  ...         ...
# 34665  {"code":"X4","name":"X4","ru_name":"Х4","morph...          X4
# 34666  {"code":"3ER","name":"3 серии","ru_name":"3 се...         3ER
# 34668  {"code":"5ER","name":"5 серии","ru_name":"5 се...         5ER
# 34669  {"code":"3ER","name":"3 серии","ru_name":"3 се...         3ER
# 34684  {"code":"X1","name":"X1","ru_name":"Х1","morph...          X1
#
#                                      name  numberOfDoors  parsing_unixtime  \
# 2                  DSG 1.8 AMT (152 л.с.)              5        1603226280
# 3                       1.6 AT (110 л.с.)              5        1603226284
# 5                      2.0 AMT (200 л.с.)              5        1603226291
# 6                  1.8 AMT (152 л.с.) 4WD              5        1603226295
# 16                     1.8 AMT (180 л.с.)              5        1603226333
# ...                                   ...            ...               ...
# 34665           20i 2.0 AT (184 л.с.) 4WD              5        1603707377
# 34666              328i 2.0 AT (245 л.с.)              4        1603707401
# 34668  520d xDrive 2.0d AT (190 л.с.) 4WD              4        1603707483
# 34669              318i 1.5 AT (136 л.с.)              4        1603707487
# 34684          20d 2.0d AT (184 л.с.) 4WD              5        1603707909
#
#       priceCurrency  productionDate     sell_id  \
# 2               RUB            2014  1100658222
# 3               RUB            2014  1100937408
# 5               RUB            2012  1100912634
# 6               RUB            2012  1101228730
# 16              RUB            2018  1101140033
# ...             ...             ...         ...
# 34665           RUB            2016  1101370731
# 34666           RUB            2012  1101370758
# 34668           RUB            2018  1101369894
# 34669           RUB            2018  1101370676
# 34684           RUB            2013  1101362518
#
#                                                super_gen  \
# 2      {"id":"20026323","nameplate":"DSG","displaceme...
# 3      {"id":"20105521","displacement":1598,"engine_t...
# 5      {"id":"5009158","displacement":1984,"engine_ty...
# 6      {"id":"20089129","displacement":1798,"engine_t...
# 16     {"id":"20898378","displacement":1798,"engine_t...
# ...                                                  ...
# 34665  {"id":"20102730","name":"20i","nameplate":"20i...
# 34666  {"id":"7959524","name":"328","nameplate":"328i...
# 34668  {"id":"20856402","name":"520","nameplate":"520...
# 34669  {"id":"20548469","name":"318","nameplate":"318...
# 34684  {"id":"8247004","name":"20d","nameplate":"20d"...
#
#                 vehicleConfiguration vehicleTransmission    vendor  \
# 2                 LIFTBACK ROBOT 1.8    роботизированная  EUROPEAN
# 3             LIFTBACK AUTOMATIC 1.6      автоматическая  EUROPEAN
# 5                 LIFTBACK ROBOT 2.0    роботизированная  EUROPEAN
# 6          ALLROAD_5_DOORS ROBOT 1.8    роботизированная  EUROPEAN
# 16                LIFTBACK ROBOT 1.8    роботизированная  EUROPEAN
# ...                              ...                 ...       ...
# 34665  ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
# 34666            SEDAN AUTOMATIC 2.0      автоматическая  EUROPEAN
# 34668            SEDAN AUTOMATIC 2.0      автоматическая  EUROPEAN
# 34669            SEDAN AUTOMATIC 1.5      автоматическая  EUROPEAN
# 34684  ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
#
#          Владельцы            Владение       ПТС    Привод   Руль  \
# 2       1 владелец                 NaN  Оригинал  передний  Левый
# 3       1 владелец                 NaN  Оригинал  передний  Левый
# 5      3 или более                 NaN  Оригинал  передний  Левый
# 6       1 владелец                 NaN  Оригинал    полный  Левый
# 16      1 владелец                 NaN  Оригинал  передний  Левый
# ...            ...                 ...       ...       ...    ...
# 34665  2 владельца  2 года и 7 месяцев  Оригинал    полный  Левый
# 34666  3 или более    1 год и 3 месяца  Оригинал    задний  Левый
# 34668  2 владельца  1 год и 11 месяцев  Оригинал    полный  Левый
# 34669   1 владелец   2 года и 3 месяца  Оригинал    задний  Левый
# 34684  2 владельца                 NaN  Оригинал    полный  Левый
#
#                 Состояние     Таможня
# 2      Не требует ремонта  Растаможен
# 3      Не требует ремонта  Растаможен
# 5      Не требует ремонта  Растаможен
# 6      Не требует ремонта  Растаможен
# 16     Не требует ремонта  Растаможен
# ...                   ...         ...
# 34665  Не требует ремонта  Растаможен
# 34666  Не требует ремонта  Растаможен
# 34668  Не требует ремонта  Растаможен
# 34669  Не требует ремонта  Растаможен
# 34684  Не требует ремонта  Растаможен
#
# [6418 rows x 32 columns]

# %%
test.groupby('car_url')['image'].count().sort_values(ascending=False).head(10)
# Out:
# car_url
# https://auto.ru/cars/used/sale/audi/100/1016944865-8eb8f/            1
# https://auto.ru/cars/used/sale/skoda/octavia/1100434568-e9537421/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100515744-d97a41fa/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100514944-54916e94/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100513036-35594e9f/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100495414-bb724b6c/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100492150-5ae5281f/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100491772-7f29f9e8/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100487934-c961ee31/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100486714-6ff064ce/    1
# Name: image, dtype: int64

# %%
test.iloc[2]['model_info']
# Out:
# '{"code":"SUPERB","name":"Superb","ru_name":"Суперб","morphology":{},"nameplate":{"code":"","name":"","semantic_url":""}}'

# %%
test[test['vehicleConfiguration'] == 'ALLROAD_5_DOORS AUTOMATIC 2.0']
# Out:
#                 bodyType brand  \
# 2373   внедорожник 5 дв.  AUDI
# 2375   внедорожник 5 дв.  AUDI
# 2419   внедорожник 5 дв.  AUDI
# 2465   внедорожник 5 дв.  AUDI
# 2466   внедорожник 5 дв.  AUDI
# ...                  ...   ...
# 34648  внедорожник 5 дв.   BMW
# 34649  внедорожник 5 дв.   BMW
# 34658  внедорожник 5 дв.   BMW
# 34665  внедорожник 5 дв.   BMW
# 34684  внедорожник 5 дв.   BMW
#
#                                                  car_url       color  \
# 2373   https://auto.ru/cars/used/sale/audi/q5/1101018...  коричневый
# 2375   https://auto.ru/cars/used/sale/audi/q5/1101206...      чёрный
# 2419   https://auto.ru/cars/used/sale/audi/q5/1101192...      чёрный
# 2465   https://auto.ru/cars/used/sale/audi/q5/1101289...      чёрный
# 2466   https://auto.ru/cars/used/sale/audi/q5/1101015...      чёрный
# ...                                                  ...         ...
# 34648  https://auto.ru/cars/used/sale/bmw/x4/11013729...       белый
# 34649  https://auto.ru/cars/used/sale/bmw/x1/11013719...       белый
# 34658  https://auto.ru/cars/used/sale/bmw/x3/11013699...      чёрный
# 34665  https://auto.ru/cars/used/sale/bmw/x4/11013707...       белый
# 34684  https://auto.ru/cars/used/sale/bmw/x1/11013625...  коричневый
#
#                                       complectation_dict  \
# 2373                                                 NaN
# 2375                                                 NaN
# 2419                                                 NaN
# 2465                                                 NaN
# 2466                                                 NaN
# ...                                                  ...
# 34648  {"id":"21073109","name":"xDrive20d M Sport Лок...
# 34649                                                NaN
# 34658                                                NaN
# 34665  {"id":"21184881","name":"xDrive20i xLine","ava...
# 34684  {"id":"6336008","name":"xDrive20d Локальная сб...
#
#                                              description engineDisplacement  \
# 2373   Продам свою машину AUDI Q5 в комплектации EXCL...            2.0 LTR
# 2375   Фактический 1 владелец.\n\n。Подушка безопаснос...            2.0 LTR
# 2419   АСЦ / ЧЕСТНО!\n«АвтоСпецЦентр» Химки – это шир...            2.0 LTR
# 2465   Комфорт: 5. Безопасность: 5. Обзор: 4. Салон: ...            2.0 LTR
# 2466   Артикул: 25803\n\nПРИ ПОКУПКЕ АВТОМОБИЛЯ В КРЕ...            2.0 LTR
# ...                                                  ...                ...
# 34648  В продаже автомобили от компании АО ABTODOM, о...            2.0 LTR
# 34649  Автомобиль в отличном состоянии, дизель, небол...            2.0 LTR
# 34658  Комфорт: 10. Прочее: 1. Безопасность: 9. Салон...            2.0 LTR
# 34665  Доброго дня!.Автомобиль в отличном состоянии, ...            2.0 LTR
# 34684  Автомобиль в идеальном состоянии . Куплен новы...            2.0 LTR
#
#       enginePower                                     equipment_dict fuelType  \
# 2373      225 N12  {"cruise-control":true,"tinted-glass":true,"es...   бензин
# 2375      225 N12  {"cruise-control":true,"asr":true,"tinted-glas...   бензин
# 2419      225 N12  {"alloy-wheel-disks":true,"ptf":true,"esp":tru...   бензин
# 2465      225 N12  {"cruise-control":true,"airbag-rear-side":true...   бензин
# 2466      211 N12  {"cruise-control":true,"asr":true,"tinted-glas...   бензин
# ...           ...                                                ...      ...
# 34648     190 N12  {"cruise-control":true,"esp":true,"adaptive-li...   дизель
# 34649     184 N12  {"wheel-heat":true,"navigation":true,"eco-leat...   дизель
# 34658     245 N12  {"cruise-control":true,"engine-proof":true,"as...   бензин
# 34665     184 N12  {"esp":true,"start-stop-function":true,"airbag...   бензин
# 34684     184 N12  {"engine-proof":true,"esp":true,"start-stop-fu...   дизель
#
#                                                    image  mileage  modelDate  \
# 2373   https://autoru.naydex.net/ys1kR7800/fbd964zfcB...   114000       2012
# 2375   https://avatars.mds.yandex.net/get-autoru-vos/...    67205       2012
# 2419   https://autoru.naydex.net/ys1kR7800/fbd964zfcB...   126700       2012
# 2465   https://avatars.mds.yandex.net/get-autoru-vos/...    81378       2012
# 2466   https://avatars.mds.yandex.net/get-autoru-vos/...   111000       2008
# ...                                                  ...      ...        ...
# 34648  https://autoru.naydex.net/nwI1K7152/b604fdsYg7...    36639       2014
# 34649  https://avatars.mds.yandex.net/get-autoru-vos/...    82700       2012
# 34658  https://avatars.mds.yandex.net/get-autoru-vos/...   156000       2010
# 34665  https://autoru.naydex.net/nwI1K7152/b604fdsYg7...    80000       2014
# 34684  https://autoru.naydex.net/nwI1K7152/b604fdsYg7...    90500       2012
#
#                                               model_info model_name  \
# 2373   {"code":"Q5","name":"Q5","ru_name":"Ку5","morp...         Q5
# 2375   {"code":"Q5","name":"Q5","ru_name":"Ку5","morp...         Q5
# 2419   {"code":"Q5","name":"Q5","ru_name":"Ку5","morp...         Q5
# 2465   {"code":"Q5","name":"Q5","ru_name":"Ку5","morp...         Q5
# 2466   {"code":"Q5","name":"Q5","ru_name":"Ку5","morp...         Q5
# ...                                                  ...        ...
# 34648  {"code":"X4","name":"X4","ru_name":"Х4","morph...         X4
# 34649  {"code":"X1","name":"X1","ru_name":"Х1","morph...         X1
# 34658  {"code":"X3","name":"X3","ru_name":"Х3","morph...         X3
# 34665  {"code":"X4","name":"X4","ru_name":"Х4","morph...         X4
# 34684  {"code":"X1","name":"X1","ru_name":"Х1","morph...         X1
#
#                                    name  numberOfDoors  parsing_unixtime  \
# 2373              2.0 AT (225 л.с.) 4WD              5        1603121495
# 2375              2.0 AT (225 л.с.) 4WD              5        1603121503
# 2419              2.0 AT (225 л.с.) 4WD              5        1603121680
# 2465              2.0 AT (225 л.с.) 4WD              5        1603121870
# 2466   8tiptronic 2.0 AT (211 л.с.) 4WD              5        1603121875
# ...                                 ...            ...               ...
# 34648        20d 2.0d AT (190 л.с.) 4WD              5        1603706862
# 34649        20d 2.0d AT (184 л.с.) 4WD              5        1603706889
# 34658  28i xDrive 2.0 AT (245 л.с.) 4WD              5        1603707061
# 34665         20i 2.0 AT (184 л.с.) 4WD              5        1603707377
# 34684        20d 2.0d AT (184 л.с.) 4WD              5        1603707909
#
#       priceCurrency  productionDate     sell_id  \
# 2373            RUB            2012  1101018904
# 2375            RUB            2015  1101206595
# 2419            RUB            2013  1101192211
# 2465            RUB            2014  1101289792
# 2466            RUB            2011  1101015857
# ...             ...             ...         ...
# 34648           RUB            2018  1101372969
# 34649           RUB            2013  1101371938
# 34658           RUB            2013  1101369973
# 34665           RUB            2016  1101370731
# 34684           RUB            2013  1101362518
#
#                                                super_gen  \
# 2373   {"id":"8351307","displacement":1984,"engine_ty...
# 2375   {"id":"8351307","displacement":1984,"engine_ty...
# 2419   {"id":"8351307","displacement":1984,"engine_ty...
# 2465   {"id":"8351307","displacement":1984,"engine_ty...
# 2466   {"id":"8219747","nameplate":"8tiptronic","disp...
# ...                                                  ...
# 34648  {"id":"20102733","name":"20d","nameplate":"20d...
# 34649  {"id":"8247004","name":"20d","nameplate":"20d"...
# 34658  {"id":"7957949","name":"28i","nameplate":"28i ...
# 34665  {"id":"20102730","name":"20i","nameplate":"20i...
# 34684  {"id":"8247004","name":"20d","nameplate":"20d"...
#
#                 vehicleConfiguration vehicleTransmission    vendor  \
# 2373   ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
# 2375   ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
# 2419   ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
# 2465   ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
# 2466   ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
# ...                              ...                 ...       ...
# 34648  ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
# 34649  ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
# 34658  ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
# 34665  ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
# 34684  ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
#
#          Владельцы            Владение       ПТС  Привод   Руль  \
# 2373   3 или более                 NaN  Оригинал  полный  Левый
# 2375    1 владелец                 NaN  Оригинал  полный  Левый
# 2419   2 владельца                 NaN  Оригинал  полный  Левый
# 2465    1 владелец                 NaN  Оригинал  полный  Левый
# 2466   2 владельца                 NaN  Оригинал  полный  Левый
# ...            ...                 ...       ...     ...    ...
# 34648   1 владелец                 NaN  Оригинал  полный  Левый
# 34649   1 владелец                 NaN  Дубликат  полный  Левый
# 34658  2 владельца                 NaN  Оригинал  полный  Левый
# 34665  2 владельца  2 года и 7 месяцев  Оригинал  полный  Левый
# 34684  2 владельца                 NaN  Оригинал  полный  Левый
#
#                 Состояние     Таможня
# 2373   Не требует ремонта  Растаможен
# 2375   Не требует ремонта  Растаможен
# 2419   Не требует ремонта  Растаможен
# 2465   Не требует ремонта  Растаможен
# 2466   Не требует ремонта  Растаможен
# ...                   ...         ...
# 34648  Не требует ремонта  Растаможен
# 34649  Не требует ремонта  Растаможен
# 34658  Не требует ремонта  Растаможен
# 34665  Не требует ремонта  Растаможен
# 34684  Не требует ремонта  Растаможен
#
# [1327 rows x 32 columns]

# %%
test['Владение'] = test['Владение'].apply(get_number_of_weeks_from_ownings)
train['Владение'] = train['Владение'].apply(get_number_of_weeks_from_ownings)

# %%
test['Владельцы'] = test['Владельцы'].apply(get_number_of_owners_from_owners)
train['Владельцы'] = train['Владельцы'].apply(get_number_of_owners_from_owners)

# %%
print(
    "unique object cols in train:",
    set(train.select_dtypes("object").columns.tolist())
    - set(test.select_dtypes("object").columns.tolist()),
    "\nunique object cols in test:",
    set(test.select_dtypes("object").columns.tolist())
    - set(train.select_dtypes("object").columns.tolist()),
)
# Out:
# unique object cols in train: {'region', 'date_added'}
# unique object cols in test: {'vendor', 'model_info'}

# %% [markdown]
# ## making train and test similar

# %%
train["model_name"] = train.model_name.apply(lambda x: str(x).lower())
test["model_name"] = test.model_name.apply(lambda x: str(x).lower())

# %%
vendor_voc = test[["brand", "vendor"]].drop_duplicates().set_index("brand").to_dict()["vendor"]
vendor_voc
# Out:
# {'SKODA': 'EUROPEAN',
#  'AUDI': 'EUROPEAN',
#  'HONDA': 'JAPANESE',
#  'VOLVO': 'EUROPEAN',
#  'BMW': 'EUROPEAN',
#  'NISSAN': 'JAPANESE',
#  'INFINITI': 'JAPANESE',
#  'MERCEDES': 'EUROPEAN',
#  'TOYOTA': 'JAPANESE',
#  'LEXUS': 'JAPANESE',
#  'VOLKSWAGEN': 'EUROPEAN',
#  'MITSUBISHI': 'JAPANESE'}

# %%
train.brand.unique().tolist()
# Out:
# ['SKODA',
#  nan,
#  'AUDI',
#  'HONDA',
#  'VOLVO',
#  'BMW',
#  'NISSAN',
#  'INFINITI',
#  'MERCEDES',
#  'TOYOTA',
#  'LEXUS',
#  'VOLKSWAGEN',
#  'MITSUBISHI']

# %%
train["vendor"] = train["brand"].map(vendor_voc)
train.vendor.unique().tolist()
# Out:
# ['EUROPEAN', nan, 'JAPANESE']

# %%
print(len(train.loc[train.vendor.isna()]["model_name"].unique().tolist()), "na of", len(train.model_name.unique().tolist()))
# Out:
# 1 na of 514

# %%
train.loc[train.vendor.isna()].shape
# Out:
# (213, 36)

# %%
train.priceCurrency.unique()
# Out:
# array(['RUB', 'RUR', nan], dtype=object)

# %%
del train["priceCurrency"]
del test["priceCurrency"]
del train["model_info"]
del test["model_info"]
del train["views"]
del train["date_added"]
del train["region"]
del train["Состояние"]
del test["Состояние"]
del train["Таможня"]
del test["Таможня"]

# %% [markdown]
# ## view again

# %%
describe_nums(train.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_8509c_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_8509c_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_8509c_row0_col4 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_8509c_row0_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_8509c_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 31.3%, transparent 31.3%);
# }
# #T_8509c_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 67.7%, transparent 67.7%);
# }
# #T_8509c_row1_col4 {
#   background-color: #e43027;
#   color: #f1f1f1;
# }
# #T_8509c_row1_col7 {
#   background-color: #3aba76;
#   color: #f1f1f1;
# }
# #T_8509c_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 11.7%, transparent 11.7%);
# }
# #T_8509c_row2_col3, #T_8509c_row4_col3, #T_8509c_row5_col3, #T_8509c_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_8509c_row2_col4 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_8509c_row2_col7, #T_8509c_row3_col7, #T_8509c_row4_col7, #T_8509c_row5_col7, #T_8509c_row6_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_8509c_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 6.2%, transparent 6.2%);
# }
# #T_8509c_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_8509c_row3_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_8509c_row4_col0, #T_8509c_row5_col0, #T_8509c_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# #T_8509c_row4_col4, #T_8509c_row5_col4, #T_8509c_row6_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_8509c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8509c_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_8509c_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_8509c_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_8509c_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_8509c_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_8509c_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_8509c_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_8509c_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_8509c_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_8509c_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8509c_level0_row0" class="row_heading level0 row0" >parsing_unixtime</th>
#       <td id="T_8509c_row0_col0" class="data row0 col0" >130154</td>
#       <td id="T_8509c_row0_col1" class="data row0 col1" >47</td>
#       <td id="T_8509c_row0_col2" class="data row0 col2" >130154.000000</td>
#       <td id="T_8509c_row0_col3" class="data row0 col3" >1632842487.144867</td>
#       <td id="T_8509c_row0_col4" class="data row0 col4" >131636.029755</td>
#       <td id="T_8509c_row0_col5" class="data row0 col5" >1632613481.000000</td>
#       <td id="T_8509c_row0_col6" class="data row0 col6" >1632724602.500000</td>
#       <td id="T_8509c_row0_col7" class="data row0 col7" >1632820776.000000</td>
#       <td id="T_8509c_row0_col8" class="data row0 col8" >1632972687.500000</td>
#       <td id="T_8509c_row0_col9" class="data row0 col9" >1633049056.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8509c_level0_row1" class="row_heading level0 row1" >sell_id</th>
#       <td id="T_8509c_row1_col0" class="data row1 col0" >40721</td>
#       <td id="T_8509c_row1_col1" class="data row1 col1" >232</td>
#       <td id="T_8509c_row1_col2" class="data row1 col2" >129969.000000</td>
#       <td id="T_8509c_row1_col3" class="data row1 col3" >1104865960.875278</td>
#       <td id="T_8509c_row1_col4" class="data row1 col4" >1779786.356124</td>
#       <td id="T_8509c_row1_col5" class="data row1 col5" >1003139396.000000</td>
#       <td id="T_8509c_row1_col6" class="data row1 col6" >1104900484.000000</td>
#       <td id="T_8509c_row1_col7" class="data row1 col7" >1105218565.000000</td>
#       <td id="T_8509c_row1_col8" class="data row1 col8" >1105376150.000000</td>
#       <td id="T_8509c_row1_col9" class="data row1 col9" >1105402618.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8509c_level0_row2" class="row_heading level0 row2" >mileage</th>
#       <td id="T_8509c_row2_col0" class="data row2 col0" >15181</td>
#       <td id="T_8509c_row2_col1" class="data row2 col1" >27167</td>
#       <td id="T_8509c_row2_col2" class="data row2 col2" >103034.000000</td>
#       <td id="T_8509c_row2_col3" class="data row2 col3" >116610.915407</td>
#       <td id="T_8509c_row2_col4" class="data row2 col4" >85154.492046</td>
#       <td id="T_8509c_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_8509c_row2_col6" class="data row2 col6" >51000.000000</td>
#       <td id="T_8509c_row2_col7" class="data row2 col7" >100000.000000</td>
#       <td id="T_8509c_row2_col8" class="data row2 col8" >161000.000000</td>
#       <td id="T_8509c_row2_col9" class="data row2 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8509c_level0_row3" class="row_heading level0 row3" >price</th>
#       <td id="T_8509c_row3_col0" class="data row3 col0" >8105</td>
#       <td id="T_8509c_row3_col1" class="data row3 col1" >20436</td>
#       <td id="T_8509c_row3_col2" class="data row3 col2" >109765.000000</td>
#       <td id="T_8509c_row3_col3" class="data row3 col3" >2801223.260639</td>
#       <td id="T_8509c_row3_col4" class="data row3 col4" >2689068.150068</td>
#       <td id="T_8509c_row3_col5" class="data row3 col5" >23000.000000</td>
#       <td id="T_8509c_row3_col6" class="data row3 col6" >1000000.000000</td>
#       <td id="T_8509c_row3_col7" class="data row3 col7" >2045000.000000</td>
#       <td id="T_8509c_row3_col8" class="data row3 col8" >3649000.000000</td>
#       <td id="T_8509c_row3_col9" class="data row3 col9" >39990000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8509c_level0_row4" class="row_heading level0 row4" >modelDate</th>
#       <td id="T_8509c_row4_col0" class="data row4 col0" >53</td>
#       <td id="T_8509c_row4_col1" class="data row4 col1" >215</td>
#       <td id="T_8509c_row4_col2" class="data row4 col2" >129986.000000</td>
#       <td id="T_8509c_row4_col3" class="data row4 col3" >2012.934578</td>
#       <td id="T_8509c_row4_col4" class="data row4 col4" >6.017749</td>
#       <td id="T_8509c_row4_col5" class="data row4 col5" >1938.000000</td>
#       <td id="T_8509c_row4_col6" class="data row4 col6" >2010.000000</td>
#       <td id="T_8509c_row4_col7" class="data row4 col7" >2014.000000</td>
#       <td id="T_8509c_row4_col8" class="data row4 col8" >2017.000000</td>
#       <td id="T_8509c_row4_col9" class="data row4 col9" >2021.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8509c_level0_row5" class="row_heading level0 row5" >productionDate</th>
#       <td id="T_8509c_row5_col0" class="data row5 col0" >50</td>
#       <td id="T_8509c_row5_col1" class="data row5 col1" >213</td>
#       <td id="T_8509c_row5_col2" class="data row5 col2" >129988.000000</td>
#       <td id="T_8509c_row5_col3" class="data row5 col3" >2015.083854</td>
#       <td id="T_8509c_row5_col4" class="data row5 col4" >5.929774</td>
#       <td id="T_8509c_row5_col5" class="data row5 col5" >1952.000000</td>
#       <td id="T_8509c_row5_col6" class="data row5 col6" >2012.000000</td>
#       <td id="T_8509c_row5_col7" class="data row5 col7" >2016.000000</td>
#       <td id="T_8509c_row5_col8" class="data row5 col8" >2020.000000</td>
#       <td id="T_8509c_row5_col9" class="data row5 col9" >2021.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8509c_level0_row6" class="row_heading level0 row6" >numberOfDoors</th>
#       <td id="T_8509c_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_8509c_row6_col1" class="data row6 col1

# %%
describe_nums(test.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_1c379_row0_col0, #T_1c379_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_1c379_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_1c379_row0_col4, #T_1c379_row2_col4 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_1c379_row0_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_1c379_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.5%, transparent 68.5%);
# }
# #T_1c379_row1_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_1c379_row1_col7 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_1c379_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 32.5%, transparent 32.5%);
# }
# #T_1c379_row2_col3, #T_1c379_row3_col3, #T_1c379_row4_col3, #T_1c379_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_1c379_row2_col7, #T_1c379_row3_col7, #T_1c379_row4_col7, #T_1c379_row5_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_1c379_row3_col0, #T_1c379_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.2%, transparent 0.2%);
# }
# #T_1c379_row3_col4, #T_1c379_row4_col4, #T_1c379_row5_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_1c379_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_1c379">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c379_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_1c379_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_1c379_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_1c379_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_1c379_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_1c379_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_1c379_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_1c379_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_1c379_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_1c379_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c379_level0_row0" class="row_heading level0 row0" >parsing_unixtime</th>
#       <td id="T_1c379_row0_col0" class="data row0 col0" >34686</td>
#       <td id="T_1c379_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_1c379_row0_col2" class="data row0 col2" >34686.000000</td>
#       <td id="T_1c379_row0_col3" class="data row0 col3" >1603286733.619356</td>
#       <td id="T_1c379_row0_col4" class="data row0 col4" >149307.058483</td>
#       <td id="T_1c379_row0_col5" class="data row0 col5" >1603107306.000000</td>
#       <td id="T_1c379_row0_col6" class="data row0 col6" >1603221157.750000</td>
#       <td id="T_1c379_row0_col7" class="data row0 col7" >1603254133.000000</td>
#       <td id="T_1c379_row0_col8" class="data row0 col8" >1603290080.250000</td>
#       <td id="T_1c379_row0_col9" class="data row0 col9" >1603710264.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c379_level0_row1" class="row_heading level0 row1" >sell_id</th>
#       <td id="T_1c379_row1_col0" class="data row1 col0" >34686</td>
#       <td id="T_1c379_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_1c379_row1_col2" class="data row1 col2" >34686.000000</td>
#       <td id="T_1c379_row1_col3" class="data row1 col3" >1098300150.880644</td>
#       <td id="T_1c379_row1_col4" class="data row1 col4" >19112247.594511</td>
#       <td id="T_1c379_row1_col5" class="data row1 col5" >2665.000000</td>
#       <td id="T_1c379_row1_col6" class="data row1 col6" >1099048798.000000</td>
#       <td id="T_1c379_row1_col7" class="data row1 col7" >1100910913.000000</td>
#       <td id="T_1c379_row1_col8" class="data row1 col8" >1101245023.750000</td>
#       <td id="T_1c379_row1_col9" class="data row1 col9" >1101374610.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c379_level0_row2" class="row_heading level0 row2" >mileage</th>
#       <td id="T_1c379_row2_col0" class="data row2 col0" >11268</td>
#       <td id="T_1c379_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_1c379_row2_col2" class="data row2 col2" >34686.000000</td>
#       <td id="T_1c379_row2_col3" class="data row2 col3" >162009.767889</td>
#       <td id="T_1c379_row2_col4" class="data row2 col4" >100676.559489</td>
#       <td id="T_1c379_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_1c379_row2_col6" class="data row2 col6" >91153.500000</td>
#       <td id="T_1c379_row2_col7" class="data row2 col7" >149779.500000</td>
#       <td id="T_1c379_row2_col8" class="data row2 col8" >215000.000000</td>
#       <td id="T_1c379_row2_col9" class="data row2 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c379_level0_row3" class="row_heading level0 row3" >productionDate</th>
#       <td id="T_1c379_row3_col0" class="data row3 col0" >69</td>
#       <td id="T_1c379_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_1c379_row3_col2" class="data row3 col2" >34686.000000</td>
#       <td id="T_1c379_row3_col3" class="data row3 col3" >2009.264602</td>
#       <td id="T_1c379_row3_col4" class="data row3 col4" >7.047661</td>
#       <td id="T_1c379_row3_col5" class="data row3 col5" >1904.000000</td>
#       <td id="T_1c379_row3_col6" class="data row3 col6" >2006.000000</td>
#       <td id="T_1c379_row3_col7" class="data row3 col7" >2011.000000</td>
#       <td id="T_1c379_row3_col8" class="data row3 col8" >2014.000000</td>
#       <td id="T_1c379_row3_col9" class="data row3 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c379_level0_row4" class="row_heading level0 row4" >modelDate</th>
#       <td id="T_1c379_row4_col0" class="data row4 col0" >66</td>
#       <td id="T_1c379_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_1c379_row4_col2" class="data row4 col2" >34686.000000</td>
#       <td id="T_1c379_row4_col3" class="data row4 col3" >2007.074728</td>
#       <td id="T_1c379_row4_col4" class="data row4 col4" >7.415894</td>
#       <td id="T_1c379_row4_col5" class="data row4 col5" >1904.000000</td>
#       <td id="T_1c379_row4_col6" class="data row4 col6" >2004.000000</td>
#       <td id="T_1c379_row4_col7" class="data row4 col7" >2008.000000</td>
#       <td id="T_1c379_row4_col8" class="data row4 col8" >2012.000000</td>
#       <td id="T_1c379_row4_col9" class="data row4 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c379_level0_row5" class="row_heading level0 row5" >numberOfDoors</th>
#       <td id="T_1c379_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_1c379_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_1c379_row5_col2" class="data row5 col2" >34686.000000</td>
#       <td id="T_1c379_row5_col3" class="data row5 col3" >4.450816</td>
#       <td id="T_1c379_row5_col4" class="data row5 col4" >0.703040</td>
#       <td id="T_1c379_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_1c379_row5_col6" class="data row5 col6" >4.000000</td>
#       <td id="T_1c379_row5_col7" class="data row5 col7" >5.000000</td>
#       <td id="T_1c379_row5_col8" class="data row5 col8" >5.000000</td>
#       <td id="T_1c379_row5_col9" class="data row5 col9" >5.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
train.select_dtypes("object").shape, test.select_dtypes("object").shape
# Out:
# ((130201, 22), (34686, 22))

# %%
train.select_dtypes("object").describe().T.sort_values("unique", ascending=False)
# Out:
#                        count unique  \
# super_gen             130135  43825
# image                 130065  42933
# car_url               129969  40721
# description           129988  35274
# equipment_dict        129969  31190
# complectation_dict    105267   2348
# name                  130153   2283
# vehicleConfiguration  129987    564
# model_name            130201    514
# enginePower           129988    307
# Владение               14286    261
# engineDisplacement    129988     52
# bodyType              129986     21
# color                 129988     16
# brand                 129988     12
# fuelType              129986      5
# vehicleTransmission   129986      4
# Владельцы             103034      3
# Привод                103032      3
# vendor                129988      2
# ПТС                   103034      2
# Руль                  103033      2
#
#                                                                     top  \
# super_gen             {'sale-data-attributes': {'asciiCat': 'cars', ...
# image                 https://avatars.mds.yandex.net/get-autoru-vos/...
# car_url               https://auto.ru/cars/new/group/toyota/rav_4/21...
# description           Официальный дилер Mercedes Benz ООО РОЛЬФ фили...
# equipment_dict                                                       {}
# complectation_dict    ['cruise-control', 'multi-wheel', 'airbag-pass...
# name                                      Nissan X-Trail III Рестайлинг
# vehicleConfiguration                      ALLROAD_5_DOORS AUTOMATIC 3.0
# model_name                                                          nan
# enginePower                                                     249 N12
# Владение                                              3 года и 2 месяца
# engineDisplacement                                              2.0 LTR
# bodyType                                              внедорожник 5 дв.
# color                                                            чёрный
# brand                                                            TOYOTA
# fuelType                                                         бензин
# vehicleTransmission                                      автоматическая
# Владельцы                                                    1 владелец
# Привод                                                           полный
# vendor                                                         EUROPEAN
# ПТС                                                            Оригинал
# Руль                                                              Левый
#
#                         freq
# super_gen                235
# image                    241
# car_url                  428
# description             3230
# equipment_dict          8214
# complectation_dict      1979
# name                    4013
# vehicleConfiguration   10895
# model_name             27167
# enginePower            14262
# Владение                 646
# engineDisplacement     36933
# bodyType               75068
# color                  42216
# brand                  20117
# fuelType              100407
# vehicleTransmission    73836
# Владельцы              40576
# Привод                 58563
# vendor                 72959
# ПТС                    92587
# Руль                   99356

# %%
test.select_dtypes("object").describe().T.sort_values("unique", ascending=False)['top'].head(1).tolist()
# Out:
# ['https://auto.ru/cars/used/sale/bmw/3er/1078412133-45adb3d5/']

# %%
test.sample(3).T
# Out:
#                                                                   16633  \
# bodyType                                              внедорожник 5 дв.
# brand                                                          MERCEDES
# car_url               https://auto.ru/cars/used/sale/mercedes/g_klas...
# color                                                            чёрный
# complectation_dict                                                  NaN
# description           id: 41467\n«МБ Измайлово» – официальный дилер ...
# engineDisplacement                                              3.0 LTR
# enginePower                                                     245 N12
# equipment_dict        {"cruise-control":true,"engine-proof":true,"as...
# fuelType                                                         дизель
# image                 https://avatars.mds.yandex.net/get-autoru-vos/...
# mileage                                                           85180
# modelDate                                                          2015
# model_info            {"code":"G_KLASSE","name":"G-Класс","ru_name":...
# model_name                                                     G_KLASSE
# name                                       350 d 3.0d AT (245 л.с.) 4WD
# numberOfDoors                                                         5
# parsing_unixtime                                             1603244687
# priceCurrency                                                       RUB
# productionDate                                                     2016
# sell_id                                                      1101082301
# super_gen             {"id":"20632445","name":"350","nameplate":"350...
# vehicleConfiguration                      ALLROAD_5_DOORS AUTOMATIC 3.0
# vehicleTransmission                                      автоматическая
# vendor                                                         EUROPEAN
# Владельцы                                                   2 владельца
# Владение                                                            NaN
# ПТС                                                            Оригинал
# Привод                                                           полный
# Руль                                                              Левый
# Состояние                                            Не требует ремонта
# Таможня                                                      Растаможен
#
#                                                                   5432   \
# bodyType                                              внедорожник 5 дв.
# brand                                                             HONDA
# car_url               https://auto.ru/cars/used/sale/honda/cr_v/1101...
# color                                                           голубой
# complectation_dict                                                  NaN
# description           В идеальном состоянии, ни одного крашенного эл...
# engineDisplacement                                              2.4 LTR
# enginePower                                                     188 N12
# equipment_dict        {"cruise-control":true,"tinted-glass":true,"es...
# fuelType                                                         бензин
# image                 https://avatars.mds.yandex.net/get-autoru-vos/...
# mileage                                                          128000
# modelDate                                                          2014
# model_info            {"code":"CR_V","name":"CR-V","ru_name":"CR-V",...
# model_name                                                         CR_V
# name                                             2.4 CVT (188 л.с.) 4WD
# numberOfDoors                                                         5
# parsing_unixtime                                             1603254394
# priceCurrency                                                       RUB
# productionDate                                                     2016
# sell_id                                                      1101283969
# super_gen             {"id":"20522313","displacement":2356,"engine_t...
# vehicleConfiguration                       ALLROAD_5_DOORS VARIATOR 2.4
# vehicleTransmission                                            вариатор
# vendor                                                         JAPANESE
# Владельцы                                                    1 владелец
# Владение                                                         4 года
# ПТС                                                            Оригинал
# Привод                                                           полный
# Руль                                                              Левый
# Состояние                                            Не требует ремонта
# Таможня                                                      Растаможен
#
#                                                                   8200
# bodyType                                              внедорожник 5 дв.
# brand                                                               BMW
# car_url               https://auto.ru/cars/used/sale/bmw/x5_m/108984...
# color                                                             синий
# complectation_dict    {"id":"20493549","name":"Базовая","available_o...
# description           Родной Цвет - Белый.\nАвтомобиль куплен весной...
# engineDisplacement                                              4.4 LTR
# enginePower                                                     575 N12
# equipment_dict        {"cruise-control":true,"esp":true,"adaptive-li...
# fuelType                                                         бензин
# image                 https://avatars.mds.yandex.net/get-autoru-vos/...
# mileage                                                           47000
# modelDate                                                          2014
# model_info            {"code":"X5_M","name":"X5 M","ru_name":"Х5 М",...
# model_name                                                         X5_M
# name                                              4.4 AT (575 л.с.) 4WD
# numberOfDoors                                                         5
# parsing_unixtime                                             1603110218
# priceCurrency                                                       RUB
# productionDate                                                     2017
# sell_id                                                      1089842790
# super_gen             {"id":"20289110","displacement":4395,"engine_t...
# vehicleConfiguration                      ALLROAD_5_DOORS AUTOMATIC 4.4
# vehicleTransmission                                      автоматическая
# vendor                                                         EUROPEAN
# Владельцы                                                    1 владелец
# Владение                                             2 года и 6 месяцев
# ПТС                                                            Оригинал
# Привод                                                           полный
# Руль                                                              Левый
# Состояние                                            Не требует ремонта
# Таможня                                                      Растаможен

# %%
train.iloc[97515]['complectation_dict']
# Out:
# "['cruise-control', 'multi-wheel', 'airbag-passenger', 'lock', 'electro-mirrors', 'mirrors-heat', 'leather', 'computer', 'seat-transformation', 'wheel-power', 'light-cleaner', 'airbag-rear-side', 'airbag-side', 'abs', 'wheel-leather', 'climate-control-1', 'auto-mirrors', 'esp', 'audiopreparation', 'electro-window-back', 'condition', 'park-assist-r', 'airbag-driver', 'aux', 'electro-window-front', 'hcc', 'airbag-curtain', 'keyless-entry', 'passenger-seat-electric', 'start-button', 'ptf', 'audiosystem-cd', 'migration-flag', 'front-seats-heat', 'bluetooth', 'wheel-configuration2', 'wheel-configuration1', 'immo']"

# %%
test.iloc[16633]['model_info']
# Out:
# '{"code":"G_KLASSE","name":"G-Класс","ru_name":"G-класс","morphology":{},"nameplate":{"code":"9264617","name":"350","semantic_url":"350"}}'

# %%
test['transmission'] = test['super_gen'].apply(lambda x: json.loads(x)['transmission'])

# %%
test['transmission'].unique()
# Out:
# array(['ROBOT', 'MECHANICAL', 'AUTOMATIC', 'VARIATOR'], dtype=object)

# %%
train.shape, test.shape
# Out:
# ((130201, 29), (34686, 28))

# %%
train.loc[train.price.isna()].shape[0], train.price.shape[0], train.loc[train.price.isna()].shape[0] / train.price.shape[0]
# Out:
# (20436, 130201, 0.1569573198362532)

# %% [markdown]
# ## conclusion
#
# $y = price$ - dropna, take a log
#
# - **car_url** - why we have different rows with the same url for train?
# - **image** - maybe same images with different urls indicate fraud? - checked - to remove
# - **description** - to tokenize - to read more about tokenize
# - **equipment_dict** - deserialize, expand as additional cols
# - **complectation_dict** - deserialize, expand as additional cols
# - **name** - to check intersection train vs test
# - **vehicleConfiguration** - view and maybe split to several features if splittable, and check the mean of number 3.0
# - **engineDisplacement** - convert to float
# - **enginePower** - convert to integer
# - **Владельцы** - convert to integer
# - **Владение** - calculate number of days
# - **model_name** - check NAs, compare with **name** - maybe keep only one?
# - **vendor** - check NAs
# - **bodyType**, **color**, **brand**, **fuelType**, **vehicleTransmission**, **Привод**, **ПТС**, **Руль** - _temporary keep as is_
# - mileage rename
# - compare with existing features
# - compare 4 dicts (equepment, complactation) train - test
# Numerics - fill na, log if tailed, standartize
# https://www.kaggle.com/datasets/gmbitz/all-auto-ru-09-09-2020
