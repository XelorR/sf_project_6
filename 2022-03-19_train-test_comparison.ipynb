# %% [markdown]
# ## imports

# %%
import pandas as pd

from lib.data_viz_functions import *

# %% [markdown]
# ## reading data from disk

# %%
train = pd.read_pickle("data/train_df_full_part1.pkl.zip", compression="zip")
test = pd.read_pickle("data/test.pkl.zip", compression="zip")

train.shape, test.shape
# Out:
# ((130201, 36), (34686, 32))

# %% [markdown]
# ## quick view

# %%
describe_nums(train.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_ba305_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_ba305_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_ba305_row0_col4 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_ba305_row0_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_ba305_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 31.3%, transparent 31.3%);
# }
# #T_ba305_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 67.7%, transparent 67.7%);
# }
# #T_ba305_row1_col4 {
#   background-color: #e43027;
#   color: #f1f1f1;
# }
# #T_ba305_row1_col7 {
#   background-color: #3aba76;
#   color: #f1f1f1;
# }
# #T_ba305_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 11.7%, transparent 11.7%);
# }
# #T_ba305_row2_col3, #T_ba305_row4_col3, #T_ba305_row5_col3, #T_ba305_row6_col3, #T_ba305_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_ba305_row2_col4 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_ba305_row2_col7, #T_ba305_row3_col7, #T_ba305_row4_col7, #T_ba305_row5_col7, #T_ba305_row6_col7, #T_ba305_row7_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_ba305_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 6.2%, transparent 6.2%);
# }
# #T_ba305_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_ba305_row3_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_ba305_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 3.5%, transparent 3.5%);
# }
# #T_ba305_row4_col4, #T_ba305_row5_col4, #T_ba305_row6_col4, #T_ba305_row7_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_ba305_row5_col0, #T_ba305_row6_col0, #T_ba305_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# #T_ba305_row8_col0, #T_ba305_row8_col3, #T_ba305_row9_col0, #T_ba305_row9_col3 {
#   width: 10em;
# }
# #T_ba305_row8_col4, #T_ba305_row8_col7, #T_ba305_row9_col4, #T_ba305_row9_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ba305">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba305_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_ba305_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_ba305_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_ba305_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_ba305_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_ba305_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_ba305_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_ba305_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_ba305_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_ba305_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba305_level0_row0" class="row_heading level0 row0" >parsing_unixtime</th>
#       <td id="T_ba305_row0_col0" class="data row0 col0" >130154</td>
#       <td id="T_ba305_row0_col1" class="data row0 col1" >47</td>
#       <td id="T_ba305_row0_col2" class="data row0 col2" >130154.000000</td>
#       <td id="T_ba305_row0_col3" class="data row0 col3" >1632842487.144867</td>
#       <td id="T_ba305_row0_col4" class="data row0 col4" >131636.029755</td>
#       <td id="T_ba305_row0_col5" class="data row0 col5" >1632613481.000000</td>
#       <td id="T_ba305_row0_col6" class="data row0 col6" >1632724602.500000</td>
#       <td id="T_ba305_row0_col7" class="data row0 col7" >1632820776.000000</td>
#       <td id="T_ba305_row0_col8" class="data row0 col8" >1632972687.500000</td>
#       <td id="T_ba305_row0_col9" class="data row0 col9" >1633049056.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ba305_level0_row1" class="row_heading level0 row1" >sell_id</th>
#       <td id="T_ba305_row1_col0" class="data row1 col0" >40721</td>
#       <td id="T_ba305_row1_col1" class="data row1 col1" >232</td>
#       <td id="T_ba305_row1_col2" class="data row1 col2" >129969.000000</td>
#       <td id="T_ba305_row1_col3" class="data row1 col3" >1104865960.875278</td>
#       <td id="T_ba305_row1_col4" class="data row1 col4" >1779786.356124</td>
#       <td id="T_ba305_row1_col5" class="data row1 col5" >1003139396.000000</td>
#       <td id="T_ba305_row1_col6" class="data row1 col6" >1104900484.000000</td>
#       <td id="T_ba305_row1_col7" class="data row1 col7" >1105218565.000000</td>
#       <td id="T_ba305_row1_col8" class="data row1 col8" >1105376150.000000</td>
#       <td id="T_ba305_row1_col9" class="data row1 col9" >1105402618.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ba305_level0_row2" class="row_heading level0 row2" >mileage</th>
#       <td id="T_ba305_row2_col0" class="data row2 col0" >15181</td>
#       <td id="T_ba305_row2_col1" class="data row2 col1" >27167</td>
#       <td id="T_ba305_row2_col2" class="data row2 col2" >103034.000000</td>
#       <td id="T_ba305_row2_col3" class="data row2 col3" >116610.915407</td>
#       <td id="T_ba305_row2_col4" class="data row2 col4" >85154.492046</td>
#       <td id="T_ba305_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_ba305_row2_col6" class="data row2 col6" >51000.000000</td>
#       <td id="T_ba305_row2_col7" class="data row2 col7" >100000.000000</td>
#       <td id="T_ba305_row2_col8" class="data row2 col8" >161000.000000</td>
#       <td id="T_ba305_row2_col9" class="data row2 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ba305_level0_row3" class="row_heading level0 row3" >price</th>
#       <td id="T_ba305_row3_col0" class="data row3 col0" >8105</td>
#       <td id="T_ba305_row3_col1" class="data row3 col1" >20436</td>
#       <td id="T_ba305_row3_col2" class="data row3 col2" >109765.000000</td>
#       <td id="T_ba305_row3_col3" class="data row3 col3" >2801223.260639</td>
#       <td id="T_ba305_row3_col4" class="data row3 col4" >2689068.150068</td>
#       <td id="T_ba305_row3_col5" class="data row3 col5" >23000.000000</td>
#       <td id="T_ba305_row3_col6" class="data row3 col6" >1000000.000000</td>
#       <td id="T_ba305_row3_col7" class="data row3 col7" >2045000.000000</td>
#       <td id="T_ba305_row3_col8" class="data row3 col8" >3649000.000000</td>
#       <td id="T_ba305_row3_col9" class="data row3 col9" >39990000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ba305_level0_row4" class="row_heading level0 row4" >views</th>
#       <td id="T_ba305_row4_col0" class="data row4 col0" >4511</td>
#       <td id="T_ba305_row4_col1" class="data row4 col1" >28203</td>
#       <td id="T_ba305_row4_col2" class="data row4 col2" >101998.000000</td>
#       <td id="T_ba305_row4_col3" class="data row4 col3" >564.982284</td>
#       <td id="T_ba305_row4_col4" class="data row4 col4" >1814.036025</td>
#       <td id="T_ba305_row4_col5" class="data row4 col5" >2.000000</td>
#       <td id="T_ba305_row4_col6" class="data row4 col6" >127.000000</td>
#       <td id="T_ba305_row4_col7" class="data row4 col7" >245.000000</td>
#       <td id="T_ba305_row4_col8" class="data row4 col8" >511.000000</td>
#       <td id="T_ba305_row4_col9" class="data row4 col9" >148149.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ba305_level0_row5" class="row_heading level0 row5" >modelDate</th>
#       <td id="T_ba305_row5_col0" class="data row5 col0" >53</td>
#       <td id="T_ba305_row5_col1" class="data row5 col1" >215</td>
#       <td id="T_ba305_row5_col2" class="data row5 col2" >129986.000000</td>
#       <td id="T_ba305_row5_col3" class="data row5 col3" >2012.934578</td>
#       <td id="T_ba305_row5_col4" class="data row5 col4" >6.017749</td>
#       <td id="T_ba305_row5_col5" class="data row5 col5" >1938.000000</td>
#       <td id="T_ba305_row5_col6" class="data row5 col6" >2010.000000</td>
#       <td id="T_ba305_row5_col7" class="data row5 col7"

# %%
describe_nums(test.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_2a1a5_row0_col0, #T_2a1a5_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_2a1a5_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_2a1a5_row0_col4, #T_2a1a5_row2_col4 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_2a1a5_row0_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_2a1a5_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.5%, transparent 68.5%);
# }
# #T_2a1a5_row1_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_2a1a5_row1_col7 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_2a1a5_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 32.5%, transparent 32.5%);
# }
# #T_2a1a5_row2_col3, #T_2a1a5_row3_col3, #T_2a1a5_row4_col3, #T_2a1a5_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_2a1a5_row2_col7, #T_2a1a5_row3_col7, #T_2a1a5_row4_col7, #T_2a1a5_row5_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_2a1a5_row3_col0, #T_2a1a5_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.2%, transparent 0.2%);
# }
# #T_2a1a5_row3_col4, #T_2a1a5_row4_col4, #T_2a1a5_row5_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_2a1a5_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_2a1a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a1a5_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_2a1a5_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_2a1a5_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_2a1a5_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_2a1a5_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_2a1a5_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_2a1a5_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_2a1a5_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_2a1a5_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_2a1a5_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a1a5_level0_row0" class="row_heading level0 row0" >parsing_unixtime</th>
#       <td id="T_2a1a5_row0_col0" class="data row0 col0" >34686</td>
#       <td id="T_2a1a5_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_2a1a5_row0_col2" class="data row0 col2" >34686.000000</td>
#       <td id="T_2a1a5_row0_col3" class="data row0 col3" >1603286733.619356</td>
#       <td id="T_2a1a5_row0_col4" class="data row0 col4" >149307.058483</td>
#       <td id="T_2a1a5_row0_col5" class="data row0 col5" >1603107306.000000</td>
#       <td id="T_2a1a5_row0_col6" class="data row0 col6" >1603221157.750000</td>
#       <td id="T_2a1a5_row0_col7" class="data row0 col7" >1603254133.000000</td>
#       <td id="T_2a1a5_row0_col8" class="data row0 col8" >1603290080.250000</td>
#       <td id="T_2a1a5_row0_col9" class="data row0 col9" >1603710264.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2a1a5_level0_row1" class="row_heading level0 row1" >sell_id</th>
#       <td id="T_2a1a5_row1_col0" class="data row1 col0" >34686</td>
#       <td id="T_2a1a5_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_2a1a5_row1_col2" class="data row1 col2" >34686.000000</td>
#       <td id="T_2a1a5_row1_col3" class="data row1 col3" >1098300150.880644</td>
#       <td id="T_2a1a5_row1_col4" class="data row1 col4" >19112247.594511</td>
#       <td id="T_2a1a5_row1_col5" class="data row1 col5" >2665.000000</td>
#       <td id="T_2a1a5_row1_col6" class="data row1 col6" >1099048798.000000</td>
#       <td id="T_2a1a5_row1_col7" class="data row1 col7" >1100910913.000000</td>
#       <td id="T_2a1a5_row1_col8" class="data row1 col8" >1101245023.750000</td>
#       <td id="T_2a1a5_row1_col9" class="data row1 col9" >1101374610.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2a1a5_level0_row2" class="row_heading level0 row2" >mileage</th>
#       <td id="T_2a1a5_row2_col0" class="data row2 col0" >11268</td>
#       <td id="T_2a1a5_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_2a1a5_row2_col2" class="data row2 col2" >34686.000000</td>
#       <td id="T_2a1a5_row2_col3" class="data row2 col3" >162009.767889</td>
#       <td id="T_2a1a5_row2_col4" class="data row2 col4" >100676.559489</td>
#       <td id="T_2a1a5_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_2a1a5_row2_col6" class="data row2 col6" >91153.500000</td>
#       <td id="T_2a1a5_row2_col7" class="data row2 col7" >149779.500000</td>
#       <td id="T_2a1a5_row2_col8" class="data row2 col8" >215000.000000</td>
#       <td id="T_2a1a5_row2_col9" class="data row2 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2a1a5_level0_row3" class="row_heading level0 row3" >productionDate</th>
#       <td id="T_2a1a5_row3_col0" class="data row3 col0" >69</td>
#       <td id="T_2a1a5_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_2a1a5_row3_col2" class="data row3 col2" >34686.000000</td>
#       <td id="T_2a1a5_row3_col3" class="data row3 col3" >2009.264602</td>
#       <td id="T_2a1a5_row3_col4" class="data row3 col4" >7.047661</td>
#       <td id="T_2a1a5_row3_col5" class="data row3 col5" >1904.000000</td>
#       <td id="T_2a1a5_row3_col6" class="data row3 col6" >2006.000000</td>
#       <td id="T_2a1a5_row3_col7" class="data row3 col7" >2011.000000</td>
#       <td id="T_2a1a5_row3_col8" class="data row3 col8" >2014.000000</td>
#       <td id="T_2a1a5_row3_col9" class="data row3 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2a1a5_level0_row4" class="row_heading level0 row4" >modelDate</th>
#       <td id="T_2a1a5_row4_col0" class="data row4 col0" >66</td>
#       <td id="T_2a1a5_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_2a1a5_row4_col2" class="data row4 col2" >34686.000000</td>
#       <td id="T_2a1a5_row4_col3" class="data row4 col3" >2007.074728</td>
#       <td id="T_2a1a5_row4_col4" class="data row4 col4" >7.415894</td>
#       <td id="T_2a1a5_row4_col5" class="data row4 col5" >1904.000000</td>
#       <td id="T_2a1a5_row4_col6" class="data row4 col6" >2004.000000</td>
#       <td id="T_2a1a5_row4_col7" class="data row4 col7" >2008.000000</td>
#       <td id="T_2a1a5_row4_col8" class="data row4 col8" >2012.000000</td>
#       <td id="T_2a1a5_row4_col9" class="data row4 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2a1a5_level0_row5" class="row_heading level0 row5" >numberOfDoors</th>
#       <td id="T_2a1a5_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_2a1a5_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_2a1a5_row5_col2" class="data row5 col2" >34686.000000</td>
#       <td id="T_2a1a5_row5_col3" class="data row5 col3" >4.450816</td>
#       <td id="T_2a1a5_row5_col4" class="data row5 col4" >0.703040</td>
#       <td id="T_2a1a5_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_2a1a5_row5_col6" class="data row5 col6" >4.000000</td>
#       <td id="T_2a1a5_row5_col7" class="data row5 col7" >5.000000</td>
#       <td id="T_2a1a5_row5_col8" class="data row5 col8" >5.000000</td>
#       <td id="T_2a1a5_row5_col9" class="data row5 col9" >5.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
train.select_dtypes("object").shape, test.select_dtypes("object").shape
# Out:
# ((130201, 26), (34686, 26))

# %%
train.select_dtypes("object").describe().T.sort_values("unique", ascending=False)
# Out:
#                        count unique  \
# super_gen             130135  43825
# image                 130065  42933
# car_url               129969  40721
# description           129988  35274
# equipment_dict        129969  31190
# complectation_dict    105267   2348
# name                  130153   2283
# region                103034   1335
# date_added            103034    939
# vehicleConfiguration  129987    564
# model_name            103034    514
# enginePower           129988    307
# Владение               14286    261
# engineDisplacement    129988     52
# bodyType              129986     21
# color                 129988     16
# brand                 129988     12
# fuelType              129986      5
# vehicleTransmission   129986      4
# Владельцы             103034      3
# Привод                103032      3
# ПТС                   103034      2
# Руль                  103033      2
# priceCurrency         130153      2
# Состояние             103032      1
# Таможня               103030      1
#
#                                                                     top  \
# super_gen             {'sale-data-attributes': {'asciiCat': 'cars', ...
# image                 https://avatars.mds.yandex.net/get-autoru-vos/...
# car_url               https://auto.ru/cars/new/group/toyota/rav_4/21...
# description           Официальный дилер Mercedes Benz ООО РОЛЬФ фили...
# equipment_dict                                                       {}
# complectation_dict    ['cruise-control', 'multi-wheel', 'airbag-pass...
# name                                      Nissan X-Trail III Рестайлинг
# region                                                         в Москве
# date_added                                                  25 сентября
# vehicleConfiguration                      ALLROAD_5_DOORS AUTOMATIC 3.0
# model_name                                                       Tiguan
# enginePower                                                     249 N12
# Владение                                              3 года и 2 месяца
# engineDisplacement                                              2.0 LTR
# bodyType                                              внедорожник 5 дв.
# color                                                            чёрный
# brand                                                            TOYOTA
# fuelType                                                         бензин
# vehicleTransmission                                      автоматическая
# Владельцы                                                    1 владелец
# Привод                                                           полный
# ПТС                                                            Оригинал
# Руль                                                              Левый
# priceCurrency                                                       RUB
# Состояние                                            Не требует ремонта
# Таможня                                                      Растаможен
#
#                         freq
# super_gen                235
# image                    241
# car_url                  428
# description             3230
# equipment_dict          8214
# complectation_dict      1979
# name                    4013
# region                 39180
# date_added             44873
# vehicleConfiguration   10895
# model_name              4592
# enginePower            14262
# Владение                 646
# engineDisplacement     36933
# bodyType               75068
# color                  42216
# brand                  20117
# fuelType              100407
# vehicleTransmission    73836
# Владельцы              40576
# Привод                 58563
# ПТС                    92587
# Руль                   99356
# priceCurrency         129969
# Состояние             103032
# Таможня               103030

# %%
test.select_dtypes("object").describe().T.sort_values("unique", ascending=False)
# Out:
#                       count unique  \
# car_url               34686  34686
# image                 34686  34557
# description           34686  31732
# equipment_dict        24690  23705
# super_gen             34686   5890
# name                  34686   2780
# complectation_dict     6418   2364
# model_info            34686    954
# vehicleConfiguration  34686    634
# model_name            34686    544
# enginePower           34686    315
# Владение              11995    275
# engineDisplacement    34686     55
# bodyType              34686     24
# color                 34686     16
# brand                 34686     12
# fuelType              34686      5
# vehicleTransmission   34686      4
# Владельцы             34686      3
# Привод                34686      3
# vendor                34686      2
# ПТС                   34685      2
# Руль                  34686      2
# priceCurrency         34686      1
# Состояние             34686      1
# Таможня               34686      1
#
#                                                                     top   freq
# car_url               https://auto.ru/cars/used/sale/skoda/octavia/1...      1
# image                 https://avatars.mds.yandex.net/get-verba/21620...     13
# description           Выгода до 82 000 руб. при обмене на Ваш автомо...    264
# equipment_dict                                         {"leather":true}    108
# super_gen             {"id":"6214876","displacement":1598,"engine_ty...    193
# name                                                  1.6 AT (110 л.с.)    631
# complectation_dict    {"id":"4562904","name":"Elegance","available_o...     51
# model_info            {"code":"OCTAVIA","name":"Octavia","ru_name":"...   1404
# vehicleConfiguration                      ALLROAD_5_DOORS AUTOMATIC 3.0   2389
# model_name                                                      OCTAVIA   1418
# enginePower                                                     249 N12   1708
# Владение                                             1 год и 10 месяцев    209
# engineDisplacement                                              2.0 LTR   7391
# bodyType                                                          седан  13147
# color                                                            чёрный  11010
# brand                                                               BMW   4473
# fuelType                                                         бензин  28601
# vehicleTransmission                                      автоматическая  19596
# Владельцы                                                   3 или более  15957
# Привод                                                         передний  15565
# vendor                                                         EUROPEAN  20682
# ПТС                                                            Оригинал  30098
# Руль                                                              Левый  33287
# priceCurrency                                                       RUB  34686
# Состояние                                            Не требует ремонта  34686
# Таможня                                                      Растаможен  34686

# %%
print(
    "unique object cols in train:",
    set(train.select_dtypes("object").columns.tolist())
    - set(test.select_dtypes("object").columns.tolist()),
    "\nunique object cols in test:",
    set(test.select_dtypes("object").columns.tolist())
    - set(train.select_dtypes("object").columns.tolist()),
)
# Out:
# unique object cols in train: {'date_added', 'region'}
# unique object cols in test: {'vendor', 'model_info'}

# %% [markdown]
# ## making train and test similar

# %%
train["model_name"] = train.model_name.apply(lambda x: str(x).lower())
test["model_name"] = test.model_name.apply(lambda x: str(x).lower())

# %%
vendor_voc = test[["brand", "vendor"]].drop_duplicates().set_index("brand").to_dict()["vendor"]
vendor_voc
# Out:
# {'SKODA': 'EUROPEAN',
#  'AUDI': 'EUROPEAN',
#  'HONDA': 'JAPANESE',
#  'VOLVO': 'EUROPEAN',
#  'BMW': 'EUROPEAN',
#  'NISSAN': 'JAPANESE',
#  'INFINITI': 'JAPANESE',
#  'MERCEDES': 'EUROPEAN',
#  'TOYOTA': 'JAPANESE',
#  'LEXUS': 'JAPANESE',
#  'VOLKSWAGEN': 'EUROPEAN',
#  'MITSUBISHI': 'JAPANESE'}

# %%
train.brand.unique().tolist()
# Out:
# ['SKODA',
#  nan,
#  'AUDI',
#  'HONDA',
#  'VOLVO',
#  'BMW',
#  'NISSAN',
#  'INFINITI',
#  'MERCEDES',
#  'TOYOTA',
#  'LEXUS',
#  'VOLKSWAGEN',
#  'MITSUBISHI']

# %%
train["vendor"] = train["brand"].map(vendor_voc)
train.vendor.unique().tolist()
# Out:
# ['EUROPEAN', nan, 'JAPANESE']

# %%
print(len(train.loc[train.vendor.isna()]["model_name"].unique().tolist()), "na of", len(train.model_name.unique().tolist()))
# Out:
# 1 na of 514

# %%
train.loc[train.vendor.isna()].shape
# Out:
# (213, 36)

# %%
train.priceCurrency.unique()
# Out:
# array(['RUB', 'RUR', nan], dtype=object)

# %%
del train["priceCurrency"]
del test["priceCurrency"]
del train["model_info"]
del test["model_info"]
del train["views"]
del train["date_added"]
del train["region"]
del train["Состояние"]
del test["Состояние"]
del train["Таможня"]
del test["Таможня"]

# %% [markdown]
# ## view again

# %%
describe_nums(train.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_34df9_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_34df9_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_34df9_row0_col4 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_34df9_row0_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_34df9_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 31.3%, transparent 31.3%);
# }
# #T_34df9_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 67.7%, transparent 67.7%);
# }
# #T_34df9_row1_col4 {
#   background-color: #e43027;
#   color: #f1f1f1;
# }
# #T_34df9_row1_col7 {
#   background-color: #3aba76;
#   color: #f1f1f1;
# }
# #T_34df9_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 11.7%, transparent 11.7%);
# }
# #T_34df9_row2_col3, #T_34df9_row4_col3, #T_34df9_row5_col3, #T_34df9_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_34df9_row2_col4 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_34df9_row2_col7, #T_34df9_row3_col7, #T_34df9_row4_col7, #T_34df9_row5_col7, #T_34df9_row6_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_34df9_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 6.2%, transparent 6.2%);
# }
# #T_34df9_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_34df9_row3_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_34df9_row4_col0, #T_34df9_row5_col0, #T_34df9_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# #T_34df9_row4_col4, #T_34df9_row5_col4, #T_34df9_row6_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_34df9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34df9_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_34df9_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_34df9_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_34df9_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_34df9_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_34df9_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_34df9_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_34df9_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_34df9_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_34df9_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34df9_level0_row0" class="row_heading level0 row0" >parsing_unixtime</th>
#       <td id="T_34df9_row0_col0" class="data row0 col0" >130154</td>
#       <td id="T_34df9_row0_col1" class="data row0 col1" >47</td>
#       <td id="T_34df9_row0_col2" class="data row0 col2" >130154.000000</td>
#       <td id="T_34df9_row0_col3" class="data row0 col3" >1632842487.144867</td>
#       <td id="T_34df9_row0_col4" class="data row0 col4" >131636.029755</td>
#       <td id="T_34df9_row0_col5" class="data row0 col5" >1632613481.000000</td>
#       <td id="T_34df9_row0_col6" class="data row0 col6" >1632724602.500000</td>
#       <td id="T_34df9_row0_col7" class="data row0 col7" >1632820776.000000</td>
#       <td id="T_34df9_row0_col8" class="data row0 col8" >1632972687.500000</td>
#       <td id="T_34df9_row0_col9" class="data row0 col9" >1633049056.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34df9_level0_row1" class="row_heading level0 row1" >sell_id</th>
#       <td id="T_34df9_row1_col0" class="data row1 col0" >40721</td>
#       <td id="T_34df9_row1_col1" class="data row1 col1" >232</td>
#       <td id="T_34df9_row1_col2" class="data row1 col2" >129969.000000</td>
#       <td id="T_34df9_row1_col3" class="data row1 col3" >1104865960.875278</td>
#       <td id="T_34df9_row1_col4" class="data row1 col4" >1779786.356124</td>
#       <td id="T_34df9_row1_col5" class="data row1 col5" >1003139396.000000</td>
#       <td id="T_34df9_row1_col6" class="data row1 col6" >1104900484.000000</td>
#       <td id="T_34df9_row1_col7" class="data row1 col7" >1105218565.000000</td>
#       <td id="T_34df9_row1_col8" class="data row1 col8" >1105376150.000000</td>
#       <td id="T_34df9_row1_col9" class="data row1 col9" >1105402618.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34df9_level0_row2" class="row_heading level0 row2" >mileage</th>
#       <td id="T_34df9_row2_col0" class="data row2 col0" >15181</td>
#       <td id="T_34df9_row2_col1" class="data row2 col1" >27167</td>
#       <td id="T_34df9_row2_col2" class="data row2 col2" >103034.000000</td>
#       <td id="T_34df9_row2_col3" class="data row2 col3" >116610.915407</td>
#       <td id="T_34df9_row2_col4" class="data row2 col4" >85154.492046</td>
#       <td id="T_34df9_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_34df9_row2_col6" class="data row2 col6" >51000.000000</td>
#       <td id="T_34df9_row2_col7" class="data row2 col7" >100000.000000</td>
#       <td id="T_34df9_row2_col8" class="data row2 col8" >161000.000000</td>
#       <td id="T_34df9_row2_col9" class="data row2 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34df9_level0_row3" class="row_heading level0 row3" >price</th>
#       <td id="T_34df9_row3_col0" class="data row3 col0" >8105</td>
#       <td id="T_34df9_row3_col1" class="data row3 col1" >20436</td>
#       <td id="T_34df9_row3_col2" class="data row3 col2" >109765.000000</td>
#       <td id="T_34df9_row3_col3" class="data row3 col3" >2801223.260639</td>
#       <td id="T_34df9_row3_col4" class="data row3 col4" >2689068.150068</td>
#       <td id="T_34df9_row3_col5" class="data row3 col5" >23000.000000</td>
#       <td id="T_34df9_row3_col6" class="data row3 col6" >1000000.000000</td>
#       <td id="T_34df9_row3_col7" class="data row3 col7" >2045000.000000</td>
#       <td id="T_34df9_row3_col8" class="data row3 col8" >3649000.000000</td>
#       <td id="T_34df9_row3_col9" class="data row3 col9" >39990000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34df9_level0_row4" class="row_heading level0 row4" >modelDate</th>
#       <td id="T_34df9_row4_col0" class="data row4 col0" >53</td>
#       <td id="T_34df9_row4_col1" class="data row4 col1" >215</td>
#       <td id="T_34df9_row4_col2" class="data row4 col2" >129986.000000</td>
#       <td id="T_34df9_row4_col3" class="data row4 col3" >2012.934578</td>
#       <td id="T_34df9_row4_col4" class="data row4 col4" >6.017749</td>
#       <td id="T_34df9_row4_col5" class="data row4 col5" >1938.000000</td>
#       <td id="T_34df9_row4_col6" class="data row4 col6" >2010.000000</td>
#       <td id="T_34df9_row4_col7" class="data row4 col7" >2014.000000</td>
#       <td id="T_34df9_row4_col8" class="data row4 col8" >2017.000000</td>
#       <td id="T_34df9_row4_col9" class="data row4 col9" >2021.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34df9_level0_row5" class="row_heading level0 row5" >productionDate</th>
#       <td id="T_34df9_row5_col0" class="data row5 col0" >50</td>
#       <td id="T_34df9_row5_col1" class="data row5 col1" >213</td>
#       <td id="T_34df9_row5_col2" class="data row5 col2" >129988.000000</td>
#       <td id="T_34df9_row5_col3" class="data row5 col3" >2015.083854</td>
#       <td id="T_34df9_row5_col4" class="data row5 col4" >5.929774</td>
#       <td id="T_34df9_row5_col5" class="data row5 col5" >1952.000000</td>
#       <td id="T_34df9_row5_col6" class="data row5 col6" >2012.000000</td>
#       <td id="T_34df9_row5_col7" class="data row5 col7" >2016.000000</td>
#       <td id="T_34df9_row5_col8" class="data row5 col8" >2020.000000</td>
#       <td id="T_34df9_row5_col9" class="data row5 col9" >2021.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34df9_level0_row6" class="row_heading level0 row6" >numberOfDoors</th>
#       <td id="T_34df9_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_34df9_row6_col1" class="data row6 col1

# %%
describe_nums(test.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_ad08e_row0_col0, #T_ad08e_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_ad08e_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_ad08e_row0_col4, #T_ad08e_row2_col4 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_ad08e_row0_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_ad08e_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.5%, transparent 68.5%);
# }
# #T_ad08e_row1_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_ad08e_row1_col7 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_ad08e_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 32.5%, transparent 32.5%);
# }
# #T_ad08e_row2_col3, #T_ad08e_row3_col3, #T_ad08e_row4_col3, #T_ad08e_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_ad08e_row2_col7, #T_ad08e_row3_col7, #T_ad08e_row4_col7, #T_ad08e_row5_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_ad08e_row3_col0, #T_ad08e_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.2%, transparent 0.2%);
# }
# #T_ad08e_row3_col4, #T_ad08e_row4_col4, #T_ad08e_row5_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_ad08e_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_ad08e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad08e_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_ad08e_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_ad08e_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_ad08e_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_ad08e_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_ad08e_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_ad08e_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_ad08e_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_ad08e_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_ad08e_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad08e_level0_row0" class="row_heading level0 row0" >parsing_unixtime</th>
#       <td id="T_ad08e_row0_col0" class="data row0 col0" >34686</td>
#       <td id="T_ad08e_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_ad08e_row0_col2" class="data row0 col2" >34686.000000</td>
#       <td id="T_ad08e_row0_col3" class="data row0 col3" >1603286733.619356</td>
#       <td id="T_ad08e_row0_col4" class="data row0 col4" >149307.058483</td>
#       <td id="T_ad08e_row0_col5" class="data row0 col5" >1603107306.000000</td>
#       <td id="T_ad08e_row0_col6" class="data row0 col6" >1603221157.750000</td>
#       <td id="T_ad08e_row0_col7" class="data row0 col7" >1603254133.000000</td>
#       <td id="T_ad08e_row0_col8" class="data row0 col8" >1603290080.250000</td>
#       <td id="T_ad08e_row0_col9" class="data row0 col9" >1603710264.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ad08e_level0_row1" class="row_heading level0 row1" >sell_id</th>
#       <td id="T_ad08e_row1_col0" class="data row1 col0" >34686</td>
#       <td id="T_ad08e_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_ad08e_row1_col2" class="data row1 col2" >34686.000000</td>
#       <td id="T_ad08e_row1_col3" class="data row1 col3" >1098300150.880644</td>
#       <td id="T_ad08e_row1_col4" class="data row1 col4" >19112247.594511</td>
#       <td id="T_ad08e_row1_col5" class="data row1 col5" >2665.000000</td>
#       <td id="T_ad08e_row1_col6" class="data row1 col6" >1099048798.000000</td>
#       <td id="T_ad08e_row1_col7" class="data row1 col7" >1100910913.000000</td>
#       <td id="T_ad08e_row1_col8" class="data row1 col8" >1101245023.750000</td>
#       <td id="T_ad08e_row1_col9" class="data row1 col9" >1101374610.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ad08e_level0_row2" class="row_heading level0 row2" >mileage</th>
#       <td id="T_ad08e_row2_col0" class="data row2 col0" >11268</td>
#       <td id="T_ad08e_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_ad08e_row2_col2" class="data row2 col2" >34686.000000</td>
#       <td id="T_ad08e_row2_col3" class="data row2 col3" >162009.767889</td>
#       <td id="T_ad08e_row2_col4" class="data row2 col4" >100676.559489</td>
#       <td id="T_ad08e_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_ad08e_row2_col6" class="data row2 col6" >91153.500000</td>
#       <td id="T_ad08e_row2_col7" class="data row2 col7" >149779.500000</td>
#       <td id="T_ad08e_row2_col8" class="data row2 col8" >215000.000000</td>
#       <td id="T_ad08e_row2_col9" class="data row2 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ad08e_level0_row3" class="row_heading level0 row3" >productionDate</th>
#       <td id="T_ad08e_row3_col0" class="data row3 col0" >69</td>
#       <td id="T_ad08e_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_ad08e_row3_col2" class="data row3 col2" >34686.000000</td>
#       <td id="T_ad08e_row3_col3" class="data row3 col3" >2009.264602</td>
#       <td id="T_ad08e_row3_col4" class="data row3 col4" >7.047661</td>
#       <td id="T_ad08e_row3_col5" class="data row3 col5" >1904.000000</td>
#       <td id="T_ad08e_row3_col6" class="data row3 col6" >2006.000000</td>
#       <td id="T_ad08e_row3_col7" class="data row3 col7" >2011.000000</td>
#       <td id="T_ad08e_row3_col8" class="data row3 col8" >2014.000000</td>
#       <td id="T_ad08e_row3_col9" class="data row3 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ad08e_level0_row4" class="row_heading level0 row4" >modelDate</th>
#       <td id="T_ad08e_row4_col0" class="data row4 col0" >66</td>
#       <td id="T_ad08e_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_ad08e_row4_col2" class="data row4 col2" >34686.000000</td>
#       <td id="T_ad08e_row4_col3" class="data row4 col3" >2007.074728</td>
#       <td id="T_ad08e_row4_col4" class="data row4 col4" >7.415894</td>
#       <td id="T_ad08e_row4_col5" class="data row4 col5" >1904.000000</td>
#       <td id="T_ad08e_row4_col6" class="data row4 col6" >2004.000000</td>
#       <td id="T_ad08e_row4_col7" class="data row4 col7" >2008.000000</td>
#       <td id="T_ad08e_row4_col8" class="data row4 col8" >2012.000000</td>
#       <td id="T_ad08e_row4_col9" class="data row4 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ad08e_level0_row5" class="row_heading level0 row5" >numberOfDoors</th>
#       <td id="T_ad08e_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_ad08e_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_ad08e_row5_col2" class="data row5 col2" >34686.000000</td>
#       <td id="T_ad08e_row5_col3" class="data row5 col3" >4.450816</td>
#       <td id="T_ad08e_row5_col4" class="data row5 col4" >0.703040</td>
#       <td id="T_ad08e_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_ad08e_row5_col6" class="data row5 col6" >4.000000</td>
#       <td id="T_ad08e_row5_col7" class="data row5 col7" >5.000000</td>
#       <td id="T_ad08e_row5_col8" class="data row5 col8" >5.000000</td>
#       <td id="T_ad08e_row5_col9" class="data row5 col9" >5.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
train.select_dtypes("object").shape, test.select_dtypes("object").shape
# Out:
# ((130201, 22), (34686, 22))

# %%
train.select_dtypes("object").describe().T.sort_values("unique", ascending=False)
# Out:
#                        count unique  \
# super_gen             130135  43825
# image                 130065  42933
# car_url               129969  40721
# description           129988  35274
# equipment_dict        129969  31190
# complectation_dict    105267   2348
# name                  130153   2283
# vehicleConfiguration  129987    564
# model_name            130201    514
# enginePower           129988    307
# Владение               14286    261
# engineDisplacement    129988     52
# bodyType              129986     21
# color                 129988     16
# brand                 129988     12
# fuelType              129986      5
# vehicleTransmission   129986      4
# Владельцы             103034      3
# Привод                103032      3
# vendor                129988      2
# ПТС                   103034      2
# Руль                  103033      2
#
#                                                                     top  \
# super_gen             {'sale-data-attributes': {'asciiCat': 'cars', ...
# image                 https://avatars.mds.yandex.net/get-autoru-vos/...
# car_url               https://auto.ru/cars/new/group/toyota/rav_4/21...
# description           Официальный дилер Mercedes Benz ООО РОЛЬФ фили...
# equipment_dict                                                       {}
# complectation_dict    ['cruise-control', 'multi-wheel', 'airbag-pass...
# name                                      Nissan X-Trail III Рестайлинг
# vehicleConfiguration                      ALLROAD_5_DOORS AUTOMATIC 3.0
# model_name                                                          nan
# enginePower                                                     249 N12
# Владение                                              3 года и 2 месяца
# engineDisplacement                                              2.0 LTR
# bodyType                                              внедорожник 5 дв.
# color                                                            чёрный
# brand                                                            TOYOTA
# fuelType                                                         бензин
# vehicleTransmission                                      автоматическая
# Владельцы                                                    1 владелец
# Привод                                                           полный
# vendor                                                         EUROPEAN
# ПТС                                                            Оригинал
# Руль                                                              Левый
#
#                         freq
# super_gen                235
# image                    241
# car_url                  428
# description             3230
# equipment_dict          8214
# complectation_dict      1979
# name                    4013
# vehicleConfiguration   10895
# model_name             27167
# enginePower            14262
# Владение                 646
# engineDisplacement     36933
# bodyType               75068
# color                  42216
# brand                  20117
# fuelType              100407
# vehicleTransmission    73836
# Владельцы              40576
# Привод                 58563
# vendor                 72959
# ПТС                    92587
# Руль                   99356

# %%
test.select_dtypes("object").describe().T.sort_values("unique", ascending=False)
# Out:
#                       count unique  \
# car_url               34686  34686
# image                 34686  34557
# description           34686  31732
# equipment_dict        24690  23705
# super_gen             34686   5890
# name                  34686   2780
# complectation_dict     6418   2364
# vehicleConfiguration  34686    634
# model_name            34686    544
# enginePower           34686    315
# Владение              11995    275
# engineDisplacement    34686     55
# bodyType              34686     24
# color                 34686     16
# brand                 34686     12
# fuelType              34686      5
# vehicleTransmission   34686      4
# Владельцы             34686      3
# Привод                34686      3
# vendor                34686      2
# ПТС                   34685      2
# Руль                  34686      2
#
#                                                                     top   freq
# car_url               https://auto.ru/cars/used/sale/skoda/octavia/1...      1
# image                 https://avatars.mds.yandex.net/get-verba/21620...     13
# description           Выгода до 82 000 руб. при обмене на Ваш автомо...    264
# equipment_dict                                         {"leather":true}    108
# super_gen             {"id":"6214876","displacement":1598,"engine_ty...    193
# name                                                  1.6 AT (110 л.с.)    631
# complectation_dict    {"id":"4562904","name":"Elegance","available_o...     51
# vehicleConfiguration                      ALLROAD_5_DOORS AUTOMATIC 3.0   2389
# model_name                                                      octavia   1418
# enginePower                                                     249 N12   1708
# Владение                                             1 год и 10 месяцев    209
# engineDisplacement                                              2.0 LTR   7391
# bodyType                                                          седан  13147
# color                                                            чёрный  11010
# brand                                                               BMW   4473
# fuelType                                                         бензин  28601
# vehicleTransmission                                      автоматическая  19596
# Владельцы                                                   3 или более  15957
# Привод                                                         передний  15565
# vendor                                                         EUROPEAN  20682
# ПТС                                                            Оригинал  30098
# Руль                                                              Левый  33287

# %%
train.shape, test.shape
# Out:
# ((130201, 29), (34686, 28))

# %% [markdown]
# ## conclusion
#
# $y = price$ - take a log
#
# - **car_url** - why we have different rows with the same url for train?
# - **image** - maybe same images with different urls indicate fraud?
# - **description** - to tokenize
# - **equipment_dict** - deserialize, expand as additional cols
# - **complectation_dict** - deserialize, expand as additional cols
# - **name** - to check intersection train vs test
# - **vehicleConfiguration** - view and maybe split to several features if splittable
# - **engineDisplacement** - convert to float
# - **enginePower** - convert to integer
# - **Владельцы** - convert to integer
# - **Владение** - calculate number of days
# - **model_name** - check NAs, compare with **name** - maybe keep only one?
# - **vendor** - check NAs
# - **bodyType**, **color**, **brand**, **fuelType**, **vehicleTransmission**, **Привод**, **ПТС**, **Руль** - _temporary keep as is_
#
# Numerics - fill na, log if tailed, standartize
