# %% [markdown]
# ## imports

# %%
from datetime import datetime
import re
import json

import pandas as pd
import numpy as np

from lib.data_viz_functions import *

# %%
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 100)

# %% [markdown]
# ## reading data from disk

# %%
train_jane = pd.read_pickle("data/train_df_full_part1.pkl.zip", compression="zip")
train_baseline = pd.read_pickle(
    "data/all_auto_ru_09_09_2020.pkl.zip", compression="zip"
)
test = pd.read_pickle("data/test.pkl.zip", compression="zip")

train_jane.shape, train_baseline.shape, test.shape
# Out:
# ((130201, 36), (89378, 26), (34686, 32))

# %% [markdown]
# ## preprocessing functions

# %%
def parse_ownership_duration(train_str: str) -> float:

    """
    Returns ownership duration in days
    """

    baseline_str = "{'year': 2020, 'month': 9}"

    if not isinstance(train_str, str):
        return np.nan
    elif "year" in str(train_str):
        baseline_dict = json.loads(baseline_str.replace("'", '"'))
        train_dict = json.loads(train_str.replace("'", '"'))

        baseline_date = datetime.strptime(
            f"{baseline_dict['year']}-{baseline_dict['month']}-1", "%Y-%m-%d"
        )
        train_date = datetime.strptime(
            f"{train_dict['year']}-{train_dict['month']}-1", "%Y-%m-%d"
        )
        return (baseline_date - train_date).days
    elif " и " in str(train_str):
        return (
            int(train_str.split(" ")[0]) * 365
            + int(train_str.split(" и ")[1].split(" ")[0]) * 30
        )
    else:
        return int(train_str.split(" ")[0]) * 365


def get_number_of_owners_from_owners(in_str):
    if not isinstance(in_str, str):
        return None
    else:
        result = in_str.replace("\xa0", "")
        return int(re.sub("\D", "", result))
    # return string (to cat)


def get_engine_value(in_str):
    parsed_str = re.findall("(\d+.\d+)", in_str)
    if len(parsed_str):
        return float(parsed_str[0])
    else:
        return None


def get_bodytype(body_type):
    if isinstance(body_type, str):
        if "внедорожник 5 дв." in body_type:
            return "внедорожник 5 дв."
        elif "внедорожник 3 дв." in body_type:
            return "внедорожник 3 дв."
        elif "хэтчбек 5 дв." in body_type:
            return "хэтчбек 5 дв."
        elif "хэтчбек 3 дв." in body_type:
            return "хэтчбек 3 дв."
        elif "седан" in body_type:
            return "седан"
        elif "пикап двойная кабина" in body_type:
            return "пикап двойная кабина"
        elif "пикап полуторная кабина" in body_type:
            return "пикап полуторная кабина"
        elif "пикап одинарная кабина" in body_type:
            return "пикап одинарная кабина"
        elif "микровэн" in body_type:
            return "микровэн"
        elif "кабриолет" in body_type:
            return "кабриолет"
        elif "купе" in body_type:
            return "купе"
        elif "лифтбек" in body_type:
            "лифтбек"

        [
            "лифтбек",
            "внедорожник 5 дв.",
            "хэтчбек 5 дв.",
            "седан",
            "компактвэн",
            "универсал 5 дв.",
            "пикап одинарная кабина",
            "хэтчбек 3 дв.",
            "купе",
            "кабриолет",
            "минивэн",
            "пикап двойная кабина",
            "внедорожник 3 дв.",
            "родстер",
            "микровэн",
            "седан 2 дв.",
            "купе-хардтоп",
            "фастбек",
            "тарга",
            "внедорожник открытый",
            "лимузин",
            "пикап полуторная кабина",
            "седан-хардтоп",
            "фургон",
        ]

# %% [markdown]
# ## quick view

# %%
describe_nums(train_jane.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_94624_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_94624_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_94624_row0_col4 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_94624_row0_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_94624_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 31.3%, transparent 31.3%);
# }
# #T_94624_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 67.7%, transparent 67.7%);
# }
# #T_94624_row1_col4 {
#   background-color: #e43027;
#   color: #f1f1f1;
# }
# #T_94624_row1_col7 {
#   background-color: #3aba76;
#   color: #f1f1f1;
# }
# #T_94624_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 11.7%, transparent 11.7%);
# }
# #T_94624_row2_col3, #T_94624_row4_col3, #T_94624_row5_col3, #T_94624_row6_col3, #T_94624_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_94624_row2_col4 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_94624_row2_col7, #T_94624_row3_col7, #T_94624_row4_col7, #T_94624_row5_col7, #T_94624_row6_col7, #T_94624_row7_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_94624_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 6.2%, transparent 6.2%);
# }
# #T_94624_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_94624_row3_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_94624_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 3.5%, transparent 3.5%);
# }
# #T_94624_row4_col4, #T_94624_row5_col4, #T_94624_row6_col4, #T_94624_row7_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_94624_row5_col0, #T_94624_row6_col0, #T_94624_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# #T_94624_row8_col0, #T_94624_row8_col3, #T_94624_row9_col0, #T_94624_row9_col3 {
#   width: 10em;
# }
# #T_94624_row8_col4, #T_94624_row8_col7, #T_94624_row9_col4, #T_94624_row9_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_94624">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94624_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_94624_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_94624_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_94624_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_94624_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_94624_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_94624_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_94624_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_94624_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_94624_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94624_level0_row0" class="row_heading level0 row0" >parsing_unixtime</th>
#       <td id="T_94624_row0_col0" class="data row0 col0" >130154</td>
#       <td id="T_94624_row0_col1" class="data row0 col1" >47</td>
#       <td id="T_94624_row0_col2" class="data row0 col2" >130154.000000</td>
#       <td id="T_94624_row0_col3" class="data row0 col3" >1632842487.144867</td>
#       <td id="T_94624_row0_col4" class="data row0 col4" >131636.029755</td>
#       <td id="T_94624_row0_col5" class="data row0 col5" >1632613481.000000</td>
#       <td id="T_94624_row0_col6" class="data row0 col6" >1632724602.500000</td>
#       <td id="T_94624_row0_col7" class="data row0 col7" >1632820776.000000</td>
#       <td id="T_94624_row0_col8" class="data row0 col8" >1632972687.500000</td>
#       <td id="T_94624_row0_col9" class="data row0 col9" >1633049056.000000</td>
#     </tr>
#     <tr>
#       <th id="T_94624_level0_row1" class="row_heading level0 row1" >sell_id</th>
#       <td id="T_94624_row1_col0" class="data row1 col0" >40721</td>
#       <td id="T_94624_row1_col1" class="data row1 col1" >232</td>
#       <td id="T_94624_row1_col2" class="data row1 col2" >129969.000000</td>
#       <td id="T_94624_row1_col3" class="data row1 col3" >1104865960.875278</td>
#       <td id="T_94624_row1_col4" class="data row1 col4" >1779786.356124</td>
#       <td id="T_94624_row1_col5" class="data row1 col5" >1003139396.000000</td>
#       <td id="T_94624_row1_col6" class="data row1 col6" >1104900484.000000</td>
#       <td id="T_94624_row1_col7" class="data row1 col7" >1105218565.000000</td>
#       <td id="T_94624_row1_col8" class="data row1 col8" >1105376150.000000</td>
#       <td id="T_94624_row1_col9" class="data row1 col9" >1105402618.000000</td>
#     </tr>
#     <tr>
#       <th id="T_94624_level0_row2" class="row_heading level0 row2" >mileage</th>
#       <td id="T_94624_row2_col0" class="data row2 col0" >15181</td>
#       <td id="T_94624_row2_col1" class="data row2 col1" >27167</td>
#       <td id="T_94624_row2_col2" class="data row2 col2" >103034.000000</td>
#       <td id="T_94624_row2_col3" class="data row2 col3" >116610.915407</td>
#       <td id="T_94624_row2_col4" class="data row2 col4" >85154.492046</td>
#       <td id="T_94624_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_94624_row2_col6" class="data row2 col6" >51000.000000</td>
#       <td id="T_94624_row2_col7" class="data row2 col7" >100000.000000</td>
#       <td id="T_94624_row2_col8" class="data row2 col8" >161000.000000</td>
#       <td id="T_94624_row2_col9" class="data row2 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_94624_level0_row3" class="row_heading level0 row3" >price</th>
#       <td id="T_94624_row3_col0" class="data row3 col0" >8105</td>
#       <td id="T_94624_row3_col1" class="data row3 col1" >20436</td>
#       <td id="T_94624_row3_col2" class="data row3 col2" >109765.000000</td>
#       <td id="T_94624_row3_col3" class="data row3 col3" >2801223.260639</td>
#       <td id="T_94624_row3_col4" class="data row3 col4" >2689068.150068</td>
#       <td id="T_94624_row3_col5" class="data row3 col5" >23000.000000</td>
#       <td id="T_94624_row3_col6" class="data row3 col6" >1000000.000000</td>
#       <td id="T_94624_row3_col7" class="data row3 col7" >2045000.000000</td>
#       <td id="T_94624_row3_col8" class="data row3 col8" >3649000.000000</td>
#       <td id="T_94624_row3_col9" class="data row3 col9" >39990000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_94624_level0_row4" class="row_heading level0 row4" >views</th>
#       <td id="T_94624_row4_col0" class="data row4 col0" >4511</td>
#       <td id="T_94624_row4_col1" class="data row4 col1" >28203</td>
#       <td id="T_94624_row4_col2" class="data row4 col2" >101998.000000</td>
#       <td id="T_94624_row4_col3" class="data row4 col3" >564.982284</td>
#       <td id="T_94624_row4_col4" class="data row4 col4" >1814.036025</td>
#       <td id="T_94624_row4_col5" class="data row4 col5" >2.000000</td>
#       <td id="T_94624_row4_col6" class="data row4 col6" >127.000000</td>
#       <td id="T_94624_row4_col7" class="data row4 col7" >245.000000</td>
#       <td id="T_94624_row4_col8" class="data row4 col8" >511.000000</td>
#       <td id="T_94624_row4_col9" class="data row4 col9" >148149.000000</td>
#     </tr>
#     <tr>
#       <th id="T_94624_level0_row5" class="row_heading level0 row5" >modelDate</th>
#       <td id="T_94624_row5_col0" class="data row5 col0" >53</td>
#       <td id="T_94624_row5_col1" class="data row5 col1" >215</td>
#       <td id="T_94624_row5_col2" class="data row5 col2" >129986.000000</td>
#       <td id="T_94624_row5_col3" class="data row5 col3" >2012.934578</td>
#       <td id="T_94624_row5_col4" class="data row5 col4" >6.017749</td>
#       <td id="T_94624_row5_col5" class="data row5 col5" >1938.000000</td>
#       <td id="T_94624_row5_col6" class="data row5 col6" >2010.000000</td>
#       <td id="T_94624_row5_col7" class="data row5 col7"

# %%
describe_nums(train_baseline.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_4810f_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_4810f_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.4%, transparent 10.4%);
# }
# #T_4810f_row0_col4 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_4810f_row0_col7 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_4810f_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 46.9%, transparent 46.9%);
# }
# #T_4810f_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_4810f_row1_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_4810f_row1_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_4810f_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 2.3%, transparent 2.3%);
# }
# #T_4810f_row2_col3, #T_4810f_row5_col3, #T_4810f_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_4810f_row2_col4, #T_4810f_row3_col4, #T_4810f_row4_col4, #T_4810f_row5_col4, #T_4810f_row6_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_4810f_row2_col7, #T_4810f_row3_col7, #T_4810f_row4_col7, #T_4810f_row5_col7, #T_4810f_row6_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_4810f_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.5%, transparent 0.5%);
# }
# #T_4810f_row3_col3, #T_4810f_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_4810f_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.4%, transparent 0.4%);
# }
# #T_4810f_row5_col0, #T_4810f_row6_col0, #T_4810f_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# #T_4810f_row7_col3, #T_4810f_row8_col0, #T_4810f_row8_col3, #T_4810f_row9_col0, #T_4810f_row9_col3 {
#   width: 10em;
# }
# #T_4810f_row7_col4, #T_4810f_row7_col7, #T_4810f_row8_col4, #T_4810f_row8_col7, #T_4810f_row9_col4, #T_4810f_row9_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4810f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4810f_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_4810f_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_4810f_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_4810f_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_4810f_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_4810f_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_4810f_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_4810f_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_4810f_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_4810f_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4810f_level0_row0" class="row_heading level0 row0" >mileage</th>
#       <td id="T_4810f_row0_col0" class="data row0 col0" >17403</td>
#       <td id="T_4810f_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_4810f_row0_col2" class="data row0 col2" >89378.000000</td>
#       <td id="T_4810f_row0_col3" class="data row0 col3" >134828.811497</td>
#       <td id="T_4810f_row0_col4" class="data row0 col4" >102979.784485</td>
#       <td id="T_4810f_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_4810f_row0_col6" class="data row0 col6" >56042.500000</td>
#       <td id="T_4810f_row0_col7" class="data row0 col7" >130000.000000</td>
#       <td id="T_4810f_row0_col8" class="data row0 col8" >194939.750000</td>
#       <td id="T_4810f_row0_col9" class="data row0 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4810f_level0_row1" class="row_heading level0 row1" >price</th>
#       <td id="T_4810f_row1_col0" class="data row1 col0" >8168</td>
#       <td id="T_4810f_row1_col1" class="data row1 col1" >410</td>
#       <td id="T_4810f_row1_col2" class="data row1 col2" >88968.000000</td>
#       <td id="T_4810f_row1_col3" class="data row1 col3" >1294586.356330</td>
#       <td id="T_4810f_row1_col4" class="data row1 col4" >1950410.471999</td>
#       <td id="T_4810f_row1_col5" class="data row1 col5" >16000.000000</td>
#       <td id="T_4810f_row1_col6" class="data row1 col6" >350000.000000</td>
#       <td id="T_4810f_row1_col7" class="data row1 col7" >650000.000000</td>
#       <td id="T_4810f_row1_col8" class="data row1 col8" >1480000.000000</td>
#       <td id="T_4810f_row1_col9" class="data row1 col9" >99000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4810f_level0_row2" class="row_heading level0 row2" >enginePower</th>
#       <td id="T_4810f_row2_col0" class="data row2 col0" >396</td>
#       <td id="T_4810f_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_4810f_row2_col2" class="data row2 col2" >89377.000000</td>
#       <td id="T_4810f_row2_col3" class="data row2 col3" >171.231637</td>
#       <td id="T_4810f_row2_col4" class="data row2 col4" >83.527540</td>
#       <td id="T_4810f_row2_col5" class="data row2 col5" >11.000000</td>
#       <td id="T_4810f_row2_col6" class="data row2 col6" >115.000000</td>
#       <td id="T_4810f_row2_col7" class="data row2 col7" >150.000000</td>
#       <td id="T_4810f_row2_col8" class="data row2 col8" >199.000000</td>
#       <td id="T_4810f_row2_col9" class="data row2 col9" >800.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4810f_level0_row3" class="row_heading level0 row3" >productionDate</th>
#       <td id="T_4810f_row3_col0" class="data row3 col0" >80</td>
#       <td id="T_4810f_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_4810f_row3_col2" class="data row3 col2" >89378.000000</td>
#       <td id="T_4810f_row3_col3" class="data row3 col3" >2010.832531</td>
#       <td id="T_4810f_row3_col4" class="data row3 col4" >7.024776</td>
#       <td id="T_4810f_row3_col5" class="data row3 col5" >1904.000000</td>
#       <td id="T_4810f_row3_col6" class="data row3 col6" >2007.000000</td>
#       <td id="T_4810f_row3_col7" class="data row3 col7" >2011.000000</td>
#       <td id="T_4810f_row3_col8" class="data row3 col8" >2016.000000</td>
#       <td id="T_4810f_row3_col9" class="data row3 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4810f_level0_row4" class="row_heading level0 row4" >modelDate</th>
#       <td id="T_4810f_row4_col0" class="data row4 col0" >78</td>
#       <td id="T_4810f_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_4810f_row4_col2" class="data row4 col2" >89377.000000</td>
#       <td id="T_4810f_row4_col3" class="data row4 col3" >2008.543294</td>
#       <td id="T_4810f_row4_col4" class="data row4 col4" >7.415436</td>
#       <td id="T_4810f_row4_col5" class="data row4 col5" >1904.000000</td>
#       <td id="T_4810f_row4_col6" class="data row4 col6" >2005.000000</td>
#       <td id="T_4810f_row4_col7" class="data row4 col7" >2009.000000</td>
#       <td id="T_4810f_row4_col8" class="data row4 col8" >2014.000000</td>
#       <td id="T_4810f_row4_col9" class="data row4 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4810f_level0_row5" class="row_heading level0 row5" >numberOfDoors</th>
#       <td id="T_4810f_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_4810f_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_4810f_row5_col2" class="data row5 col2" >89377.000000</td>
#       <td id="T_4810f_row5_col3" class="data row5 col3" >4.510467</td>
#       <td id="T_4810f_row5_col4" class="data row5 col4" >0.653203</td>
#       <td id="T_4810f_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_4810f_row5_col6" class="data row5 col6" >4.000000</td>
#       <td id="T_4810f_row5_col7" class="data row5 col7" >5.000000</td>
#       <td id="T_4810f_row5_col8" class="data row5 col8" >5.000000</td>
#       <td id="T_4810f_row5_col9" class="data row5 col9" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4810f_level0_row6" class="

# %%
describe_nums(test.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_fa851_row0_col0, #T_fa851_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_fa851_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_fa851_row0_col4, #T_fa851_row2_col4 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_fa851_row0_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_fa851_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.5%, transparent 68.5%);
# }
# #T_fa851_row1_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_fa851_row1_col7 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_fa851_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 32.5%, transparent 32.5%);
# }
# #T_fa851_row2_col3, #T_fa851_row3_col3, #T_fa851_row4_col3, #T_fa851_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_fa851_row2_col7, #T_fa851_row3_col7, #T_fa851_row4_col7, #T_fa851_row5_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_fa851_row3_col0, #T_fa851_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.2%, transparent 0.2%);
# }
# #T_fa851_row3_col4, #T_fa851_row4_col4, #T_fa851_row5_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_fa851_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_fa851">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa851_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_fa851_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_fa851_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_fa851_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_fa851_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_fa851_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_fa851_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_fa851_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_fa851_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_fa851_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa851_level0_row0" class="row_heading level0 row0" >parsing_unixtime</th>
#       <td id="T_fa851_row0_col0" class="data row0 col0" >34686</td>
#       <td id="T_fa851_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_fa851_row0_col2" class="data row0 col2" >34686.000000</td>
#       <td id="T_fa851_row0_col3" class="data row0 col3" >1603286733.619356</td>
#       <td id="T_fa851_row0_col4" class="data row0 col4" >149307.058483</td>
#       <td id="T_fa851_row0_col5" class="data row0 col5" >1603107306.000000</td>
#       <td id="T_fa851_row0_col6" class="data row0 col6" >1603221157.750000</td>
#       <td id="T_fa851_row0_col7" class="data row0 col7" >1603254133.000000</td>
#       <td id="T_fa851_row0_col8" class="data row0 col8" >1603290080.250000</td>
#       <td id="T_fa851_row0_col9" class="data row0 col9" >1603710264.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fa851_level0_row1" class="row_heading level0 row1" >sell_id</th>
#       <td id="T_fa851_row1_col0" class="data row1 col0" >34686</td>
#       <td id="T_fa851_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_fa851_row1_col2" class="data row1 col2" >34686.000000</td>
#       <td id="T_fa851_row1_col3" class="data row1 col3" >1098300150.880644</td>
#       <td id="T_fa851_row1_col4" class="data row1 col4" >19112247.594511</td>
#       <td id="T_fa851_row1_col5" class="data row1 col5" >2665.000000</td>
#       <td id="T_fa851_row1_col6" class="data row1 col6" >1099048798.000000</td>
#       <td id="T_fa851_row1_col7" class="data row1 col7" >1100910913.000000</td>
#       <td id="T_fa851_row1_col8" class="data row1 col8" >1101245023.750000</td>
#       <td id="T_fa851_row1_col9" class="data row1 col9" >1101374610.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fa851_level0_row2" class="row_heading level0 row2" >mileage</th>
#       <td id="T_fa851_row2_col0" class="data row2 col0" >11268</td>
#       <td id="T_fa851_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_fa851_row2_col2" class="data row2 col2" >34686.000000</td>
#       <td id="T_fa851_row2_col3" class="data row2 col3" >162009.767889</td>
#       <td id="T_fa851_row2_col4" class="data row2 col4" >100676.559489</td>
#       <td id="T_fa851_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_fa851_row2_col6" class="data row2 col6" >91153.500000</td>
#       <td id="T_fa851_row2_col7" class="data row2 col7" >149779.500000</td>
#       <td id="T_fa851_row2_col8" class="data row2 col8" >215000.000000</td>
#       <td id="T_fa851_row2_col9" class="data row2 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fa851_level0_row3" class="row_heading level0 row3" >productionDate</th>
#       <td id="T_fa851_row3_col0" class="data row3 col0" >69</td>
#       <td id="T_fa851_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_fa851_row3_col2" class="data row3 col2" >34686.000000</td>
#       <td id="T_fa851_row3_col3" class="data row3 col3" >2009.264602</td>
#       <td id="T_fa851_row3_col4" class="data row3 col4" >7.047661</td>
#       <td id="T_fa851_row3_col5" class="data row3 col5" >1904.000000</td>
#       <td id="T_fa851_row3_col6" class="data row3 col6" >2006.000000</td>
#       <td id="T_fa851_row3_col7" class="data row3 col7" >2011.000000</td>
#       <td id="T_fa851_row3_col8" class="data row3 col8" >2014.000000</td>
#       <td id="T_fa851_row3_col9" class="data row3 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fa851_level0_row4" class="row_heading level0 row4" >modelDate</th>
#       <td id="T_fa851_row4_col0" class="data row4 col0" >66</td>
#       <td id="T_fa851_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_fa851_row4_col2" class="data row4 col2" >34686.000000</td>
#       <td id="T_fa851_row4_col3" class="data row4 col3" >2007.074728</td>
#       <td id="T_fa851_row4_col4" class="data row4 col4" >7.415894</td>
#       <td id="T_fa851_row4_col5" class="data row4 col5" >1904.000000</td>
#       <td id="T_fa851_row4_col6" class="data row4 col6" >2004.000000</td>
#       <td id="T_fa851_row4_col7" class="data row4 col7" >2008.000000</td>
#       <td id="T_fa851_row4_col8" class="data row4 col8" >2012.000000</td>
#       <td id="T_fa851_row4_col9" class="data row4 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fa851_level0_row5" class="row_heading level0 row5" >numberOfDoors</th>
#       <td id="T_fa851_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_fa851_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_fa851_row5_col2" class="data row5 col2" >34686.000000</td>
#       <td id="T_fa851_row5_col3" class="data row5 col3" >4.450816</td>
#       <td id="T_fa851_row5_col4" class="data row5 col4" >0.703040</td>
#       <td id="T_fa851_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_fa851_row5_col6" class="data row5 col6" >4.000000</td>
#       <td id="T_fa851_row5_col7" class="data row5 col7" >5.000000</td>
#       <td id="T_fa851_row5_col8" class="data row5 col8" >5.000000</td>
#       <td id="T_fa851_row5_col9" class="data row5 col9" >5.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_jane.select_dtypes("object").shape, train_baseline.select_dtypes(
    "object"
).shape, test.select_dtypes("object").shape
# Out:
# ((130201, 26), (89378, 16), (34686, 26))

# %%
train_jane.select_dtypes("object").describe().T.sort_values("unique", ascending=False)
# Out:
#                        count unique  \
# super_gen             130135  43825
# image                 130065  42933
# car_url               129969  40721
# description           129988  35274
# equipment_dict        129969  31190
# complectation_dict    105267   2348
# name                  130153   2283
# region                103034   1335
# date_added            103034    939
# vehicleConfiguration  129987    564
# model_name            103034    514
# enginePower           129988    307
# Владение               14286    261
# engineDisplacement    129988     52
# bodyType              129986     21
# color                 129988     16
# brand                 129988     12
# fuelType              129986      5
# vehicleTransmission   129986      4
# Владельцы             103034      3
# Привод                103032      3
# ПТС                   103034      2
# Руль                  103033      2
# priceCurrency         130153      2
# Состояние             103032      1
# Таможня               103030      1
#
#                                                                     top  \
# super_gen             {'sale-data-attributes': {'asciiCat': 'cars', ...
# image                 https://avatars.mds.yandex.net/get-autoru-vos/...
# car_url               https://auto.ru/cars/new/group/toyota/rav_4/21...
# description           Официальный дилер Mercedes Benz ООО РОЛЬФ фили...
# equipment_dict                                                       {}
# complectation_dict    ['cruise-control', 'multi-wheel', 'airbag-pass...
# name                                      Nissan X-Trail III Рестайлинг
# region                                                         в Москве
# date_added                                                  25 сентября
# vehicleConfiguration                      ALLROAD_5_DOORS AUTOMATIC 3.0
# model_name                                                       Tiguan
# enginePower                                                     249 N12
# Владение                                              3 года и 2 месяца
# engineDisplacement                                              2.0 LTR
# bodyType                                              внедорожник 5 дв.
# color                                                            чёрный
# brand                                                            TOYOTA
# fuelType                                                         бензин
# vehicleTransmission                                      автоматическая
# Владельцы                                                    1 владелец
# Привод                                                           полный
# ПТС                                                            Оригинал
# Руль                                                              Левый
# priceCurrency                                                       RUB
# Состояние                                            Не требует ремонта
# Таможня                                                      Растаможен
#
#                         freq
# super_gen                235
# image                    241
# car_url                  428
# description             3230
# equipment_dict          8214
# complectation_dict      1979
# name                    4013
# region                 39180
# date_added             44873
# vehicleConfiguration   10895
# model_name              4592
# enginePower            14262
# Владение                 646
# engineDisplacement     36933
# bodyType               75068
# color                  42216
# brand                  20117
# fuelType              100407
# vehicleTransmission    73836
# Владельцы              40576
# Привод                 58563
# ПТС                    92587
# Руль                   99356
# priceCurrency         129969
# Состояние             103032
# Таможня               103030

# %%
train_baseline.select_dtypes("object").describe().T.sort_values(
    "unique", ascending=False
)
# Out:
#                       count unique  \
# description           86124  77568
# start_date            89378  75680
# Комплектация          89378   5839
# name                  89377   4484
# vehicleConfiguration  89377   1860
# model                 89378   1086
# engineDisplacement    89377    534
# Владение              29201    290
# bodyType              89377    168
# brand                 89378     36
# color                 89378     16
# fuelType              89378      6
# vehicleTransmission   89377      4
# Привод                89377      3
# Руль                  89378      2
# ПТС                   89017      2
#
#                                                                     top   freq
# description           РОЛЬФ Северо-Запад - это первый мегамолл автом...    246
# start_date                                         2020-09-01T10:01:11Z     93
# Комплектация                                                {'id': '0'}  59130
# name                                                  2.0 AT (150 л.с.)   1610
# vehicleConfiguration                               SEDAN MECHANICAL 1.6   4166
# model                                                             FOCUS   2467
# engineDisplacement                                                  1.6  17032
# Владение                                    {'year': 2018, 'month': 10}    497
# bodyType                                              Внедорожник 5 дв.  31885
# brand                                                          MERCEDES   8012
# color                                                            040001  25212
# fuelType                                                         бензин  75053
# vehicleTransmission                                           AUTOMATIC  49218
# Привод                                                         передний  47315
# Руль                                                               LEFT  87589
# ПТС                                                            ORIGINAL  78597

# %%
train_jane["enginePower"] = train_jane["enginePower"].replace("undefined N12", None)
train_jane["enginePower"] = (
    train_jane[~pd.isna(train_jane["enginePower"])]["enginePower"]
    .str.split()
    .str.get(0)
    .astype("int")
)

# %%
train_jane["engineDisplacement"] = train_jane["engineDisplacement"].replace(
    " LTR", None
)
train_jane["engineDisplacement"] = (
    train_jane[~pd.isna(train_jane["engineDisplacement"])]["engineDisplacement"]
    .str.split()
    .str.get(0)
    .astype("float")
)

# %%
train_jane.engineDisplacement.head()
# Out:
# 0    1.8
# 1    1.6
# 2    1.6
# 3    1.4
# 4    1.4
# Name: engineDisplacement, dtype: float64

# %%
train_jane["used"] = train_jane["car_url"].str.contains("used")

# %%
train_jane[train_jane["used"] == False].dropna(thresh=24).shape
# Out:
# (0, 37)

# %%
test.iloc[34682]
# Out:
# bodyType                                                            седан
# brand                                                                 BMW
# car_url                 https://auto.ru/cars/used/sale/bmw/5er/1101369...
# color                                                              чёрный
# complectation_dict                                                    NaN
# description                                Продаётся отличный автомобиль.
# engineDisplacement                                                2.0 LTR
# enginePower                                                       190 N12
# equipment_dict                                                        NaN
# fuelType                                                           дизель
# image                   https://autoru.naydex.net/nwI1K7152/b604fdsYg7...
# mileage                                                             98000
# modelDate                                                            2016
# model_info              {"code":"5ER","name":"5 серии","ru_name":"5 се...
# model_name                                                            5ER
# name                                   520d xDrive 2.0d AT (190 л.с.) 4WD
# numberOfDoors                                                           4
# parsing_unixtime                                               1603707651
# priceCurrency                                                         RUB
# productionDate                                                       2018
# sell_id                                                        1101369581
# super_gen               {"id":"20856402","name":"520","nameplate":"520...
# vehicleConfiguration                                  SEDAN AUTOMATIC 2.0
# vehicleTransmission                                        автоматическая
# vendor                                                           EUROPEAN
# Владельцы                                                      1 владелец
# Владение                                                              NaN
# ПТС                                                              Оригинал
# Привод                                                             полный
# Руль                                                                Левый
# Состояние                                              Не требует ремонта
# Таможня                                                        Растаможен
# Name: 34682, dtype: object

# %%
train_jane["car_url"].str.contains("used").value_counts()
# Out:
# True     103034
# False     26935
# Name: car_url, dtype: int64

# %%
test.select_dtypes("object").describe().T.sort_values("unique", ascending=False)
# Out:
#                       count unique  \
# car_url               34686  34686
# image                 34686  34557
# description           34686  31732
# equipment_dict        24690  23705
# super_gen             34686   5890
# name                  34686   2780
# complectation_dict     6418   2364
# model_info            34686    954
# vehicleConfiguration  34686    634
# model_name            34686    544
# enginePower           34686    315
# Владение              11995    275
# engineDisplacement    34686     55
# bodyType              34686     24
# color                 34686     16
# brand                 34686     12
# fuelType              34686      5
# vehicleTransmission   34686      4
# Владельцы             34686      3
# Привод                34686      3
# vendor                34686      2
# ПТС                   34685      2
# Руль                  34686      2
# priceCurrency         34686      1
# Состояние             34686      1
# Таможня               34686      1
#
#                                                                     top   freq
# car_url               https://auto.ru/cars/used/sale/skoda/octavia/1...      1
# image                 https://avatars.mds.yandex.net/get-verba/21620...     13
# description           Выгода до 82 000 руб. при обмене на Ваш автомо...    264
# equipment_dict                                         {"leather":true}    108
# super_gen             {"id":"6214876","displacement":1598,"engine_ty...    193
# name                                                  1.6 AT (110 л.с.)    631
# complectation_dict    {"id":"4562904","name":"Elegance","available_o...     51
# model_info            {"code":"OCTAVIA","name":"Octavia","ru_name":"...   1404
# vehicleConfiguration                      ALLROAD_5_DOORS AUTOMATIC 3.0   2389
# model_name                                                      OCTAVIA   1418
# enginePower                                                     249 N12   1708
# Владение                                             1 год и 10 месяцев    209
# engineDisplacement                                              2.0 LTR   7391
# bodyType                                                          седан  13147
# color                                                            чёрный  11010
# brand                                                               BMW   4473
# fuelType                                                         бензин  28601
# vehicleTransmission                                      автоматическая  19596
# Владельцы                                                   3 или более  15957
# Привод                                                         передний  15565
# vendor                                                         EUROPEAN  20682
# ПТС                                                            Оригинал  30098
# Руль                                                              Левый  33287
# priceCurrency                                                       RUB  34686
# Состояние                                            Не требует ремонта  34686
# Таможня                                                      Растаможен  34686

# %%
test["fuelType"].value_counts()
# Out:
# бензин     28601
# дизель      5800
# гибрид       223
# электро       55
# газ            7
# Name: fuelType, dtype: int64

# %%
test.groupby("car_url")["image"].count().sort_values(ascending=False).head(10)
# Out:
# car_url
# https://auto.ru/cars/used/sale/audi/100/1016944865-8eb8f/            1
# https://auto.ru/cars/used/sale/skoda/octavia/1100434568-e9537421/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100515744-d97a41fa/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100514944-54916e94/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100513036-35594e9f/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100495414-bb724b6c/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100492150-5ae5281f/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100491772-7f29f9e8/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100487934-c961ee31/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100486714-6ff064ce/    1
# Name: image, dtype: int64

# %%
test.iloc[2]["model_info"]
# Out:
# '{"code":"SUPERB","name":"Superb","ru_name":"Суперб","morphology":{},"nameplate":{"code":"","name":"","semantic_url":""}}'

# %%
test[test["vehicleConfiguration"] == "ALLROAD_5_DOORS AUTOMATIC 2.0"].sample(
    5, random_state=42
)
# Out:
#                 bodyType       brand  \
# 23340  внедорожник 5 дв.  VOLKSWAGEN
# 5517   внедорожник 5 дв.       HONDA
# 10155  внедорожник 5 дв.         BMW
# 6177   внедорожник 5 дв.       HONDA
# 4276   внедорожник 5 дв.        AUDI
#
#                                                  car_url        color  \
# 23340  https://auto.ru/cars/used/sale/volkswagen/tigu...  серебристый
# 5517   https://auto.ru/cars/used/sale/honda/cr_v/1101...        белый
# 10155  https://auto.ru/cars/used/sale/bmw/x3/10960043...      красный
# 6177   https://auto.ru/cars/used/sale/honda/cr_v/1100...      красный
# 4276   https://auto.ru/cars/used/sale/audi/q5/1101303...        белый
#
#                                       complectation_dict  \
# 23340                                                NaN
# 5517                                                 NaN
# 10155  {"id":"2424078","name":"xDrive20","available_o...
# 6177                                                 NaN
# 4276                                                 NaN
#
#                                              description engineDisplacement  \
# 23340  Единственный владелец\nАвтомобиль с полным НДС...            2.0 LTR
# 5517   ✔У НАС КРЕДИТ ДАДУТ ВСЕМ!\n●ПРОСТО ОСТАВЬТЕ ЗА...            2.0 LTR
# 10155  Продаю  автомобиль  БМВ-Х 3,2009 года выпуска,...            2.0 LTR
# 6177   Авто в отличном состоянии для своих лет, ходов...            2.0 LTR
# 4276   Состояние нового автомобиля. Нет крашенных эле...            2.0 LTR
#
#       enginePower                                     equipment_dict fuelType  \
# 23340     140 N12  {"cruise-control":true,"asr":true,"airbag-driv...   дизель
# 5517      128 N12  {"engine-proof":true,"asr":true,"adaptive-ligh...   бензин
# 10155     177 N12  {"engine-proof":true,"esp":true,"airbag-driver...   дизель
# 6177      128 N12                                                NaN   бензин
# 4276      180 N12  {"alloy-wheel-disks":true,"ptf":true,"aux":tru...   бензин
#
#                                                    image  mileage  modelDate  \
# 23340  https://autoru.naydex.net/o9DBXQ270/5ac010hAY0...    70366       2011
# 5517   https://autoru.naydex.net/mcQh17801/f1b5751dCi...   156000       1995
# 10155  https://autoru.naydex.net/lICN99c69/9bc7d3Rr7k...   158313       2006
# 6177   https://avatars.mds.yandex.net/get-autoru-vos/...   319000       1995
# 4276   https://avatars.mds.yandex.net/get-autoru-vos/...    31420       2012
#
#                                               model_info model_name  \
# 23340  {"code":"TIGUAN","name":"Tiguan","ru_name":"Ти...     TIGUAN
# 5517   {"code":"CR_V","name":"CR-V","ru_name":"CR-V",...       CR_V
# 10155  {"code":"X3","name":"X3","ru_name":"Х3","morph...         X3
# 6177   {"code":"CR_V","name":"CR-V","ru_name":"CR-V",...       CR_V
# 4276   {"code":"Q5","name":"Q5","ru_name":"Ку5","morp...         Q5
#
#                              name  numberOfDoors  parsing_unixtime  \
# 23340      2.0d AT (140 л.с.) 4WD              5        1603213368
# 5517        2.0 AT (128 л.с.) 4WD              5        1603254705
# 10155  20d 2.0d AT (177 л.с.) 4WD              5        1603117968
# 6177        2.0 AT (128 л.с.) 4WD              5        1603257132
# 4276        2.0 AT (180 л.с.) 4WD              5        1603129045
#
#       priceCurrency  productionDate     sell_id  \
# 23340           RUB            2015  1101291589
# 5517            RUB            1998  1101117481
# 10155           RUB            2009  1096004334
# 6177            RUB            1998  1100628270
# 4276            RUB            2016  1101303784
#
#                                                super_gen  \
# 23340  {"id":"7344497","displacement":1968,"engine_ty...
# 5517   {"id":"20501678","displacement":1973,"engine_t...
# 10155  {"id":"4917631","name":"20d","nameplate":"20d"...
# 6177   {"id":"20501678","displacement":1973,"engine_t...
# 4276   {"id":"20773921","displacement":1984,"engine_t...
#
#                 vehicleConfiguration vehicleTransmission    vendor  \
# 23340  ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
# 5517   ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  JAPANESE
# 10155  ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
# 6177   ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  JAPANESE
# 4276   ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
#
#          Владельцы            Владение       ПТС  Привод   Руль  \
# 23340   1 владелец                 NaN  Оригинал  полный  Левый
# 5517   3 или более                 NaN  Оригинал  полный  Левый
# 10155  3 или более  3 года и 5 месяцев  Оригинал  полный  Левый
# 6177   3 или более                 NaN  Оригинал  полный  Левый
# 4276   2 владельца            2 месяца  Оригинал  полный  Левый
#
#                 Состояние     Таможня
# 23340  Не требует ремонта  Растаможен
# 5517   Не требует ремонта  Растаможен
# 10155  Не требует ремонта  Растаможен
# 6177   Не требует ремонта  Растаможен
# 4276   Не требует ремонта  Растаможен

# %%
test["Владельцы"] = test["Владельцы"].apply(get_number_of_owners_from_owners)
train_jane["Владельцы"] = train_jane["Владельцы"].apply(
    get_number_of_owners_from_owners
)

# %%
print(
    "unique object cols in train (Jane's version):",
    set(train_jane.select_dtypes("object").columns.tolist())
    - set(test.select_dtypes("object").columns.tolist()),
    "\nunique object cols in test:",
    set(test.select_dtypes("object").columns.tolist())
    - set(train_jane.select_dtypes("object").columns.tolist()),
)
# Out:
# unique object cols in train (Jane's version): {'date_added', 'region', 'used'}
# unique object cols in test: {'enginePower', 'model_info', 'vendor', 'engineDisplacement'}

# %% [markdown]
# ## making train and test similar

# %%
train_jane["model_name"] = train_jane.model_name.apply(lambda x: str(x).lower())
test["model_name"] = test.model_name.apply(lambda x: str(x).lower())

# %%
vendor_voc = (
    test[["brand", "vendor"]].drop_duplicates().set_index("brand").to_dict()["vendor"]
)
vendor_voc
# Out:
# {'SKODA': 'EUROPEAN',
#  'AUDI': 'EUROPEAN',
#  'HONDA': 'JAPANESE',
#  'VOLVO': 'EUROPEAN',
#  'BMW': 'EUROPEAN',
#  'NISSAN': 'JAPANESE',
#  'INFINITI': 'JAPANESE',
#  'MERCEDES': 'EUROPEAN',
#  'TOYOTA': 'JAPANESE',
#  'LEXUS': 'JAPANESE',
#  'VOLKSWAGEN': 'EUROPEAN',
#  'MITSUBISHI': 'JAPANESE'}

# %%
train_jane.brand.unique().tolist()
# Out:
# ['SKODA',
#  nan,
#  'AUDI',
#  'HONDA',
#  'VOLVO',
#  'BMW',
#  'NISSAN',
#  'INFINITI',
#  'MERCEDES',
#  'TOYOTA',
#  'LEXUS',
#  'VOLKSWAGEN',
#  'MITSUBISHI']

# %%
train_baseline.brand.unique().tolist()
# Out:
# ['AUDI',
#  'BMW',
#  'CADILLAC',
#  'CHERY',
#  'CHEVROLET',
#  'CHRYSLER',
#  'CITROEN',
#  'DAEWOO',
#  'DODGE',
#  'FORD',
#  'GEELY',
#  'HONDA',
#  'HYUNDAI',
#  'INFINITI',
#  'JAGUAR',
#  'JEEP',
#  'KIA',
#  'LEXUS',
#  'MAZDA',
#  'MINI',
#  'MITSUBISHI',
#  'NISSAN',
#  'OPEL',
#  'PEUGEOT',
#  'PORSCHE',
#  'RENAULT',
#  'SKODA',
#  'SUBARU',
#  'SUZUKI',
#  'TOYOTA',
#  'VOLKSWAGEN',
#  'VOLVO',
#  'GREAT_WALL',
#  'LAND_ROVER',
#  'MERCEDES',
#  'SSANG_YONG']

# %%
train_jane["vendor"] = train_jane["brand"].map(vendor_voc)
train_baseline["vendor"] = train_baseline["brand"].map(vendor_voc)
train_jane.vendor.unique().tolist(), train_baseline.vendor.unique().tolist()
# Out:
# (['EUROPEAN', nan, 'JAPANESE'], ['EUROPEAN', nan, 'JAPANESE'])

# %%
print(
    len(train_jane.loc[train_jane.vendor.isna()]["model_name"].unique().tolist()),
    "na of",
    len(train_jane.model_name.unique().tolist()),
)
# Out:
# 1 na of 514

# %%
train_jane.loc[train_jane.vendor.isna()].shape
# Out:
# (213, 37)

# %%
train_jane.priceCurrency.unique()
# Out:
# array(['RUB', 'RUR', nan], dtype=object)

# %%
train_baseline.columns.sort_values().tolist()
# Out:
# ['bodyType',
#  'brand',
#  'color',
#  'description',
#  'engineDisplacement',
#  'enginePower',
#  'fuelType',
#  'hidden',
#  'mileage',
#  'model',
#  'modelDate',
#  'name',
#  'numberOfDoors',
#  'price',
#  'productionDate',
#  'start_date',
#  'vehicleConfiguration',
#  'vehicleTransmission',
#  'vendor',
#  'Владельцы',
#  'Владение',
#  'Комплектация',
#  'ПТС',
#  'Привод',
#  'Руль',
#  'Состояние',
#  'Таможня']

# %% [markdown]
# ## deleting cols which can't be used
#
# at least for now - to re-review later

# %%
del test["car_url"]
del test["complectation_dict"]
del test["equipment_dict"]
del test["image"]
del test["model_info"]
del test["name"]
del test["parsing_unixtime"]
del test["priceCurrency"]
del test["sell_id"]
del test["vehicleConfiguration"]
del test["Состояние"]
del test["Таможня"]
del test["super_gen"]
del train_baseline["hidden"]
del train_baseline["name"]
del train_baseline["start_date"]
del train_baseline["vehicleConfiguration"]
del train_baseline["Комплектация"]
del train_baseline["Состояние"]
del train_baseline["Таможня"]
del train_jane["car_url"]
del train_jane["complectation_dict"]
del train_jane["date_added"]
del train_jane["equipment_dict"]
del train_jane["image"]
del train_jane["model_info"]
del train_jane["name"]
del train_jane["parsing_unixtime"]
del train_jane["priceCurrency"]
del train_jane["region"]
del train_jane["sell_id"]
del train_jane["vehicleConfiguration"]
del train_jane["views"]
del train_jane["Состояние"]
del train_jane["Таможня"]
del train_jane["super_gen"]
del train_jane["used"]

# %% [markdown]
# ## view again

# %%
describe_nums(train_jane.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_1f696_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_1f696_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.2%, transparent 4.2%);
# }
# #T_1f696_row0_col4 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_1f696_row0_col7 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_1f696_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 53.4%, transparent 53.4%);
# }
# #T_1f696_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_1f696_row1_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_1f696_row1_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_1f696_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 2.0%, transparent 2.0%);
# }
# #T_1f696_row2_col3, #T_1f696_row4_col3, #T_1f696_row6_col3, #T_1f696_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_1f696_row2_col4, #T_1f696_row3_col4, #T_1f696_row4_col4, #T_1f696_row5_col4, #T_1f696_row6_col4, #T_1f696_row7_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_1f696_row2_col7, #T_1f696_row3_col7, #T_1f696_row4_col7, #T_1f696_row5_col7, #T_1f696_row6_col7, #T_1f696_row7_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_1f696_row3_col0, #T_1f696_row4_col0, #T_1f696_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.3%, transparent 0.3%);
# }
# #T_1f696_row3_col3, #T_1f696_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.1%, transparent 0.1%);
# }
# #T_1f696_row6_col0, #T_1f696_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_1f696">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f696_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_1f696_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_1f696_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_1f696_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_1f696_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_1f696_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_1f696_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_1f696_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_1f696_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_1f696_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f696_level0_row0" class="row_heading level0 row0" >mileage</th>
#       <td id="T_1f696_row0_col0" class="data row0 col0" >15181</td>
#       <td id="T_1f696_row0_col1" class="data row0 col1" >27167</td>
#       <td id="T_1f696_row0_col2" class="data row0 col2" >103034.000000</td>
#       <td id="T_1f696_row0_col3" class="data row0 col3" >116610.915407</td>
#       <td id="T_1f696_row0_col4" class="data row0 col4" >85154.492046</td>
#       <td id="T_1f696_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_1f696_row0_col6" class="data row0 col6" >51000.000000</td>
#       <td id="T_1f696_row0_col7" class="data row0 col7" >100000.000000</td>
#       <td id="T_1f696_row0_col8" class="data row0 col8" >161000.000000</td>
#       <td id="T_1f696_row0_col9" class="data row0 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1f696_level0_row1" class="row_heading level0 row1" >price</th>
#       <td id="T_1f696_row1_col0" class="data row1 col0" >8105</td>
#       <td id="T_1f696_row1_col1" class="data row1 col1" >20436</td>
#       <td id="T_1f696_row1_col2" class="data row1 col2" >109765.000000</td>
#       <td id="T_1f696_row1_col3" class="data row1 col3" >2801223.260639</td>
#       <td id="T_1f696_row1_col4" class="data row1 col4" >2689068.150068</td>
#       <td id="T_1f696_row1_col5" class="data row1 col5" >23000.000000</td>
#       <td id="T_1f696_row1_col6" class="data row1 col6" >1000000.000000</td>
#       <td id="T_1f696_row1_col7" class="data row1 col7" >2045000.000000</td>
#       <td id="T_1f696_row1_col8" class="data row1 col8" >3649000.000000</td>
#       <td id="T_1f696_row1_col9" class="data row1 col9" >39990000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1f696_level0_row2" class="row_heading level0 row2" >enginePower</th>
#       <td id="T_1f696_row2_col0" class="data row2 col0" >306</td>
#       <td id="T_1f696_row2_col1" class="data row2 col1" >215</td>
#       <td id="T_1f696_row2_col2" class="data row2 col2" >129986.000000</td>
#       <td id="T_1f696_row2_col3" class="data row2 col3" >205.952133</td>
#       <td id="T_1f696_row2_col4" class="data row2 col4" >97.503652</td>
#       <td id="T_1f696_row2_col5" class="data row2 col5" >41.000000</td>
#       <td id="T_1f696_row2_col6" class="data row2 col6" >146.000000</td>
#       <td id="T_1f696_row2_col7" class="data row2 col7" >180.000000</td>
#       <td id="T_1f696_row2_col8" class="data row2 col8" >249.000000</td>
#       <td id="T_1f696_row2_col9" class="data row2 col9" >646.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1f696_level0_row3" class="row_heading level0 row3" >modelDate</th>
#       <td id="T_1f696_row3_col0" class="data row3 col0" >53</td>
#       <td id="T_1f696_row3_col1" class="data row3 col1" >215</td>
#       <td id="T_1f696_row3_col2" class="data row3 col2" >129986.000000</td>
#       <td id="T_1f696_row3_col3" class="data row3 col3" >2012.934578</td>
#       <td id="T_1f696_row3_col4" class="data row3 col4" >6.017749</td>
#       <td id="T_1f696_row3_col5" class="data row3 col5" >1938.000000</td>
#       <td id="T_1f696_row3_col6" class="data row3 col6" >2010.000000</td>
#       <td id="T_1f696_row3_col7" class="data row3 col7" >2014.000000</td>
#       <td id="T_1f696_row3_col8" class="data row3 col8" >2017.000000</td>
#       <td id="T_1f696_row3_col9" class="data row3 col9" >2021.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1f696_level0_row4" class="row_heading level0 row4" >engineDisplacement</th>
#       <td id="T_1f696_row4_col0" class="data row4 col0" >51</td>
#       <td id="T_1f696_row4_col1" class="data row4 col1" >629</td>
#       <td id="T_1f696_row4_col2" class="data row4 col2" >129572.000000</td>
#       <td id="T_1f696_row4_col3" class="data row4 col3" >2.437865</td>
#       <td id="T_1f696_row4_col4" class="data row4 col4" >0.933884</td>
#       <td id="T_1f696_row4_col5" class="data row4 col5" >0.700000</td>
#       <td id="T_1f696_row4_col6" class="data row4 col6" >2.000000</td>
#       <td id="T_1f696_row4_col7" class="data row4 col7" >2.000000</td>
#       <td id="T_1f696_row4_col8" class="data row4 col8" >3.000000</td>
#       <td id="T_1f696_row4_col9" class="data row4 col9" >6.600000</td>
#     </tr>
#     <tr>
#       <th id="T_1f696_level0_row5" class="row_heading level0 row5" >productionDate</th>
#       <td id="T_1f696_row5_col0" class="data row5 col0" >50</td>
#       <td id="T_1f696_row5_col1" class="data row5 col1" >213</td>
#       <td id="T_1f696_row5_col2" class="data row5 col2" >129988.000000</td>
#       <td id="T_1f696_row5_col3" class="data row5 col3" >2015.083854</td>
#       <td id="T_1f696_row5_col4" class="data row5 col4" >5.929774</td>
#       <td id="T_1f696_row5_col5" class="data row5 col5" >1952.000000</td>
#       <td id="T_1f696_row5_col6" class="data row5 col6" >2012.000000</td>
#       <td id="T_1f696_row5_col7" class="data row5 col7" >2016.000000</td>
#       <td id="T_1f696_row5_col8" class="data row5 col8" >2020.000000</td>
#       <td id="T_1f696_row5_col9" class="data row5 col9" >2021.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1f696_level0_row6" class="row_heading level0 row6" >numberOfDoors</th>
#       <td id="T_1f696_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_1f696_row6_col1" class="data row6 col1" >214</td>
#       <td id="T_1f696_row6_col2" class="data row6 col2" >129987.000000</td>
#       <td id="T_1f696_row6_col3" class="da

# %%
describe_nums(train_baseline.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_08eaa_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_08eaa_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.4%, transparent 10.4%);
# }
# #T_08eaa_row0_col4 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_08eaa_row0_col7 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_08eaa_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 46.9%, transparent 46.9%);
# }
# #T_08eaa_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_08eaa_row1_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_08eaa_row1_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_08eaa_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 2.3%, transparent 2.3%);
# }
# #T_08eaa_row2_col3, #T_08eaa_row5_col3, #T_08eaa_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_08eaa_row2_col4, #T_08eaa_row3_col4, #T_08eaa_row4_col4, #T_08eaa_row5_col4, #T_08eaa_row6_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_08eaa_row2_col7, #T_08eaa_row3_col7, #T_08eaa_row4_col7, #T_08eaa_row5_col7, #T_08eaa_row6_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_08eaa_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.5%, transparent 0.5%);
# }
# #T_08eaa_row3_col3, #T_08eaa_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_08eaa_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.4%, transparent 0.4%);
# }
# #T_08eaa_row5_col0, #T_08eaa_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_08eaa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08eaa_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_08eaa_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_08eaa_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_08eaa_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_08eaa_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_08eaa_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_08eaa_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_08eaa_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_08eaa_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_08eaa_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08eaa_level0_row0" class="row_heading level0 row0" >mileage</th>
#       <td id="T_08eaa_row0_col0" class="data row0 col0" >17403</td>
#       <td id="T_08eaa_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_08eaa_row0_col2" class="data row0 col2" >89378.000000</td>
#       <td id="T_08eaa_row0_col3" class="data row0 col3" >134828.811497</td>
#       <td id="T_08eaa_row0_col4" class="data row0 col4" >102979.784485</td>
#       <td id="T_08eaa_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_08eaa_row0_col6" class="data row0 col6" >56042.500000</td>
#       <td id="T_08eaa_row0_col7" class="data row0 col7" >130000.000000</td>
#       <td id="T_08eaa_row0_col8" class="data row0 col8" >194939.750000</td>
#       <td id="T_08eaa_row0_col9" class="data row0 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_08eaa_level0_row1" class="row_heading level0 row1" >price</th>
#       <td id="T_08eaa_row1_col0" class="data row1 col0" >8168</td>
#       <td id="T_08eaa_row1_col1" class="data row1 col1" >410</td>
#       <td id="T_08eaa_row1_col2" class="data row1 col2" >88968.000000</td>
#       <td id="T_08eaa_row1_col3" class="data row1 col3" >1294586.356330</td>
#       <td id="T_08eaa_row1_col4" class="data row1 col4" >1950410.471999</td>
#       <td id="T_08eaa_row1_col5" class="data row1 col5" >16000.000000</td>
#       <td id="T_08eaa_row1_col6" class="data row1 col6" >350000.000000</td>
#       <td id="T_08eaa_row1_col7" class="data row1 col7" >650000.000000</td>
#       <td id="T_08eaa_row1_col8" class="data row1 col8" >1480000.000000</td>
#       <td id="T_08eaa_row1_col9" class="data row1 col9" >99000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_08eaa_level0_row2" class="row_heading level0 row2" >enginePower</th>
#       <td id="T_08eaa_row2_col0" class="data row2 col0" >396</td>
#       <td id="T_08eaa_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_08eaa_row2_col2" class="data row2 col2" >89377.000000</td>
#       <td id="T_08eaa_row2_col3" class="data row2 col3" >171.231637</td>
#       <td id="T_08eaa_row2_col4" class="data row2 col4" >83.527540</td>
#       <td id="T_08eaa_row2_col5" class="data row2 col5" >11.000000</td>
#       <td id="T_08eaa_row2_col6" class="data row2 col6" >115.000000</td>
#       <td id="T_08eaa_row2_col7" class="data row2 col7" >150.000000</td>
#       <td id="T_08eaa_row2_col8" class="data row2 col8" >199.000000</td>
#       <td id="T_08eaa_row2_col9" class="data row2 col9" >800.000000</td>
#     </tr>
#     <tr>
#       <th id="T_08eaa_level0_row3" class="row_heading level0 row3" >productionDate</th>
#       <td id="T_08eaa_row3_col0" class="data row3 col0" >80</td>
#       <td id="T_08eaa_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_08eaa_row3_col2" class="data row3 col2" >89378.000000</td>
#       <td id="T_08eaa_row3_col3" class="data row3 col3" >2010.832531</td>
#       <td id="T_08eaa_row3_col4" class="data row3 col4" >7.024776</td>
#       <td id="T_08eaa_row3_col5" class="data row3 col5" >1904.000000</td>
#       <td id="T_08eaa_row3_col6" class="data row3 col6" >2007.000000</td>
#       <td id="T_08eaa_row3_col7" class="data row3 col7" >2011.000000</td>
#       <td id="T_08eaa_row3_col8" class="data row3 col8" >2016.000000</td>
#       <td id="T_08eaa_row3_col9" class="data row3 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_08eaa_level0_row4" class="row_heading level0 row4" >modelDate</th>
#       <td id="T_08eaa_row4_col0" class="data row4 col0" >78</td>
#       <td id="T_08eaa_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_08eaa_row4_col2" class="data row4 col2" >89377.000000</td>
#       <td id="T_08eaa_row4_col3" class="data row4 col3" >2008.543294</td>
#       <td id="T_08eaa_row4_col4" class="data row4 col4" >7.415436</td>
#       <td id="T_08eaa_row4_col5" class="data row4 col5" >1904.000000</td>
#       <td id="T_08eaa_row4_col6" class="data row4 col6" >2005.000000</td>
#       <td id="T_08eaa_row4_col7" class="data row4 col7" >2009.000000</td>
#       <td id="T_08eaa_row4_col8" class="data row4 col8" >2014.000000</td>
#       <td id="T_08eaa_row4_col9" class="data row4 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_08eaa_level0_row5" class="row_heading level0 row5" >numberOfDoors</th>
#       <td id="T_08eaa_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_08eaa_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_08eaa_row5_col2" class="data row5 col2" >89377.000000</td>
#       <td id="T_08eaa_row5_col3" class="data row5 col3" >4.510467</td>
#       <td id="T_08eaa_row5_col4" class="data row5 col4" >0.653203</td>
#       <td id="T_08eaa_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_08eaa_row5_col6" class="data row5 col6" >4.000000</td>
#       <td id="T_08eaa_row5_col7" class="data row5 col7" >5.000000</td>
#       <td id="T_08eaa_row5_col8" class="data row5 col8" >5.000000</td>
#       <td id="T_08eaa_row5_col9" class="data row5 col9" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_08eaa_level0_row6" class="row_heading level0 row6" >Владельцы</th>
#       <td id="T_08eaa_row6_col0" class="data row6 col0" >3</td>
#       <td id="T_08eaa_row6_col1" class="data row6 col1" >13588</td>
#       <td id="T_08eaa_row6_col2" class="data row6 col2" >75790.000000</td>
#       <td id="T_08eaa_row6_col3" class="data row6 col3" >2.2

# %%
describe_nums(test.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_e6240_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_e6240_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_e6240_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e6240_row0_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_e6240_row1_col0, #T_e6240_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.6%, transparent 0.6%);
# }
# #T_e6240_row1_col3, #T_e6240_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.2%, transparent 1.2%);
# }
# #T_e6240_row1_col4, #T_e6240_row2_col4, #T_e6240_row3_col4, #T_e6240_row4_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_e6240_row1_col7, #T_e6240_row2_col7 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_e6240_row3_col0, #T_e6240_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# #T_e6240_row3_col3, #T_e6240_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_e6240_row3_col7, #T_e6240_row4_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e6240">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6240_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_e6240_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_e6240_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_e6240_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_e6240_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_e6240_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_e6240_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_e6240_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_e6240_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_e6240_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6240_level0_row0" class="row_heading level0 row0" >mileage</th>
#       <td id="T_e6240_row0_col0" class="data row0 col0" >11268</td>
#       <td id="T_e6240_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_e6240_row0_col2" class="data row0 col2" >34686.000000</td>
#       <td id="T_e6240_row0_col3" class="data row0 col3" >162009.767889</td>
#       <td id="T_e6240_row0_col4" class="data row0 col4" >100676.559489</td>
#       <td id="T_e6240_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_e6240_row0_col6" class="data row0 col6" >91153.500000</td>
#       <td id="T_e6240_row0_col7" class="data row0 col7" >149779.500000</td>
#       <td id="T_e6240_row0_col8" class="data row0 col8" >215000.000000</td>
#       <td id="T_e6240_row0_col9" class="data row0 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e6240_level0_row1" class="row_heading level0 row1" >productionDate</th>
#       <td id="T_e6240_row1_col0" class="data row1 col0" >69</td>
#       <td id="T_e6240_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_e6240_row1_col2" class="data row1 col2" >34686.000000</td>
#       <td id="T_e6240_row1_col3" class="data row1 col3" >2009.264602</td>
#       <td id="T_e6240_row1_col4" class="data row1 col4" >7.047661</td>
#       <td id="T_e6240_row1_col5" class="data row1 col5" >1904.000000</td>
#       <td id="T_e6240_row1_col6" class="data row1 col6" >2006.000000</td>
#       <td id="T_e6240_row1_col7" class="data row1 col7" >2011.000000</td>
#       <td id="T_e6240_row1_col8" class="data row1 col8" >2014.000000</td>
#       <td id="T_e6240_row1_col9" class="data row1 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e6240_level0_row2" class="row_heading level0 row2" >modelDate</th>
#       <td id="T_e6240_row2_col0" class="data row2 col0" >66</td>
#       <td id="T_e6240_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_e6240_row2_col2" class="data row2 col2" >34686.000000</td>
#       <td id="T_e6240_row2_col3" class="data row2 col3" >2007.074728</td>
#       <td id="T_e6240_row2_col4" class="data row2 col4" >7.415894</td>
#       <td id="T_e6240_row2_col5" class="data row2 col5" >1904.000000</td>
#       <td id="T_e6240_row2_col6" class="data row2 col6" >2004.000000</td>
#       <td id="T_e6240_row2_col7" class="data row2 col7" >2008.000000</td>
#       <td id="T_e6240_row2_col8" class="data row2 col8" >2012.000000</td>
#       <td id="T_e6240_row2_col9" class="data row2 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e6240_level0_row3" class="row_heading level0 row3" >numberOfDoors</th>
#       <td id="T_e6240_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_e6240_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_e6240_row3_col2" class="data row3 col2" >34686.000000</td>
#       <td id="T_e6240_row3_col3" class="data row3 col3" >4.450816</td>
#       <td id="T_e6240_row3_col4" class="data row3 col4" >0.703040</td>
#       <td id="T_e6240_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_e6240_row3_col6" class="data row3 col6" >4.000000</td>
#       <td id="T_e6240_row3_col7" class="data row3 col7" >5.000000</td>
#       <td id="T_e6240_row3_col8" class="data row3 col8" >5.000000</td>
#       <td id="T_e6240_row3_col9" class="data row3 col9" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e6240_level0_row4" class="row_heading level0 row4" >Владельцы</th>
#       <td id="T_e6240_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_e6240_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_e6240_row4_col2" class="data row4 col2" >34686.000000</td>
#       <td id="T_e6240_row4_col3" class="data row4 col3" >2.187338</td>
#       <td id="T_e6240_row4_col4" class="data row4 col4" >0.835266</td>
#       <td id="T_e6240_row4_col5" class="data row4 col5" >1.000000</td>
#       <td id="T_e6240_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_e6240_row4_col7" class="data row4 col7" >2.000000</td>
#       <td id="T_e6240_row4_col8" class="data row4 col8" >3.000000</td>
#       <td id="T_e6240_row4_col9" class="data row4 col9" >3.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_jane.select_dtypes("object").shape, train_baseline.select_dtypes(
    "object"
).shape, test.select_dtypes("object").shape
# Out:
# ((130201, 12), (89378, 13), (34686, 14))

# %%
train_jane.select_dtypes("object").describe().T.sort_values("unique", ascending=False)
# Out:
#                       count unique  \
# description          129988  35274
# model_name           130201    514
# Владение              14286    261
# bodyType             129986     21
# color                129988     16
# brand                129988     12
# fuelType             129986      5
# vehicleTransmission  129986      4
# Привод               103032      3
# vendor               129988      2
# ПТС                  103034      2
# Руль                 103033      2
#
#                                                                    top    freq
# description          Официальный дилер Mercedes Benz ООО РОЛЬФ фили...    3230
# model_name                                                         nan   27167
# Владение                                             3 года и 2 месяца     646
# bodyType                                             внедорожник 5 дв.   75068
# color                                                           чёрный   42216
# brand                                                           TOYOTA   20117
# fuelType                                                        бензин  100407
# vehicleTransmission                                     автоматическая   73836
# Привод                                                          полный   58563
# vendor                                                        EUROPEAN   72959
# ПТС                                                           Оригинал   92587
# Руль                                                             Левый   99356

# %%
train_baseline.select_dtypes("object").describe().T.sort_values(
    "unique", ascending=False
)
# Out:
#                      count unique  \
# description          86124  77568
# model                89378   1086
# engineDisplacement   89377    534
# Владение             29201    290
# bodyType             89377    168
# brand                89378     36
# color                89378     16
# fuelType             89378      6
# vehicleTransmission  89377      4
# Привод               89377      3
# Руль                 89378      2
# ПТС                  89017      2
# vendor               49309      2
#
#                                                                    top   freq
# description          РОЛЬФ Северо-Запад - это первый мегамолл автом...    246
# model                                                            FOCUS   2467
# engineDisplacement                                                 1.6  17032
# Владение                                   {'year': 2018, 'month': 10}    497
# bodyType                                             Внедорожник 5 дв.  31885
# brand                                                         MERCEDES   8012
# color                                                           040001  25212
# fuelType                                                        бензин  75053
# vehicleTransmission                                          AUTOMATIC  49218
# Привод                                                        передний  47315
# Руль                                                              LEFT  87589
# ПТС                                                           ORIGINAL  78597
# vendor                                                        EUROPEAN  31507

# %%
test.select_dtypes("object").describe().T.sort_values("unique", ascending=False)[
    "top"
].head(1).tolist()
# Out:
# ['Выгода до 82 000 руб. при обмене на Ваш автомобиль! \nВыгода при покупке в кредит до 100 000 руб.! \nРОЛЬФ ЯСЕНЕВО с пробегом. \n-Мы принимаем любые легковые и коммерческие автомобили независимо от марки, года выпуска, пробега и состояния автомобиля. \n-В наличии более 500 проверенных и готовых к продаже автомобилей. \n-Более 400 комплектов шин, дисков, колес в сборе. \n-Все автомобили проходят комплексную проверку - техническую, криминалистическую, проверку истории кузовных ремонтов сертифицированными специалистами. \n-Мы предоставляем гарантию юридической чистоты в соответствии с законодательством РФ. \n-Мы работаем каждый день с 9:00 до 22:00 (без выходных). \nУслуги: \n• Срочный выкуп Вашего автомобиля \n• Выкуп кредитных а/м \n• Trade-in - обмен Вашего автомобиля на новый или с пробегом (возможна доплата с любой стороны) \n• Выездная оценка Вашего а/м \n• Комиссионная продажа (на Ваших условиях) \n• Аукцион \n• Кредитование \n• Страхование КАСКО, ОСАГО \n• Дополнительное оборудование \n• Запасные части \n• Сервисное обслуживание \n• Б/У шины и диски']

# %%
test.sample(3).T
# Out:
#                                                                  16344  \
# bodyType                                                         седан
# brand                                                         MERCEDES
# color                                                            белый
# description          Все вопросы по телефону. \nНедавно заменены це...
# engineDisplacement                                             1.8 LTR
# enginePower                                                    184 N12
# fuelType                                                        бензин
# mileage                                                         199000
# modelDate                                                         2011
# model_name                                                    c_klasse
# numberOfDoors                                                        4
# productionDate                                                    2012
# vehicleTransmission                                     автоматическая
# vendor                                                        EUROPEAN
# Владельцы                                                            3
# Владение                                                           NaN
# ПТС                                                           Оригинал
# Привод                                                          задний
# Руль                                                             Левый
#
#                                                                  29845  \
# bodyType                                             внедорожник 5 дв.
# brand                                                              BMW
# color                                                       золотистый
# description          Зимняя резина в комплекте на оригинальных литы...
# engineDisplacement                                             2.0 LTR
# enginePower                                                    150 N12
# fuelType                                                        бензин
# mileage                                                         165000
# modelDate                                                         2009
# model_name                                                          x1
# numberOfDoors                                                        5
# productionDate                                                    2011
# vehicleTransmission                                     автоматическая
# vendor                                                        EUROPEAN
# Владельцы                                                            3
# Владение                                                           NaN
# ПТС                                                           Оригинал
# Привод                                                          задний
# Руль                                                             Левый
#
#                                                                  29263
# bodyType                                             внедорожник 5 дв.
# brand                                                              BMW
# color                                                            белый
# description          В продаже автомобили от компании АО ABTODOM, о...
# engineDisplacement                                             2.0 LTR
# enginePower                                                    192 N12
# fuelType                                                        бензин
# mileage                                                          10500
# modelDate                                                         2015
# model_name                                                          x1
# numberOfDoors                                                        5
# productionDate                                                    2018
# vehicleTransmission                                     автоматическая
# vendor                                                        EUROPEAN
# Владельцы                                                            1
# Владение                                                           NaN
# ПТС                                                           Оригинал
# Привод                                                          полный
# Руль                                                             Левый

# %%
train_jane.loc[train_jane.price.isna()].shape[0], train_jane.price.shape[
    0
], train_jane.loc[train_jane.price.isna()].shape[0] / train_jane.price.shape[0]
# Out:
# (20436, 130201, 0.1569573198362532)

# %% [markdown]
# ## conclusion - to do about variables
#
# $y = price$ - dropna, multiply for date course based coefficient for each dataset, take a log
#
# - [ ] **description** - to tokenize - to read more about tokenize
# - [ ] **engineDisplacement** - convert to float
# - [ ] **enginePower** - convert to integer
# - [ ] **Владельцы** - convert to integer
# - [ ] **Владение** - calculate number of day
# - [ ] **used** - is it possible to create this from urls or something for other datasets?
# - [ ] **super_gen** - do we have something to extract? We have no such col in baseline
# - [ ] **bodyType**, **color**, **brand**, **fuelType**, **vehicleTransmission**, **Привод**, **ПТС**, **Руль** - _temporary keep as is_
#
# more
#
# - [ ] mileage rename
# - [ ] compare with existing features
# - [ ] compare 4 dicts (equepment, complactation) train - test
# Numerics - fill na, log if tailed, standartize
# https://www.kaggle.com/datasets/gmbitz/all-auto-ru-09-09-2020

# %% [markdown]
# ## more to do
#
# check NA <= 5 () (new column)
# make new or used column
# electric - drop
#
# make t-sne plot new-used - is it differ?

# %% [markdown]
# ## checking datasets similarity

# %%
train_jane.shape, train_baseline.shape, test.shape
# Out:
# ((130201, 20), (89378, 20), (34686, 19))

# %%
train_jane[train_jane.columns.sort_values().tolist()].sample(3, random_state=42).T
# Out:
#                                                                  83856  \
# bodyType                                             внедорожник 5 дв.
# brand                                                           TOYOTA
# color                                                            белый
# description          Ваш выбор и Ваше время наши главные приоритеты...
# engineDisplacement                                                 2.0
# enginePower                                                      148.0
# fuelType                                                        бензин
# mileage                                                        47800.0
# modelDate                                                       2016.0
# model_name                                                        c-hr
# numberOfDoors                                                      5.0
# price                                                        1989000.0
# productionDate                                                  2018.0
# vehicleTransmission                                           вариатор
# vendor                                                        JAPANESE
# Владельцы                                                          1.0
# Владение                                                           NaN
# ПТС                                                           Оригинал
# Привод                                                        передний
# Руль                                                             Левый
#
#                                                                  44922  \
# bodyType                                             внедорожник 5 дв.
# brand                                                           NISSAN
# color                                                           чёрный
# description          Продажа от официального дилера ГК АВТОМИР Увел...
# engineDisplacement                                                 2.0
# enginePower                                                      141.0
# fuelType                                                        бензин
# mileage                                                       184369.0
# modelDate                                                       2010.0
# model_name                                                     qashqai
# numberOfDoors                                                      5.0
# price                                                         825000.0
# productionDate                                                  2012.0
# vehicleTransmission                                           вариатор
# vendor                                                        JAPANESE
# Владельцы                                                          1.0
# Владение                                                           NaN
# ПТС                                                           Оригинал
# Привод                                                        передний
# Руль                                                             Левый
#
#                                                                  77741
# bodyType                                             внедорожник 5 дв.
# brand                                                           TOYOTA
# color                                                       коричневый
# description          Продается легендарный Toyota RAV4 1 владелец П...
# engineDisplacement                                                 2.0
# enginePower                                                      158.0
# fuelType                                                        бензин
# mileage                                                       152712.0
# modelDate                                                       2010.0
# model_name                                                        rav4
# numberOfDoors                                                      5.0
# price                                                        1135000.0
# productionDate                                                  2011.0
# vehicleTransmission                                           вариатор
# vendor                                                        JAPANESE
# Владельцы                                                          1.0
# Владение                                                           NaN
# ПТС                                                           Оригинал
# Привод                                                          полный
# Руль                                                             Левый

# %%
train_baseline.rename(columns={"model": "model_name"}, inplace=True)
train_baseline[train_baseline.columns.sort_values().tolist()].sample(
    3, random_state=42
).T
# Out:
#                                                                  54772  \
# bodyType                                                    Компактвэн
# brand                                                             OPEL
# color                                                           040001
# description          Продам авто в хорошем состоянии без проблем вс...
# engineDisplacement                                                 1.8
# enginePower                                                      140.0
# fuelType                                                        бензин
# mileage                                                         177000
# modelDate                                                       2005.0
# model_name                                                      ZAFIRA
# numberOfDoors                                                      5.0
# price                                                         360000.0
# productionDate                                                    2008
# vehicleTransmission                                              ROBOT
# vendor                                                             NaN
# Владельцы                                                          2.0
# Владение                                    {'year': 2017, 'month': 6}
# ПТС                                                           ORIGINAL
# Привод                                                        передний
# Руль                                                              LEFT
#
#                                                                  73499  \
# bodyType                                                         Седан
# brand                                                       VOLKSWAGEN
# color                                                           FFD600
# description          Штрафы оплаченны !! На днях снимут с машины, н...
# engineDisplacement                                                 1.6
# enginePower                                                       90.0
# fuelType                                                        бензин
# mileage                                                         380000
# modelDate                                                       2014.0
# model_name                                                        POLO
# numberOfDoors                                                      4.0
# price                                                         340000.0
# productionDate                                                    2016
# vehicleTransmission                                         MECHANICAL
# vendor                                                        EUROPEAN
# Владельцы                                                          1.0
# Владение                                                           NaN
# ПТС                                                           ORIGINAL
# Привод                                                        передний
# Руль                                                              LEFT
#
#                                                                  74260
# bodyType                                                       Лифтбек
# brand                                                       VOLKSWAGEN
# color                                                           FAFBFB
# description          Фольксваген Центр Подольск готов сделать вам п...
# engineDisplacement                                                 1.6
# enginePower                                                       90.0
# fuelType                                                        бензин
# mileage                                                              0
# modelDate                                                       2020.0
# model_name                                                        POLO
# numberOfDoors                                                      5.0
# price                                                         821900.0
# productionDate                                                    2020
# vehicleTransmission                                         MECHANICAL
# vendor                                                        EUROPEAN
# Владельцы                                                          NaN
# Владение                                                           NaN
# ПТС                                                           ORIGINAL
# Привод                                                        передний
# Руль                                                              LEFT

# %%
test[test.columns.sort_values().tolist()].sample(3, random_state=42).T
# Out:
#                                                                  19026  \
# bodyType                                             внедорожник 5 дв.
# brand                                                           TOYOTA
# color                                                           чёрный
# description          ЛОТ: 01215604\nФаворит Хофф\n\nВы можете получ...
# engineDisplacement                                             2.0 LTR
# enginePower                                                    150 N12
# fuelType                                                        бензин
# mileage                                                         121490
# modelDate                                                         2000
# model_name                                                       rav_4
# numberOfDoors                                                        5
# productionDate                                                    2001
# vehicleTransmission                                     автоматическая
# vendor                                                        JAPANESE
# Владельцы                                                            3
# Владение                                                           NaN
# ПТС                                                           Оригинал
# Привод                                                          полный
# Руль                                                             Левый
#
#                                                                  3337   \
# bodyType                                                         седан
# brand                                                             AUDI
# color                                                            синий
# description          Авто в идеальном состоянии проблем нет смотрит...
# engineDisplacement                                             1.8 LTR
# enginePower                                                    125 N12
# fuelType                                                        бензин
# mileage                                                         240000
# modelDate                                                         1994
# model_name                                                          a6
# numberOfDoors                                                        4
# productionDate                                                    1997
# vehicleTransmission                                       механическая
# vendor                                                        EUROPEAN
# Владельцы                                                            2
# Владение                                             1 год и 5 месяцев
# ПТС                                                           Оригинал
# Привод                                                        передний
# Руль                                                             Левый
#
#                                                                  11807
# bodyType                                             внедорожник 5 дв.
# brand                                                           NISSAN
# color                                                            белый
# description          Комфорт: 6. Безопасность: 4. Обзор: 2. Салон: 2.
# engineDisplacement                                             2.0 LTR
# enginePower                                                    141 N12
# fuelType                                                        бензин
# mileage                                                         104842
# modelDate                                                         2010
# model_name                                                     x_trail
# numberOfDoors                                                        5
# productionDate                                                    2014
# vehicleTransmission                                           вариатор
# vendor                                                        JAPANESE
# Владельцы                                                            2
# Владение                                                           NaN
# ПТС                                                           Оригинал
# Привод                                                          полный
# Руль                                                             Левый

# %% [markdown]
# ## comments on further train_baseline processing
#
# - [ ] bodyType - no doors specified
# - [ ] color - hexified
# - [ ] model_name - more standartified
# - [ ] productionDate - different dtype
# - [x] Владение - to convert to number of days
# - [ ] vehicleTransmission - to standartize naming
# - [ ] ПТС - to standartize naming
# - [ ] Руль - to standartize naming

# %% [markdown]
# ## merging train datasets

# %%
train_jane['sample'] = 1
train_baseline['sample'] = 2
train = pd.concat([train_jane, train_baseline])

# %%
train["Владение"] = train.Владение.apply(parse_ownership_duration)

# %%
train["Владение"].value_counts().head(5)
# Out:
# 1155.0    646
# 2555.0    634
# 730.0     623
# 3650.0    603
# 365.0     525
# Name: Владение, dtype: int64

# %% [markdown]
# ## ------------------------

# %%
train.drop_duplicates(inplace=True)
train.dropna(subset=['price'], inplace = True)

# %%
train['bodyType'] = train['bodyType'].str.lower()

# %%
test['bodyType'].unique()
# Out:
# array(['лифтбек', 'внедорожник 5 дв.', 'хэтчбек 5 дв.', 'седан',
#        'компактвэн', 'универсал 5 дв.', 'пикап одинарная кабина',
#        'хэтчбек 3 дв.', 'купе', 'кабриолет', 'минивэн',
#        'пикап двойная кабина', 'внедорожник 3 дв.', 'родстер', 'микровэн',
#        'седан 2 дв.', 'купе-хардтоп', 'фастбек', 'тарга',
#        'внедорожник открытый', 'лимузин', 'пикап полуторная кабина',
#        'седан-хардтоп', 'фургон'], dtype=object)

# %%
train['bodyType'] = train['bodyType'].apply(get_bodytype)

# %%
train['bodyType']
# Out:
# 0                     None
# 1                     None
# 2                     None
# 3                     None
# 4        внедорожник 5 дв.
#                ...
# 89373                 None
# 89374                 None
# 89375                 None
# 89376                 None
# 89377                 None
# Name: bodyType, Length: 121420, dtype: object

# %%
train.shape
# Out:
# (121420, 21)

# %%
train[pd.isna(train['brand'])].count()
# Out:
# bodyType               0
# brand                  0
# color                  0
# description            0
# engineDisplacement     0
# enginePower            0
# fuelType               0
# mileage                0
# modelDate              0
# model_name             0
# numberOfDoors          0
# productionDate         0
# vehicleTransmission    0
# vendor                 0
# Владельцы              0
# Владение               0
# ПТС                    0
# Привод                 0
# Руль                   0
# price                  0
# sample                 0
# dtype: int64
