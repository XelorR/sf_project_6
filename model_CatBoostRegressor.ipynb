# %% [markdown]
# - [previous file - EDA](2022-03-31_train-test_EDA.ipynb)
# - [previous file - sklearn experiments](2022-04-12_experiments-sklearn.ipynb)
# - [next file - ensembles](2022-04-15_ensemble.ipynb)
#
# ## imports

# %%
# !pip install catboost optuna joblib pyarrow

# %%
from warnings import filterwarnings
import os
import pickle

import joblib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler, LabelEncoder
from catboost import CatBoostRegressor
import optuna
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_absolute_percentage_error

sns.set()
filterwarnings("ignore")

# %% [markdown]
# ## preprocessing

# %% [markdown]
# ### reading data

# %%
path_to_data = "data"
# path_to_data = "https://github.com/XelorR/sf_project_6/raw/master/data"

train_raw = pd.read_parquet(f"{path_to_data}/2022-04-08_train_pre-model.parquet")
test_raw = pd.read_parquet(f"{path_to_data}/2022-04-08_test_pre-model.parquet")

train_raw.shape, test_raw.shape
# Out:
# ((115367, 30), (34686, 28))

# %% [markdown]
# ### functions

# %%
def train_or_load(clf, X, y, filepath: str = "model.joblib", complevel: int = 9):
    """
    Fits and serialize model as .pkl, .pickle or .joblib file.
    Loads serialized model if filepath exists.

    clf - model to fit
    X - dateset
    y - lables
    filepath - where to save
    complevel - compression level (0-9) for joblib, ignored for pickle
    """
    if filepath.endswith(".joblib"):
        if os.path.exists(filepath):
            with open(filepath, "rb") as f:
                clf = joblib.load(f)
        else:
            clf.fit(X, y)
            with open(filepath, "wb") as f:
                joblib.dump(clf, f, compress=complevel)
        return clf
    elif filepath.endswith(".pkl") or filepath.endswith(".pickle"):
        if os.path.exists(filepath):
            with open(filepath, "rb") as f:
                clf = pickle.load(f)
        else:
            clf.fit(X, y)
            with open(filepath, "wb") as f:
                pickle.dump(clf, f)
        return clf


def submit(hold_out: pd.DataFrame, model, name="submission"):
    preds = model.predict(hold_out)
    submission = pd.read_csv(f"{path_to_data}/sample_submission.csv")
    submission["price"] = preds
    submission.to_csv(f"{name}.csv", index=False)


def submit_log(hold_out: pd.DataFrame, model, name="submission"):
    preds = model.predict(hold_out)
    submission = pd.read_csv(f"{path_to_data}/sample_submission.csv")
    submission["price"] = np.exp(preds)
    submission.to_csv(f"{name}.csv", index=False)

# %% [markdown]
# ### encoding

# %%
train_raw["train/test"] = "train"
test_raw["train/test"] = "test"

data = train_raw.append(test_raw)
data["ptc"].fillna("Оригинал", inplace=True)

data[data.select_dtypes("object").columns.tolist()] = data[
    data.select_dtypes("object").columns.tolist()
].astype(str)

for col in set(data.select_dtypes(exclude=("object")).columns) - {"price"}:
    data[col] = (
        RobustScaler().fit_transform(data[col].values.reshape(-1, 1)).reshape(-1, 1)
    )

for col in ["model_name"]:
    data[col] = LabelEncoder().fit_transform(data[col].astype("str"))

data = pd.get_dummies(
    data,
    columns=[
        "vehicle_transmission",
        "vendor",
        "brand",
        "fuel_type",
        "body_type",
        "color",
        "ptc",
        "drive",
        "wheel",
        "age_cat",
    ],
)

train = data.loc[data["train/test"] == "train"]

train_jane = train.loc[train["sample"] == "jane"]
train_sokolov = train.loc[train["sample"] == "sokolov"]
train_jane["price"] = train_jane["price"] * 0.86
train = train_jane.append(train_sokolov)

train.drop(columns=["sample", "description", "train/test"], inplace=True)
test = data.loc[data["train/test"] == "test"].drop(
    columns=["sample", "description", "train/test", "price"]
)

# %% [markdown]
# ## preparing but not encoding

# %%
train_raw["train/test"] = "train"
test_raw["train/test"] = "test"

data_no_enc = train_raw.append(test_raw)
data_no_enc["ptc"].fillna("Оригинал", inplace=True)

data_no_enc[data_no_enc.select_dtypes("object").columns.tolist()] = data_no_enc[
    data_no_enc.select_dtypes("object").columns.tolist()
].astype(str)

train_no_enc = data_no_enc.loc[data_no_enc["train/test"] == "train"]

train_no_enc_jane = train_no_enc.loc[train_no_enc["sample"] == "jane"]
train_no_enc_sokolov = train_no_enc.loc[train_no_enc["sample"] == "sokolov"]
train_no_enc_jane["price"] = train_no_enc_jane["price"] * 0.86
train_no_enc = train_no_enc_jane.append(train_no_enc_sokolov)

train_no_enc.drop(columns=["sample", "description", "train/test"], inplace=True)
test_no_enc = data_no_enc.loc[data_no_enc["train/test"] == "test"].drop(
    columns=["sample", "description", "train/test", "price"]
)

# %%
train_no_enc.sample(5, random_state=42).T.reset_index()
# Out:
#                    index                84022                64128  \
# 0              body_type          внедорожник                седан
# 1                  brand              PORSCHE                  KIA
# 2                  color                белый                белый
# 3    engine_displacement                  3.0                  1.4
# 4           engine_power                245.0                107.0
# 5              fuel_type               дизель               бензин
# 6                 km_age             120676.0              53600.0
# 7             model_year               2010.0               2015.0
# 8             model_name              CAYENNE                  RIO
# 9        number_of_doors                    5                    4
# 10       production_year                 2012                 2016
# 11  vehicle_transmission            AUTOMATIC           MECHANICAL
# 12                vendor             EUROPEAN               KOREAN
# 13                owners                    2                    1
# 14                   ptc             Оригинал             Оригинал
# 15                 drive               полный             передний
# 16                 wheel                Левый                Левый
# 17                 price            2095800.0             489000.0
# 18           parsed_date  2020-09-09 00:00:00  2020-09-09 00:00:00
# 19             diff_data               3174.0               1713.0
# 20       diff_data_years              8.69589             4.693151
# 21               age_cat              not_bad     may_be_on_garant
# 22                 retro                    0                    0
# 23           most_wanted                    0                    0
# 24             good_cond                    0                    1
# 25           km_per_year         13877.359798         11420.899008
# 26            desc_count                  165                   34
# 27                dealer                    1                    0
#
#                   64226                43487                 2657
# 0                 седан              хэтчбек              хэтчбек
# 1                   KIA            CHEVROLET                SKODA
# 2                 белый                синий              красный
# 3                   1.4                  1.6                  1.2
# 4                 107.0                109.0                 60.0
# 5                бензин               бензин               бензин
# 6               68793.0             181000.0             286000.0
# 7                2015.0               2004.0               2007.0
# 8                   RIO              LACETTI                FABIA
# 9                     4                    5                    5
# 10                 2015                 2007                 2008
# 11            AUTOMATIC            AUTOMATIC           MECHANICAL
# 12               KOREAN             AMERICAN             EUROPEAN
# 13                    1                    3                    3
# 14             Оригинал             Оригинал             Оригинал
# 15             передний             передний             передний
# 16                Левый                Левый                Левый
# 17             550000.0             260000.0             240800.0
# 18  2020-09-09 00:00:00  2020-09-09 00:00:00  2021-09-26 00:00:00
# 19               2078.0               5000.0               5017.0
# 20             5.693151             13.69863            13.745205
# 21              not_bad                  med                  med
# 22                    0                    0                    0
# 23                    0                    0                    0
# 24                    0                    0                    0
# 25         12083.467276              13213.0         20807.255332
# 26                   83                   35                   13
# 27                    1                    0                    0

# %%
cat_features = [0, 1, 2, 5, 8, 9, 10, 11, 12, 13, 14, 15, 16, 21, 27]

# %% [markdown]
# ### preparing to train models

# %%
if os.path.exists("models"):
    pass
else:
    os.mkdir("models")

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
    train.drop(columns="price"), train["price"], random_state=42, shuffle=True
)
X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((86525, 112), (86525,), (28842, 112), (28842,))

# %%
X_train_no_enc, X_valid_no_enc, y_train_no_enc, y_valid_no_enc = train_test_split(
    train_no_enc.drop(columns="price"), train_no_enc["price"], random_state=42, shuffle=True
)
X_train_no_enc.shape, y_train_no_enc.shape, X_valid_no_enc.shape, y_valid_no_enc.shape
# Out:
# ((86525, 27), (86525,), (28842, 27), (28842,))

# %% [markdown]
# ## tuning
#
# ### is it faster on GPU?
#
# ![](img/catboost_on_gpu.png)
#
# it is **faster on GPU** even using laptop's intergrated Nvidia GTX 970 M.

# %% [markdown]
# ###

# %% [markdown]
# ### is it better to do manual encoding or keep raw?

# %%
model = CatBoostRegressor(task_type="GPU", devices="0", random_state=42).fit(
    X_train_no_enc, np.log(y_train_no_enc), cat_features=cat_features
)

print(
    "no preproc",
    mean_absolute_percentage_error(y_valid, model.predict(X_valid_no_enc)),
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File _catboost.pyx:2175, in _catboost.get_float_feature()
#
# File _catboost.pyx:1126, in _catboost._FloatOrNan()
#
# File _catboost.pyx:949, in _catboost._FloatOrNanFromString()
#
# TypeError: Cannot convert 'b'old'' to float
#
# During handling of the above exception, another exception occurred:
#
# CatBoostError                             Traceback (most recent call last)
# /home/user/Documents/sf_project_6/model_CatBoostRegressor.ipynb Cell 22' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/user/Documents/sf_project_6/model_CatBoostRegressor.ipynb#ch0000028?line=0'>1</a> model = CatBoostRegressor(task_type="GPU", devices="0", random_state=42).fit(
#       <a href='vscode-notebook-cell:/home/user/Documents/sf_project_6/model_CatBoostRegressor.ipynb#ch0000028?line=1'>2</a>     X_train_no_enc, np.log(y_train_no_enc), cat_features=cat_features
#       <a href='vscode-notebook-cell:/home/user/Documents/sf_project_6/model_CatBoostRegressor.ipynb#ch0000028?line=2'>3</a> )
#       <a href='vscode-notebook-cell:/home/user/Documents/sf_project_6/model_CatBoostRegressor.ipynb#ch0000028?line=4'>5</a> print(
#       <a href='vscode-notebook-cell:/home/user/Documents/sf_project_6/model_CatBoostRegressor.ipynb#ch0000028?line=5'>6</a>     "no preproc",
#       <a href='vscode-notebook-cell:/home/user/Documents/sf_project_6/model_CatBoostRegressor.ipynb#ch0000028?line=6'>7</a>     mean_absolute_percentage_error(y_valid, model.predict(X_valid_no_enc)),
#       <a href='vscode-notebook-cell:/home/user/Documents/sf_project_6/model_CatBoostRegressor.ipynb#ch0000028?line=7'>8</a> )
#
# File ~/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py:5351, in CatBoostRegressor.fit(self, X, y, cat_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=5347'>5348</a> if 'loss_function' in params:
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=5348'>5349</a>     CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
# -> <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=5350'>5351</a> return self._fit(X, y, cat_features, None, None, None, sample_weight, None, None, None, None, baseline,
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=5351'>5352</a>                  use_best_model, eval_set, verbose, logging_level, plot, column_description,
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=5352'>5353</a>                  verbose_eval, metric_period, silent, early_stopping_rounds,
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=5353'>5354</a>                  save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File ~/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py:2073, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=2069'>2070</a> if y is None and not isinstance(X, PATH_TYPES + (Pool,)):
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=2070'>2071</a>     raise CatBoostError("y may be None only when X is an instance of catboost.Pool or string")
# -> <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=2072'>2073</a> train_params = self._prepare_train_params(
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=2073'>2074</a>     X=X, y=y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features,
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=2074'>2075</a>     pairs=pairs, sample_weight=sample_weight, group_id=group_id, group_weight=group_weight,
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=2075'>2076</a>     subgroup_id=subgroup_id, pairs_weight=pairs_weight, baseline=baseline, use_best_model=use_best_model,
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=2076'>2077</a>     eval_set=eval_set, verbose=verbose, logging_level=logging_level, plot=plot,
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=2077'>2078</a>     column_description=column_description, verbose_eval=verbose_eval, metric_period=metric_period,
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=2078'>2079</a>     silent=silent, early_stopping_rounds=early_stopping_rounds, save_snapshot=save_snapshot,
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=2079'>2080</a>     snapshot_file=snapshot_file, snapshot_interval=snapshot_interval, init_model=init_model,
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=2080'>2081</a>     callbacks=callbacks
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=2081'>2082</a> )
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=2082'>2083</a> params = train_params["params"]
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=2083'>2084</a> train_pool = train_params["train_pool"]
#
# File ~/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py:1959, in CatBoost._prepare_train_params(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks)
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1955'>1956</a> text_features = _process_feature_indices(text_features, X, params, 'text_features')
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1956'>1957</a> embedding_features = _process_feature_indices(embedding_features, X, params, 'embedding_features')
# -> <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1958'>1959</a> train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1959'>1960</a>                                sample_weight, group_id, group_weight, subgroup_id, pairs_weight,
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1960'>1961</a>                                baseline, column_description)
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1961'>1962</a> if train_pool.is_empty_:
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1962'>1963</a>     raise CatBoostError("X is empty.")
#
# File ~/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py:1241, in _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, column_description)
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1238'>1239</a>     if y is None:
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1239'>1240</a>         raise CatBoostError("y has not initialized in fit(): X is not catboost.Pool object, y must be not None in fit().")
# -> <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1240'>1241</a>     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1241'>1242</a>                       group_weight=group_weight, subgroup_id=subgroup_id, pairs_weight=pairs_weight, baseline=baseline)
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1242'>1243</a> return train_pool
#
# File ~/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py:645, in Pool.__init__(self, data, label, cat_features, text_features, embedding_features, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count, log_cout, log_cerr)
#     <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=638'>639</a>         if isinstance(feature_names, PATH_TYPES):
#     <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=639'>640</a>             raise CatBoostError(
#     <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=640'>641</a>                 "feature_names must be None or have non-string type when the pool is created from "
#     <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=641'>642</a>                 "python objects."
#     <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=642'>643</a>             )
# --> <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=644'>645</a>         self._init(data, label, cat_features, text_features, embedding_features, pairs, weight,
#     <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=645'>646</a>                    group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#     <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=646'>647</a> super(Pool, self).__init__()
#
# File ~/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py:1222, in Pool._init(self, data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1219'>1220</a> if feature_tags is not None:
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1220'>1221</a>     feature_tags = self._check_transform_tags(feature_tags, feature_names)
# -> <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1221'>1222</a> self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight,
#    <a href='file:///home/user/Documents/sf_project_6/venv/lib64/python3.10/site-packages/catboost/core.py?line=1222'>1223</a>                 group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#
# File _catboost.pyx:3763, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:3812, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:3646, in _catboost._PoolBase._init_features_order_layout_pool()
#
# File _catboost.pyx:2672, in _catboost._set_features_order_data_pd_data_frame()
#
# File _catboost.pyx:2216, in _catboost.create_num_factor_data()
#
# File _catboost.pyx:2177, in _catboost.get_float_feature()
#
# CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=20]="old": Cannot convert 'b'old'' to float

# %%
model = CatBoostRegressor(task_type="GPU", devices="0", random_state=42).fit(
    X_train, np.log(y_train)
)

print(
    "no preproc",
    mean_absolute_percentage_error(y_valid, model.predict(X_valid)),
)
